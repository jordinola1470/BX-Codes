# %%
import pandas as pd
import numpy as np
import seaborn as sns
from jupyterthemes import jtplot
jtplot.style(theme='grade3', context='notebook', ticks=True, grid=False)

# %%
sites_general = pd.read_excel('sitios_general_ecuador.xlsx')
sites_integracion = pd.read_excel('sitios_integracion_ecuador.xlsx')
authors_general = pd.read_excel('autores_general_ecuador.xlsx')
authors_integracion = pd.read_excel('autores_integracion_ecuador.xlsx')

# %%
base_sitios = pd.merge(sites_general,sites_integracion, left_on='Author', right_on='Author', how = 'left')
base_cuentas = pd.merge(authors_general,authors_integracion, left_on='Author', right_on='Author', how = 'left')

# %%
base_pegada = base_cuentas.append(base_sitios)
base_pegada['Integración'] = base_pegada['Integración'].fillna(0)
base_pegada.head(7)
# Out:
#           Author  Volumen  Integración
# 0        ecuabot      412         28.0
# 1      paoleague      226          3.0
# 2    ecupuntocom      183          3.0
# 3      gkecuador      111         12.0
# 4    moviliderec       86          5.0
# 5  diarioextraec       72          4.0
# 6   acnurecuador       59         13.0

# %%
base_pegada['% Integración'] = round(base_pegada['Integración']/base_pegada['Volumen']*100,2)
base_pegada.head(7)
# Out:
#           Author  Volumen  Integración  % Integración
# 0        ecuabot      412         28.0           6.80
# 1      paoleague      226          3.0           1.33
# 2    ecupuntocom      183          3.0           1.64
# 3      gkecuador      111         12.0          10.81
# 4    moviliderec       86          5.0           5.81
# 5  diarioextraec       72          4.0           5.56
# 6   acnurecuador       59         13.0          22.03

# %%
base_grafica = base_pegada[base_pegada['% Integración'] > 25.0]
ax = sns.barplot(x="Author", y="% Integración", data=base_grafica, palette='Blues_d')
for item in ax.get_xticklabels():
    item.set_rotation(90)

# %%
base_pegada.to_excel('Base_medios_sitios_integracion.xlsx')

# %%
base_grafica = base_grafica.sort_values('Integración', ascending=False)
base_grafica
# Out:
#                        Author  Volumen  Integración  % Integración
# 4               lahora.com.ec      100         33.0          33.00
# 3                  expreso.ec      104         28.0          26.92
# 5           elmercurio.com.ec       94         28.0          29.79
# 11            lanacion.com.ec       60         18.0          30.00
# 13          ecuadorenvivo.com       51         16.0          31.37
# 21              zaracaytv.com       20          9.0          45.00
# 25             cronica.com.ec       12          6.0          50.00
# 26   elvanguardistaonline.com       12          5.0          41.67
# 41                     ccpidg       10          3.0          30.00
# 32         ecuadornews.com.ec        5          3.0          60.00
# 48                 onuecuador        9          3.0          33.33
# 59                   itsabela        6          2.0          33.33
# 62              onumujeresecu        6          2.0          33.33
# 86                 goberazuay        4          2.0          50.00
# 134              elnotista_ec        1          1.0         100.00
# 144                 radiohcjb        1          1.0         100.00
# 143           radiodistritofm        1          1.0         100.00
# 130                   cnimhec        1          1.0         100.00
# 125           somosyachaytech        2          1.0          50.00
# 116           conexnoticiasec        2          1.0          50.00
# 114                  canalrtu        2          1.0          50.00
# 111                unpguayas_        3          1.0          33.33
# 96               diariopinion        3          1.0          33.33
# 95                cn_igualdad        3          1.0          33.33
# 36        trafficamerican.com        1          1.0         100.00

# %%
base_grafica = base_grafica.sort_values('% Integración', ascending=True)
base_grafica
# Out:
#                        Author  Volumen  Integración  % Integración
# 3                  expreso.ec      104         28.0          26.92
# 5           elmercurio.com.ec       94         28.0          29.79
# 11            lanacion.com.ec       60         18.0          30.00
# 41                     ccpidg       10          3.0          30.00
# 13          ecuadorenvivo.com       51         16.0          31.37
# 4               lahora.com.ec      100         33.0          33.00
# 96               diariopinion        3          1.0          33.33
# 111                unpguayas_        3          1.0          33.33
# 95                cn_igualdad        3          1.0          33.33
# 59                   itsabela        6          2.0          33.33
# 62              onumujeresecu        6          2.0          33.33
# 48                 onuecuador        9          3.0          33.33
# 26   elvanguardistaonline.com       12          5.0          41.67
# 21              zaracaytv.com       20          9.0          45.00
# 86                 goberazuay        4          2.0          50.00
# 125           somosyachaytech        2          1.0          50.00
# 116           conexnoticiasec        2          1.0          50.00
# 114                  canalrtu        2          1.0          50.00
# 25             cronica.com.ec       12          6.0          50.00
# 32         ecuadornews.com.ec        5          3.0          60.00
# 134              elnotista_ec        1          1.0         100.00
# 144                 radiohcjb        1          1.0         100.00
# 143           radiodistritofm        1          1.0         100.00
# 130                   cnimhec        1          1.0         100.00
# 36        trafficamerican.com        1          1.0         100.00

# %%
base_grafica = base_pegada[base_pegada['% Integración'] > 28.57]
ax = sns.barplot(x="Author", y="% Integración", data=base_grafica, palette='Blues_d', order = base_grafica.sort_values('% Integración', ascending=False).Author)
for item in ax.get_xticklabels():
    item.set_rotation(90)

# %%
base_grafica = base_pegada[base_pegada['Volumen'] > 45]
ax = sns.barplot(x="Author", y="Volumen", data=base_grafica, palette='Blues_d', order = base_grafica.sort_values('Volumen', ascending=False).Author)
for item in ax.get_xticklabels():
    item.set_rotation(90)

# %%
import funciones as fn
df = pd.read_excel('mentions.xlsx')
df
# Out:
#       Unnamed: 0    Query Id Query Name                     Date  \
# 0              1  2000697378    General  2022-01-11 04:18:16.000
# 1              2  2000697378    General  2022-01-11 03:50:03.000
# 2              3  2000697378    General  2022-01-11 03:23:33.000
# 3              4  2000697378    General  2022-01-11 01:55:14.000
# 4              5  2000697378    General  2022-01-11 01:50:02.000
# ...          ...         ...        ...                      ...
# 2254        2255  2000697378    General  2021-06-15 19:10:06.000
# 2255        2256  2000697378    General  2021-06-15 17:15:00.000
# 2256        2257  2000697378    General  2021-06-15 17:06:26.000
# 2257        2258  2000697378    General  2021-06-15 15:20:00.000
# 2258        2259  2000697378    General  2021-06-15 09:00:52.000
#
#                                                   Title  \
# 0     RT @BNPeriodismo El informe del caso Saab, que...
# 1     RT @Elperiodiquito #Mundo #Ecuador anunciará e...
# 2     RT @paoleague URGENTE\nCubanos y venezolanos d...
# 3     El proceso de entrega de visas humanitarias te...
# 4     RT @Elperiodiquito #Mundo #Ecuador anunciará e...
# ...                                                 ...
# 2254  La Policía aprehende a tres sujetos armados qu...
# 2255  📰#Nacionales | El canciller Mauricio Montalvo,...
# 2256  Se acerca la Conferencia Internacional de Dona...
# 2257  “Eso es lo que yo no quiero, poner a mi hija e...
# 2258  Venezolanos con esperanza ante anuncio de Lass...
#
#                                                 Snippet  \
# 0     RT @BNPeriodismo El informe del caso Saab, que...
# 1     RT @Elperiodiquito #Mundo #Ecuador anunciará e...
# 2     RT @paoleague URGENTE Cubanos y venezolanos de...
# 3     El proceso de entrega de visas humanitarias te...
# 4     RT @Elperiodiquito #Mundo #Ecuador anunciará e...
# ...                                                 ...
# 2254  La Policía aprehende a tres sujetos armados qu...
# 2255  📰#Nacionales | El canciller Mauricio Montalvo,...
# 2256  Se acerca la Conferencia Internacional de Dona...
# 2257  “Eso es lo que yo no quiero, poner a mi hija e...
# 2258  Venezolanos con esperanza ante anuncio de Lass...
#
#                                                     Url       Domain  \
# 0     http://twitter.com/MoviLIDERec/statuses/148075...  twitter.com
# 1     http://twitter.com/ecuabot/statuses/1480748815...  twitter.com
# 2     http://twitter.com/paoleague/statuses/14807421...  twitter.com
# 3     http://twitter.com/GKecuador/statuses/14807199...  twitter.com
# 4     http://twitter.com/ecuabot/statuses/1480718613...  twitter.com
# ...                                                 ...          ...
# 2254  http://twitter.com/Expresoec/statuses/14048789...  twitter.com
# 2255  http://twitter.com/pichinchauniver/statuses/14...  twitter.com
# 2256  http://twitter.com/ACNUREcuador/statuses/14048...  twitter.com
# 2257  http://twitter.com/ACNUREcuador/statuses/14048...  twitter.com
# 2258  http://twitter.com/ecuadorenvivo/statuses/1404...  twitter.com
#
#      Sentiment  Emotion  ... Reddit Score Reddit Author Karma  \
# 0      neutral      NaN  ...          NaN                 NaN
# 1      neutral      NaN  ...          NaN                 NaN
# 2      neutral      NaN  ...          NaN                 NaN
# 3      neutral      NaN  ...          NaN                 NaN
# 4      neutral      NaN  ...          NaN                 NaN
# ...        ...      ...  ...          ...                 ...
# 2254   neutral      NaN  ...          NaN                 NaN
# 2255   neutral      NaN  ...          NaN                 NaN
# 2256   neutral      NaN  ...          NaN                 NaN
# 2257   neutral      NaN  ...          NaN                 NaN
# 2258   neutral      NaN  ...          NaN                 NaN
#
#      Reddit Author Awardee Karma Reddit Author Awarder Karma Subreddit  \
# 0                            NaN                         NaN       NaN
# 1                            NaN                         NaN       NaN
# 2                            NaN                         NaN       NaN
# 3                            NaN                         NaN       NaN
# 4                            NaN                         NaN       NaN
# ...                          ...                         ...       ...
# 2254                         NaN                         NaN       NaN
# 2255                         NaN                         NaN       NaN
# 2256                         NaN                         NaN       NaN
# 2257                         NaN                         NaN       NaN
# 2258                         NaN                         NaN       NaN
#
#      Subreddit Subscribers Barómetro Ecuador  \
# 0                      NaN               NaN
# 1                      NaN               NaN
# 2                      NaN          Vivienda
# 3                      NaN           Trabajo
# 4                      NaN               NaN
# ...                    ...               ...
# 2254                   NaN         Seguridad
# 2255                   NaN               NaN
# 2256                   NaN             Salud
# 2257                   NaN         Seguridad
# 2258                   NaN       Integración
#
#                                       Boletín   Ciudades              Medios
# 0                                         NaN      Quito  Medios, medios all
# 1                                         NaN        NaN  Medios, medios all
# 2                                         NaN      Quito  Medios, medios all
# 3     Medios de Comunicación y Organizaciones      Quito  Medios, medios all
# 4                                         NaN        NaN  Medios, medios all
# ...                                       ...        ...                 ...
# 2254  Medios de Comunicación y Organizaciones  Guayaquil  Medios, medios all
# 2255  Medios de Comunicación y Organizaciones      Quito                 NaN
# 2256  Medios de Comunicación y Organizaciones        NaN                 NaN
# 2257  Medios de Comunicación y Organizaciones        NaN                 NaN
# 2258                                      NaN        NaN  Medios, medios all
#
# [2259 rows x 87 columns]

# %%
nombres = df['Author'].unique()
nombres
# Out:
# array(['MoviLIDERec', 'ecuabot', 'paoleague', 'GKecuador', 'Expresoec',
#        'ecupuntocom', 'larepublica_ec', 'DialoguemosINFO', 'KCH_FM',
#        'unpguayas_', 'EcuadorWillana', 'LaPosta_Ecu', 'complicefm',
#        'teleamazonasec', 'albo75', 'CanalRTU', 'ecuadorprensaec',
#        'UdlaChannelEc', 'EcuavisaInforma', 'WRadioec', 'revistavistazo',
#        'eluniversocom', 'IdoloPasionWeb', 'EsmeraldasNews',
#        'cronicacuenca', 'DebateBSC', 'ecuafootball', 'elmercuriomanta',
#        'WQRadio_EC', 'iamdanielypunto', 'DiarioExtraEc', 'RevistaHogar',
#        'ACNUREcuador', 'PrimeraPlanaECU', 'tctelevision', 'notimundoec',
#        'RiobambaBot', 'portalxvcom', 'diariocorreoec', 'aldiacomec',
#        'elmercurioec', 'TVCElComercioTv', 'ecuadoraldia365',
#        'RTS_LaNoticia', 'teleradioec', 'MachalaNoticias', 'Caravana750',
#        '3monosapios', 'MundoDeporEC', 'Unionradio580am', 'ecuadorenvivo',
#        'MetroEcuador', 'quenoticiasec', 'CCPIDG', 'radioactiva_ec',
#        'TiempoRealEC', 'lahistoriaec', 'tomebamba', 'radio_pichincha',
#        'DeportesPU', 'radiosucesosec', 'marcadorec', 'lahoraecuador',
#        'Teradeportes', 'PlayFMDeportes', 'directfutbolec',
#        'LaPrensaInforma', 'EcEnDirecto', 'onumujeresEcu',
#        'prefecturaLoja', 'revista_gestion', 'horatungurahua', 'Primicias',
#        'MachalaMovil', 'Conexnoticiasec', 'LaKolmenaEC', 'itsabela',
#        'PactoGlobalEcua', 'ciespal', 'wambraEc', 'RadioMorena640',
#        'Pinvestigacion3', 'dialogodeport', 'radio_sucre700', 'ucsg_tv',
#        'manabi_noticias', 'LaMareaec', 'diariocentroec', 'manavisionec',
#        'RadioRomanceFM', 'Gamavisionecu', 'SinCadenasECU', 'GolEcuador',
#        'elcomerciocom', 'GuerrerosDig_RC', 'ecuainm_oficial', 'RC_Guayas',
#        'confirmadonet', 'diariopinion', 'QuitoSinMineria', 'Modelo977',
#        'CentroDePrensa', 'lodelmomentoloj', 'CCPD_DURAN',
#        'RadioPuntoRojo', 'radioquitoec', 'revistamariela',
#        'forbesecuador', 'indymedia_ec', 'elnorteadiario',
#        'SalaDePrensaEc', 'RonaldVinces5', 'ECUADORCHEQUEA',
#        'el_telegrafo', 'EcuadorTV', 'News_Ecuador', 'radiolacalle',
#        'MACAesPAIS', 'reportecuador', 'AsoGuayas', 'RTSEcuador',
#        'RadioPlayInter', 'teleramaec', 'Informados_Ec', 'Balompiecuador',
#        'RadioAmbato1', '680radioatalaya', 'RadioDistritoFM',
#        'SegmentoFutbol', 'antenaunofm', 'FMRadioFuego', 'PublicaFM',
#        'goberazuay', 'LosilustresLp', 'ElNotista_ec', 'CiudadanoAzul',
#        'radiohcjb', 'CN_Igualdad', 'CNIMHec', 'desdemivision',
#        'zaracaytv', 'Diario_Super', 'PrensaDelBanano', 'RadioGitanaEC',
#        'politikcorrecta', 'GADMPedernales', 'SomosYachayTech',
#        'ONUecuador', 'pichinchauniver'], dtype=object)

# %%
resultado = pd.DataFrame({"Author":[],
                         "Twitter Followers":[]})
for i in range(len(nombres)):
    basesita = df[df['Author'] == nombres[i]]
    followers = basesita['Twitter Followers'].max()
    localdf = pd.DataFrame({"Author":[nombres[i]],
                         "Twitter Followers":[followers]})
    resultado = resultado.append(localdf)

resultado.reset_index(inplace=True) 
resultado.drop(columns = 'index', inplace = True)
resultado.head()
# Out:
#         Author  Twitter Followers
# 0  MoviLIDERec              971.0
# 1      ecuabot             8164.0
# 2    paoleague             2680.0
# 3    GKecuador            38917.0
# 4    Expresoec           893167.0

# %%
resultado
resultado.to_excel("Followers_Medios_Ecuador.xlsx")

# %%
resultado[resultado['Twitter Followers'] > 100000]
# Out:
#               Author  Twitter Followers
# 4          Expresoec           893167.0
# 6     larepublica_ec           145828.0
# 7    DialoguemosINFO           196274.0
# 11       LaPosta_Ecu           265157.0
# 13    teleamazonasec          2383860.0
# 15          CanalRTU           210450.0
# 18   EcuavisaInforma          1648866.0
# 20    revistavistazo           551047.0
# 21     eluniversocom          2455819.0
# 30     DiarioExtraEc           239728.0
# 34      tctelevision          1515108.0
# 40      elmercurioec           233543.0
# 42   ecuadoraldia365           914982.0
# 50     ecuadorenvivo           285715.0
# 56      lahistoriaec           150612.0
# 57         tomebamba           254614.0
# 61        marcadorec           392011.0
# 62     lahoraecuador           657457.0
# 72         Primicias          1034908.0
# 90     Gamavisionecu           648743.0
# 93     elcomerciocom          1995927.0
# 95   ecuainm_oficial           459219.0
# 113     el_telegrafo           614511.0
# 114        EcuadorTV           577729.0
# 120       RTSEcuador           776956.0
# 122       teleramaec           171395.0
# 131        PublicaFM           205185.0
# 133    LosilustresLp           119534.0

# %%
len(resultado[resultado['Twitter Followers'] > 100000])
# Out:
# 28

# %%
base_grafica = resultado[resultado['Twitter Followers'] > 100000]
ax = sns.barplot(x="Author", y="Twitter Followers", data=base_grafica, palette='Blues_d', order = base_grafica.sort_values('Twitter Followers', ascending=False).Author)
for item in ax.get_xticklabels():
    item.set_rotation(90)
