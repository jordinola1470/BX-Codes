# %%
import pandas as pd
import numpy as np
import seaborn as sns
from jupyterthemes import jtplot
jtplot.style(theme='grade3', context='notebook', ticks=True, grid=False)

# %%
sites_general = pd.read_excel('sitios_general_ecuador.xlsx')
sites_integracion = pd.read_excel('sitios_integracion_ecuador.xlsx')
authors_general = pd.read_excel('autores_general_ecuador.xlsx')
authors_integracion = pd.read_excel('autores_integracion_ecuador.xlsx')

# %%
base_sitios = pd.merge(sites_general,sites_integracion, left_on='Author', right_on='Author', how = 'left')
base_cuentas = pd.merge(authors_general,authors_integracion, left_on='Author', right_on='Author', how = 'left')

# %%
base_pegada = base_cuentas.append(base_sitios)
base_pegada['Integración'] = base_pegada['Integración'].fillna(0)
base_pegada.head(7)
# Out:
#             Author  Volumen  Integración
# 0    diarioextraec       11          0.0
# 1     acnurecuador        8          1.0
# 2        expresoec        8          0.0
# 3        gkecuador        6          0.0
# 4  pichinchauniver        4          0.0
# 5   teleamazonasec        4          0.0
# 6           ccpidg        3          1.0

# %%
base_pegada['% Integración'] = round(base_pegada['Integración']/base_pegada['Volumen']*100,2)
base_pegada.head(7)
# Out:
#             Author  Volumen  Integración  % Integración
# 0    diarioextraec       11          0.0           0.00
# 1     acnurecuador        8          1.0          12.50
# 2        expresoec        8          0.0           0.00
# 3        gkecuador        6          0.0           0.00
# 4  pichinchauniver        4          0.0           0.00
# 5   teleamazonasec        4          0.0           0.00
# 6           ccpidg        3          1.0          33.33

# %%
base_grafica = base_pegada[base_pegada['% Integración'] > 0.0]
ax = sns.barplot(x="Author", y="% Integración", data=base_grafica, palette='BuGn')
for item in ax.get_xticklabels():
    item.set_rotation(90)

# %%
base_pegada.to_excel('Base_medios_sitios_integracion.xlsx')

# %%
base_grafica = base_grafica.sort_values('Integración', ascending=False)
base_grafica
# Out:
#                       Author  Volumen  Integración  % Integración
# 3          elmercurio.com.ec       17          6.0          35.29
# 0                   extra.ec       35          5.0          14.29
# 1                    gk.city       32          5.0          15.62
# 7              lahora.com.ec       14          4.0          28.57
# 9               primicias.ec        7          4.0          57.14
# 11             zaracaytv.com        7          3.0          42.86
# 4           teleamazonas.com       16          3.0          18.75
# 10               vistazo.com        7          3.0          42.86
# 6          ecuadorenvivo.com       14          2.0          14.29
# 5                 expreso.ec       15          2.0          13.33
# 17  elvanguardistaonline.com        3          1.0          33.33
# 16      ecuadorendirecto.com        4          1.0          25.00
# 15                elnorte.ec        5          1.0          20.00
# 14            elcomercio.com        5          1.0          20.00
# 1               acnurecuador        8          1.0          12.50
# 6                     ccpidg        3          1.0          33.33
# 11           dialoguemosinfo        1          1.0         100.00
# 10                  canalrtu        1          1.0         100.00
# 9                 onuecuador        2          1.0          50.00
# 21            cronica.com.ec        1          1.0         100.00

# %%
base_grafica = base_grafica.sort_values('% Integración', ascending=True)
base_grafica
# Out:
#                       Author  Volumen  Integración  % Integración
# 1               acnurecuador        8          1.0          12.50
# 5                 expreso.ec       15          2.0          13.33
# 0                   extra.ec       35          5.0          14.29
# 6          ecuadorenvivo.com       14          2.0          14.29
# 1                    gk.city       32          5.0          15.62
# 4           teleamazonas.com       16          3.0          18.75
# 14            elcomercio.com        5          1.0          20.00
# 15                elnorte.ec        5          1.0          20.00
# 16      ecuadorendirecto.com        4          1.0          25.00
# 7              lahora.com.ec       14          4.0          28.57
# 6                     ccpidg        3          1.0          33.33
# 17  elvanguardistaonline.com        3          1.0          33.33
# 3          elmercurio.com.ec       17          6.0          35.29
# 10               vistazo.com        7          3.0          42.86
# 11             zaracaytv.com        7          3.0          42.86
# 9                 onuecuador        2          1.0          50.00
# 9               primicias.ec        7          4.0          57.14
# 11           dialoguemosinfo        1          1.0         100.00
# 10                  canalrtu        1          1.0         100.00
# 21            cronica.com.ec        1          1.0         100.00

# %%
base_grafica = base_pegada[base_pegada['% Integración'] > 28.57]
ax = sns.barplot(x="Author", y="% Integración", data=base_grafica, palette='Greens', order = base_grafica.sort_values('% Integración', ascending=False).Author)
for item in ax.get_xticklabels():
    item.set_rotation(90)
