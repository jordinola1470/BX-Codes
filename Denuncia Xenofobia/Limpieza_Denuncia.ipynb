# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
'''
Created on Wed Jan 20 20:58:09 2021
 
@author: diegoalejandrobermudezsierra josefernandobarreradeplaza
'''
'''Vamos a verificar que usted tenga su espacio de trabajo actualizado, omitir si se siente confiado al respecto'''
import pandas as pd
import re
import string
import numpy as np
import sys
sys.path.append('../')
import funciones as fn

#Estos comandos se usan en caso de crar nuevas funciones y estas no se esten importando correctamente
#dir(fn)
#import importlib
#importlib.reload(mod)

# %% [markdown]
# # Limpieza de Base de Menciones de Xenofobia
# Este notebook explicado sirve como guía para la limpieza de un archivo ```.xlsx``` extraído de Brandwatch que captura la conversación de migrantes venezolanos para un periodo determinado. En la primera versión del documento se usa el Piloto Barómetro 2021

# %%
# Definimos la ubicación del archivo
path = input('Escriba la ruta del archivo - ')
#Importamos la base de datos que descargamos con los tweets de brandwatch 
xenofobia=pd.read_excel(path)
del path
#path='/Users/diegoalejandrobermudezsierra/Downloads/Barometro_Migrante_Colombia.xlsx'
xenofobia.head(11)
# Out:
# Escriba la ruta del archivo - /Users/diegoalejandrobermudezsierra/Downloads/Barometro_Migrante_Colombia.xlsx
#        Report:                         Bulk Mentions Download  \
# 0       Brand:               [Q [ Barometro Migrante Colombia
# 1        From:                   Wed Sep 30 00:00:00 UTC 2020
# 2          To:                   Tue Feb 02 00:00:00 UTC 2021
# 3       Label:  Q Barómetro Migrante Sep 30 2020 - Feb 1 2021
# 4          NaN                                            NaN
# 5     Query Id                                     Query Name
# 6   2000132802               [Q [ Barometro Migrante Colombia
# 7   2000132802               [Q [ Barometro Migrante Colombia
# 8   2000132802               [Q [ Barometro Migrante Colombia
# 9   2000132802               [Q [ Barometro Migrante Colombia
# 10  2000132802               [Q [ Barometro Migrante Colombia
#
#                Unnamed: 2                                         Unnamed: 3  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2                     NaN                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# 5                    Date                                              Title
# 6   2021-02-01 18:24:51.0  #1Feb 🇻🇪🇺🇸 Luego que Joe Biden asumiera la pre...
# 7   2021-02-01 18:23:56.0  @NDtitulares Que así sea... Los venezolanos, y...
# 8   2021-02-01 18:23:46.0  RT @ernestosamperp Las revelaciones conocidas ...
# 9   2021-02-01 18:22:16.0  RT @ernestosamperp Las revelaciones conocidas ...
# 10  2021-02-01 18:21:34.0  Esta también es tu casa • Comunidades de acogi...
#
#                                            Unnamed: 4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                             Snippet
# 6   #1Feb 🇻🇪🇺🇸 Luego que Joe Biden asumiera la pre...
# 7   @NDtitulares Que así sea... Los venezolanos, y...
# 8   RT @ernestosamperp Las revelaciones conocidas ...
# 9   RT @ernestosamperp Las revelaciones conocidas ...
# 10  Esta también es tu casa • Comunidades de acogi...
#
#                                            Unnamed: 5   Unnamed: 6 Unnamed: 7  \
# 0                                                 NaN          NaN        NaN
# 1                                                 NaN          NaN        NaN
# 2                                                 NaN          NaN        NaN
# 3                                                 NaN          NaN        NaN
# 4                                                 NaN          NaN        NaN
# 5                                                 Url       Domain  Sentiment
# 6   http://twitter.com/fronteravivanew/statuses/13...  twitter.com    neutral
# 7   http://twitter.com/HAROLDVACCA/statuses/135630...  twitter.com   negative
# 8   http://twitter.com/gabocano78/statuses/1356307...  twitter.com    neutral
# 9   http://twitter.com/yotagri1895/statuses/135630...  twitter.com    neutral
# 10  http://twitter.com/ficonpaz/statuses/135630671...  twitter.com    neutral
#
#    Unnamed: 8 Unnamed: 9  ...    Unnamed: 104 Unnamed: 105  \
# 0         NaN        NaN  ...             NaN          NaN
# 1         NaN        NaN  ...             NaN          NaN
# 2         NaN        NaN  ...             NaN          NaN
# 3         NaN        NaN  ...             NaN          NaN
# 4         NaN        NaN  ...             NaN          NaN
# 5   Page Type   Language  ...  Parent Post Id     Pub Type
# 6     twitter         es  ...             NaN   Twitstream
# 7     twitter         es  ...             NaN   Twitstream
# 8     twitter         es  ...             NaN   Twitstream
# 9     twitter         es  ...             NaN   Twitstream
# 10    twitter         es  ...             NaN   Twitstream
#
#           Unnamed: 106 Unnamed: 107  Unnamed: 108 Unnamed: 109   Unnamed: 110  \
# 0                  NaN          NaN           NaN          NaN            NaN
# 1                  NaN          NaN           NaN          NaN            NaN
# 2                  NaN          NaN           NaN          NaN            NaN
# 3                  NaN          NaN           NaN          NaN            NaN
# 4                  NaN          NaN           NaN          NaN            NaN
# 5   Publisher Sub Type       Rating  Reddit Score       Region    Region Code
# 6                  NaN          NaN             0       Bogota     COL.Bogota
# 7                  NaN          NaN             0       Bogota     COL.Bogota
# 8                  NaN          NaN             0    Antioquia  COL.Antioquia
# 9                  NaN          NaN             0    Antioquia  COL.Antioquia
# 10                 NaN          NaN             0       Bogota     COL.Bogota
#
#       Unnamed: 111  Unnamed: 112                        Unnamed: 113
# 0              NaN           NaN                                 NaN
# 1              NaN           NaN                                 NaN
# 2              NaN           NaN                                 NaN
# 3              NaN           NaN                                 NaN
# 4              NaN           NaN                                 NaN
# 5   Root Blog Name  Root Post Id                        Weblog Title
# 6              NaN           NaN     fronteravivanew (Frontera Viva)
# 7              NaN           NaN  HAROLDVACCA (Harold Vacca Gonzále)
# 8              NaN           NaN   gabocano78 (Gabriel Jaime Cano H)
# 9              NaN           NaN       yotagri1895 (Mario Rodriguez)
# 10             NaN           NaN                 ficonpaz (FICONPAZ)
#
# [11 rows x 114 columns]

# %%
base=fn.limpieza_base(xenofobia)
base.head()
# Out:
# Escriba la fila donde se encuentran los nombres de las columnas - 5
#                          Query_Name                   Date  \
# 0  [Q [ Barometro Migrante Colombia  2021-02-01 18:24:51.0
# 1  [Q [ Barometro Migrante Colombia  2021-02-01 18:23:56.0
# 2  [Q [ Barometro Migrante Colombia  2021-02-01 18:23:46.0
# 3  [Q [ Barometro Migrante Colombia  2021-02-01 18:22:16.0
# 4  [Q [ Barometro Migrante Colombia  2021-02-01 18:21:34.0
#
#                                                Title  \
# 0  #1Feb 🇻🇪🇺🇸 Luego que Joe Biden asumiera la pre...
# 1  @NDtitulares Que así sea... Los venezolanos, y...
# 2  RT @ernestosamperp Las revelaciones conocidas ...
# 3  RT @ernestosamperp Las revelaciones conocidas ...
# 4  Esta también es tu casa • Comunidades de acogi...
#
#                                              Snippet  \
# 0  #1Feb 🇻🇪🇺🇸 Luego que Joe Biden asumiera la pre...
# 1  @NDtitulares Que así sea... Los venezolanos, y...
# 2  RT @ernestosamperp Las revelaciones conocidas ...
# 3  RT @ernestosamperp Las revelaciones conocidas ...
# 4  Esta también es tu casa • Comunidades de acogi...
#
#                                                  Url       Domain Sentiment  \
# 0  http://twitter.com/fronteravivanew/statuses/13...  twitter.com   neutral
# 1  http://twitter.com/HAROLDVACCA/statuses/135630...  twitter.com  negative
# 2  http://twitter.com/gabocano78/statuses/1356307...  twitter.com   neutral
# 3  http://twitter.com/yotagri1895/statuses/135630...  twitter.com   neutral
# 4  http://twitter.com/ficonpaz/statuses/135630671...  twitter.com   neutral
#
#   Page_Type Language Country_Code  ... Parent_Post_Id    Pub_Type  \
# 0   twitter       es          COL  ...            NaN  Twitstream
# 1   twitter       es          COL  ...            NaN  Twitstream
# 2   twitter       es          COL  ...            NaN  Twitstream
# 3   twitter       es          COL  ...            NaN  Twitstream
# 4   twitter       es          COL  ...            NaN  Twitstream
#
#   Publisher_Sub_Type Rating Reddit_Score     Region    Region_Code  \
# 0                NaN    NaN            0     Bogota     COL.Bogota
# 1                NaN    NaN            0     Bogota     COL.Bogota
# 2                NaN    NaN            0  Antioquia  COL.Antioquia
# 3                NaN    NaN            0  Antioquia  COL.Antioquia
# 4                NaN    NaN            0     Bogota     COL.Bogota
#
#   Root_Blog_Name Root_Post_Id                        Weblog_Title
# 0            NaN          NaN     fronteravivanew (Frontera Viva)
# 1            NaN          NaN  HAROLDVACCA (Harold Vacca Gonzále)
# 2            NaN          NaN   gabocano78 (Gabriel Jaime Cano H)
# 3            NaN          NaN       yotagri1895 (Mario Rodriguez)
# 4            NaN          NaN                 ficonpaz (FICONPAZ)
#
# [5 rows x 113 columns]

# %%
del_cols=["Query_Name", "Url", "Page_Type", "Language", "Country_Code", "Continent", "Continent_Code", 
          "Country", "Added", "Assignment", "Avatar", "Category_Details", 
          "Checked", "Display_URLs", "Expanded_URLs", "Facebook_Author_ID", "Facebook_Comments",
          "Facebook_Likes", "Facebook_Role", "Facebook_Shares", "Facebook_Subtype",
          "Full_Text", "Full_Name", "Instagram_Comments", "Instagram_Followers", "Instagram_Following",
          "Instagram_Likes", "Instagram_Interactions_Count", "Instagram_Posts",
          "Last_Assignment_Date", "Latitude", "Location_Name", "Longitude", "Media_Filter",
          "Media_URLs", "Original_Url", "Priority", "Short_URLs", "Resource_Id", "Starred",
          "Status", "Subtype", "Tags", "Thread_Created_Date", "Thread_Id",
          "Thread_URL", "Twitter_Author_ID", "Twitter_Channel_Role", "Twitter_Reply_to", "Twitter_Retweet_of", 
          "Updated", "Blog_Name", "Copyright", "Item_Review", "Page_Type_Name", "Linkedin_Comments", 
          "Linkedin_Engagement", "Linkedin_Impressions", "Linkedin_Likes", "Linkedin_Shares", "Linkedin_Sponsored", 
          "Linkedin_Video_Views", "Parent_Blog_Name", "Parent_Post_Id", "Pub_Type", "Publisher_Sub_Type", "Rating", 
          "Reddit_Score", "Region", "Region_Code", "Root_Blog_Name", "Root_Post_Id", "Weblog_Title"]
base = base.drop(del_cols, axis=1)

# %%
#Eliminamos todos los @Usuario (i.e. @ClaudiaLopez)
base['Clean_Text']=base['Snippet'].replace('@\\w+', '', regex=True)
#Eliminamos todos los hashtags
base['Clean_Text']=base['Clean_Text'].replace('#\\w+', '', regex=True)
#Eliminamos los URL: Todo lo que empieza por 
base['Clean_Text']=base['Clean_Text'].replace(r"http\S+", '', regex=True)
#Eliminamos todos los signos de puntuación
base['Clean_Text']=base['Clean_Text'].replace(r'[^\w\s]+', '', regex=True)
#Eliminamos los asentos de las letras
base['Clean_Text']=base['Clean_Text'].str.normalize('NFKD')\
        .str.encode('ascii', errors='ignore')\
        .str.decode('utf-8')
#Eliminamos los dobles espacios
base['Clean_Text']=base['Clean_Text'].replace('\s+', ' ', regex=True).str.strip()
#Eliminamos las filas que sean RT
base=base[~base.Snippet.str.startswith('RT')].reset_index(drop=True)
#Eliminamos las letras repetivas dentro de las palabras
base['Clean_Text']=base['Clean_Text'].replace(r'(.)\1+', r'\1\1', regex=True)



base.head()
# Out:
#                     Date                                              Title  \
# 0  2021-02-01 18:24:51.0  #1Feb 🇻🇪🇺🇸 Luego que Joe Biden asumiera la pre...
# 1  2021-02-01 18:23:56.0  @NDtitulares Que así sea... Los venezolanos, y...
# 2  2021-02-01 18:21:34.0  Esta también es tu casa • Comunidades de acogi...
# 3  2021-02-01 18:21:33.0  En enero de 2021, entregamos a 34 niños, niñas...
# 4  2021-02-01 18:20:52.0  @LuisferTatuco @VickyDavilaH Si la meta es ser...
#
#                                              Snippet       Domain Sentiment  \
# 0  #1Feb 🇻🇪🇺🇸 Luego que Joe Biden asumiera la pre...  twitter.com   neutral
# 1  @NDtitulares Que así sea... Los venezolanos, y...  twitter.com  negative
# 2  Esta también es tu casa • Comunidades de acogi...  twitter.com   neutral
# 3  En enero de 2021, entregamos a 34 niños, niñas...  twitter.com   neutral
# 4  @LuisferTatuco @VickyDavilaH Si la meta es ser...  twitter.com  negative
#
#                 City_Code Account_Type           Author      City   Gender  \
# 0       COL.Bogota.Bogota   individual  fronteravivanew    Bogota  unknown
# 1       COL.Bogota.Bogota   individual      HAROLDVACCA    Bogota     male
# 2       COL.Bogota.Bogota   individual         ficonpaz    Bogota  unknown
# 3       COL.Bogota.Bogota   individual         ficonpaz    Bogota  unknown
# 4  COL.Antioquia.Medellin   individual     pabloinspace  Medellin     male
#
#    ... Medios_Colombianos_por_Ciudad_-_Medios_Cucuta  \
# 0  ...                                           NaN
# 1  ...                                           NaN
# 2  ...                                           NaN
# 3  ...                                           NaN
# 4  ...                                           NaN
#
#   Medios_Colombianos_por_Ciudad_-_Medios_Medellin  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Medios_Colombianos_por_Ciudad_-_Medios_Nacionales  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Medios_Policia_Captura_-_Capturas_a_Venezolanos  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Medios_Policia_Captura_-_Todas_las_capturas  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Medios_de_Comunicación_-_Alternativos_General  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Medios_de_Comunicación_-_Alternativos_Venezolanos  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Medios_de_Comunicación_-_Tradicionales_General  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Medios_de_Comunicación_-_Tradicionales_Venezolanos  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Clean_Text
# 0  Luego que Joe Biden asumiera la presidencia de...
# 1  Que asi sea Los venezolanos y solo ellos son l...
# 2  Esta tambien es tu casa Comunidades de acogida...
# 3  En enero de 2021 entregamos a 34 ninos ninas y...
# 4  Si la meta es ser como Fox News pues van por e...
#
# [5 rows x 41 columns]

# %%
len(base.loc[(base['Categorías_prueba_-_Denuncia']=='X') & (base['Categorías_prueba_-_Xenofobia']=='X')])
# Out:
# 11462
