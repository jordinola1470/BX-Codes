# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
'''
Created on Wed Jan 20 20:58:09 2021
 
@author: diegoalejandrobermudezsierra josefernandobarreradeplaza
'''
'''Vamos a verificar que usted tenga su espacio de trabajo actualizado, omitir si se siente confiado al respecto'''
import pandas as pd
import re
import string
import numpy as np
import sys
sys.path.append('../')
import funciones as fn

#Estos comandos se usan en caso de crar nuevas funciones y estas no se esten importando correctamente
#dir(fn)
#import importlib
#importlib.reload(mod)

# %% [markdown]
# # Limpieza de Base de Menciones de Xenofobia
# Este notebook explicado sirve como guía para la limpieza de un archivo ```.xlsx``` extraído de Brandwatch que captura la conversación de migrantes venezolanos para un periodo determinado. En la primera versión del documento se usa el Piloto Barómetro 2021

# %%
# Definimos la ubicación del archivo
path = input('Escriba la ruta del archivo - ')
#Importamos la base de datos que descargamos con los tweets de brandwatch 
xenofobia=pd.read_excel(path)
del path
#path='/Users/diegoalejandrobermudezsierra/Downloads/Barometro_Migrante_Colombia.xlsx'
xenofobia.head(11)
# Out:
# Escriba la ruta del archivo - E:\Base bonita\Q_BX_Feb_2020_Feb_16_2021.xlsx
# C:\Users\JOSE\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#        Report:           Bulk Mentions Download             Unnamed: 2  \
# 0       Brand:  [Q] Barómetro migrante Colombia                    NaN
# 1        From:     Sat Feb 01 00:00:00 UTC 2020                    NaN
# 2          To:     Wed Feb 17 00:00:00 UTC 2021                    NaN
# 3       Label:                              NaN                    NaN
# 4          NaN                              NaN                    NaN
# 5     Query Id                       Query Name                   Date
# 6   2000474926  [Q] Barómetro migrante Colombia  2021-02-16 23:59:44.0
# 7   2000474926  [Q] Barómetro migrante Colombia  2021-02-16 23:59:00.0
# 8   2000474926  [Q] Barómetro migrante Colombia  2021-02-16 23:59:00.0
# 9   2000474926  [Q] Barómetro migrante Colombia  2021-02-16 23:55:27.0
# 10  2000474926  [Q] Barómetro migrante Colombia  2021-02-16 23:52:51.0
#
#                                            Unnamed: 3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Title
# 6   RT @MartnDeFrancis2 @DeLaRoche01 @jaiencascom ...
# 7                  Modelos del Santa Fe - Página 1130
# 8                  Modelos del Santa Fe - Página 1130
# 9   RT @VickyDavilaH ¡Insólito! Mujer llamó hasta ...
# 10  RT @SaidVergelA Venezolan@s creyendo en los en...
#
#                                            Unnamed: 4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                             Snippet
# 6   RT @MartnDeFrancis2 @DeLaRoche01 @jaiencascom ...
# 7   Cita: Iniciado por El_Bunk Alguien a visto a e...
# 8   Cita: Iniciado por El_Bunk Alguien a visto a e...
# 9   RT @VickyDavilaH ¡Insólito! Mujer llamó hasta ...
# 10  RT @SaidVergelA Venezolan@s creyendo en los en...
#
#                                            Unnamed: 5       Unnamed: 6  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
# 5                                                 Url           Domain
# 6   http://twitter.com/jaiencascom/statuses/136182...      twitter.com
# 7   https://www.denunciando.com/sexual-turismo-249...  denunciando.com
# 8   https://www.denunciando.com/sexual-turismo-249...  denunciando.com
# 9   http://twitter.com/20Wilsongarcia/statuses/136...      twitter.com
# 10  http://twitter.com/alexanderelflac/statuses/13...      twitter.com
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ...     Unnamed: 89 Unnamed: 90  \
# 0         NaN        NaN        NaN  ...             NaN         NaN
# 1         NaN        NaN        NaN  ...             NaN         NaN
# 2         NaN        NaN        NaN  ...             NaN         NaN
# 3         NaN        NaN        NaN  ...             NaN         NaN
# 4         NaN        NaN        NaN  ...             NaN         NaN
# 5   Sentiment  Page Type   Language  ...  Parent Post Id    Pub Type
# 6    negative    twitter         es  ...             NaN  Twitstream
# 7     neutral      forum         es  ...             NaN      FORUMS
# 8     neutral      forum         es  ...             NaN       TOPIC
# 9     neutral    twitter         es  ...             NaN  Twitstream
# 10    neutral    twitter         es  ...             NaN  Twitstream
#
#            Unnamed: 91 Unnamed: 92   Unnamed: 93 Unnamed: 94     Unnamed: 95  \
# 0                  NaN         NaN           NaN         NaN             NaN
# 1                  NaN         NaN           NaN         NaN             NaN
# 2                  NaN         NaN           NaN         NaN             NaN
# 3                  NaN         NaN           NaN         NaN             NaN
# 4                  NaN         NaN           NaN         NaN             NaN
# 5   Publisher Sub Type      Rating  Reddit Score      Region     Region Code
# 6                  NaN         NaN             0      Bogota      COL.Bogota
# 7                  NaN         NaN             0         NaN             NaN
# 8                  NaN         NaN             0         NaN             NaN
# 9                  NaN         NaN             0  La Guajira  COL.La Guajira
# 10                 NaN         NaN             0      Bogota      COL.Bogota
#
#        Unnamed: 96   Unnamed: 97                           Unnamed: 98
# 0              NaN           NaN                                   NaN
# 1              NaN           NaN                                   NaN
# 2              NaN           NaN                                   NaN
# 3              NaN           NaN                                   NaN
# 4              NaN           NaN                                   NaN
# 5   Root Blog Name  Root Post Id                          Weblog Title
# 6              NaN           NaN    jaiencascom (Jairo Enrique Castro)
# 7              NaN           NaN                     Ayudante De Santa
# 8              NaN           NaN                            panchito69
# 9              NaN           NaN  20Wilsongarcia (wilson garcia navas)
# 10             NaN           NaN          alexanderelflac (JRODRIGUEZ)
#
# [11 rows x 99 columns]

# %%
xenofobia
# Out:
#            Report:           Bulk Mentions Download             Unnamed: 2  \
# 0           Brand:  [Q] Barómetro migrante Colombia                    NaN
# 1            From:     Sat Feb 01 00:00:00 UTC 2020                    NaN
# 2              To:     Wed Feb 17 00:00:00 UTC 2021                    NaN
# 3           Label:                              NaN                    NaN
# 4              NaN                              NaN                    NaN
# ...            ...                              ...                    ...
# 500533  2000474926  [Q] Barómetro migrante Colombia  2020-05-18 02:39:39.0
# 500534  2000474926  [Q] Barómetro migrante Colombia  2020-05-18 02:39:03.0
# 500535  2000474926  [Q] Barómetro migrante Colombia  2020-05-18 02:38:58.0
# 500536  2000474926  [Q] Barómetro migrante Colombia  2020-05-18 02:38:27.0
# 500537  2000474926  [Q] Barómetro migrante Colombia  2020-05-18 02:37:56.0
#
#                                                Unnamed: 3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 500533  RT @Betocoralg Señores @almacenesexito ¿dieron...
# 500534  @JulioMontoya @herreravaillant @jguaido @SOYJU...
# 500535  @CifuentesArte @intiasprilla Hablan de todo pe...
# 500536  RT @camiloarangoCR La gente del Vichada se pre...
# 500537  @sierrinni @paula_amc Las hamburguesas que vie...
#
#                                                Unnamed: 4  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 500533  RT @Betocoralg Señores @almacenesexito ¿dieron...
# 500534  @JulioMontoya @herreravaillant @jguaido @SOYJU...
# 500535  @CifuentesArte @intiasprilla Hablan de todo pe...
# 500536  RT @camiloarangoCR La gente del Vichada se pre...
# 500537  @sierrinni @paula_amc Las hamburguesas que vie...
#
#                                                Unnamed: 5   Unnamed: 6  \
# 0                                                     NaN          NaN
# 1                                                     NaN          NaN
# 2                                                     NaN          NaN
# 3                                                     NaN          NaN
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 500533  http://twitter.com/YeisonD22/statuses/12622112...  twitter.com
# 500534  http://twitter.com/villafaejaime/statuses/1262...  twitter.com
# 500535  http://twitter.com/newball_sonny/statuses/1262...  twitter.com
# 500536  http://twitter.com/Elimilsan/statuses/12622109...  twitter.com
# 500537  http://twitter.com/rankmark/statuses/126221078...  twitter.com
#
#        Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 89 Unnamed: 90  \
# 0             NaN        NaN        NaN  ...         NaN         NaN
# 1             NaN        NaN        NaN  ...         NaN         NaN
# 2             NaN        NaN        NaN  ...         NaN         NaN
# 3             NaN        NaN        NaN  ...         NaN         NaN
# 4             NaN        NaN        NaN  ...         NaN         NaN
# ...           ...        ...        ...  ...         ...         ...
# 500533    neutral    twitter         es  ...         NaN  Twitstream
# 500534    neutral    twitter         es  ...         NaN  Twitstream
# 500535   negative    twitter         es  ...         NaN  Twitstream
# 500536    neutral    twitter         es  ...         NaN  Twitstream
# 500537    neutral    twitter         es  ...         NaN  Twitstream
#
#        Unnamed: 91 Unnamed: 92 Unnamed: 93 Unnamed: 94    Unnamed: 95  \
# 0              NaN         NaN         NaN         NaN            NaN
# 1              NaN         NaN         NaN         NaN            NaN
# 2              NaN         NaN         NaN         NaN            NaN
# 3              NaN         NaN         NaN         NaN            NaN
# 4              NaN         NaN         NaN         NaN            NaN
# ...            ...         ...         ...         ...            ...
# 500533         NaN         NaN           0   Antioquia  COL.Antioquia
# 500534         NaN         NaN           0      Bogota     COL.Bogota
# 500535         NaN         NaN           0      Bogota     COL.Bogota
# 500536         NaN         NaN           0      Bogota     COL.Bogota
# 500537         NaN         NaN           0      Bogota     COL.Bogota
#
#        Unnamed: 96 Unnamed: 97                            Unnamed: 98
# 0              NaN         NaN                                    NaN
# 1              NaN         NaN                                    NaN
# 2              NaN         NaN                                    NaN
# 3              NaN         NaN                                    NaN
# 4              NaN         NaN                                    NaN
# ...            ...         ...                                    ...
# 500533         NaN         NaN                  YeisonD22 (Yeison 🇨🇴)
# 500534         NaN         NaN     villafaejaime (Jaime Villafañe e.)
# 500535         NaN         NaN  newball_sonny (Sonny Raymond Newball)
# 500536         NaN         NaN            Elimilsan (Eliana Sandoval)
# 500537         NaN         NaN                rankmark (Franck David)
#
# [500538 rows x 99 columns]

# %%
base=fn.limpieza_base(xenofobia)
base.head()
print("Tamaño de la base: " + str(base.shape))
# Out:
# Escriba la fila donde se encuentran los nombres de las columnas - 5
# Tamaño de la base: (500532, 98)

# %%
del_cols=["Query_Name", "Url", "Page_Type", "Language", "Country_Code", "Continent", "Continent_Code", 
          "Country", "Added", "Assignment", "Avatar", "Category_Details", 
          "Checked", "Display_URLs", "Expanded_URLs", "Facebook_Author_ID", "Facebook_Comments",
          "Facebook_Likes", "Facebook_Role", "Facebook_Shares", "Facebook_Subtype",
          "Full_Text", "Full_Name", "Instagram_Comments", "Instagram_Followers", "Instagram_Following",
          "Instagram_Likes", "Instagram_Interactions_Count", "Instagram_Posts",
          "Last_Assignment_Date", "Latitude", "Location_Name", "Longitude", "Media_Filter",
          "Media_URLs", "Original_Url", "Priority", "Short_URLs", "Resource_Id", "Starred",
          "Status", "Subtype", "Thread_Created_Date", "Thread_Id",
          "Thread_URL", "Twitter_Author_ID", "Twitter_Channel_Role", "Twitter_Reply_to", "Twitter_Retweet_of", 
          "Updated", "Blog_Name", "Copyright", "Item_Review", "Page_Type_Name", "Linkedin_Comments", 
          "Linkedin_Engagement", "Linkedin_Impressions", "Linkedin_Likes", "Linkedin_Shares", "Linkedin_Sponsored", 
          "Linkedin_Video_Views", "Parent_Blog_Name", "Parent_Post_Id", "Pub_Type", "Publisher_Sub_Type", "Rating", 
          "Reddit_Score", "Region", "Region_Code", "Root_Blog_Name", "Root_Post_Id", "Weblog_Title", "Title"]
try:
    base = base.drop(del_cols, axis=1)
except: print("Alguna columna a borrar no se encuentra en la base")
# "Tags" se sacaron de la eliminación
for col in base.columns: 
    print(col)
# Out:
# Date
# Snippet
# Domain
# Sentiment
# City_Code
# Account_Type
# Author
# City
# Gender
# Hashtags
# Impact
# Impressions
# Interest
# Mentioned_Authors
# Professions
# Thread_Author
# Thread_Entry_Type
# Total_Monthly_Visitors
# Twitter_Followers
# Twitter_Following
# Twitter_Reply_Count
# Twitter_Retweets
# Twitter_Tweets
# Twitter_Verified
# Reach_(new)

# %%
#Eliminamos todos los @Usuario (i.e. @ClaudiaLopez)
base['Clean_Text']=base['Snippet'].replace('@\\w+', '', regex=True)
#Eliminamos todos los hashtags
base['Clean_Text']=base['Clean_Text'].replace('#\\w+', '', regex=True)
#Eliminamos los URL: Todo lo que empieza por 
base['Clean_Text']=base['Clean_Text'].replace(r"http\S+", '', regex=True)
#Eliminamos todos los signos de puntuación
base['Clean_Text']=base['Clean_Text'].replace(r'[^\w\s]+', '', regex=True)
#Eliminamos los asentos de las letras
base['Clean_Text']=base['Clean_Text'].str.normalize('NFKD')\
        .str.encode('ascii', errors='ignore')\
        .str.decode('utf-8')
#Eliminamos los dobles espacios
base['Clean_Text']=base['Clean_Text'].replace('\s+', ' ', regex=True).str.strip()
#Eliminamos las filas que sean RT (agregar , na=False si hay NaNs)
base=base[~base.Snippet.str.startswith('RT')].reset_index(drop=True)
#Eliminamos las letras repetivas dentro de las palabras
base['Clean_Text']=base['Clean_Text'].replace(r'(.)\1+', r'\1\1', regex=True)

base.head()
# Out:
#                     Date                                            Snippet  \
# 0  2021-02-16 23:59:00.0  Cita: Iniciado por El_Bunk Alguien a visto a e...
# 1  2021-02-16 23:59:00.0  Cita: Iniciado por El_Bunk Alguien a visto a e...
# 2  2021-02-16 23:49:42.0  No se sabe si es verdad.. pero y que en Cali a...
# 3  2021-02-16 23:49:03.0  Marica que piensan esos venezolanos del video ...
# 4  2021-02-16 23:48:36.0  ...para la obtención del registro civil. Ademá...
#
#              Domain Sentiment               City_Code Account_Type  \
# 0   denunciando.com   neutral                     NaN          NaN
# 1   denunciando.com   neutral                     NaN          NaN
# 2       twitter.com  negative       COL.Bogota.Bogota   individual
# 3       twitter.com  negative  COL.Antioquia.Medellin   individual
# 4  laopinion.com.co  negative                     NaN          NaN
#
#               Author      City   Gender Hashtags  ... Thread_Entry_Type  \
# 0  ayudante de santa       NaN  unknown      NaN  ...              post
# 1         panchito69       NaN  unknown      NaN  ...              post
# 2           elcalvok    Bogota  unknown      NaN  ...              post
# 3       EiderHenaodj  Medellin  unknown      NaN  ...              post
# 4       Magaly Rubio       NaN   female      NaN  ...              post
#
#   Total_Monthly_Visitors Twitter_Followers Twitter_Following  \
# 0                 225000                 0                 0
# 1                 225000                 0                 0
# 2             6000000000              3164              2344
# 3             6000000000             28706               173
# 4                 366000                 0                 0
#
#   Twitter_Reply_Count Twitter_Retweets Twitter_Tweets Twitter_Verified  \
# 0                   0                0              0            false
# 1                   0                0              0            false
# 2                   0                0         133900            false
# 3                   3                2          53035            false
# 4                   0                0              0            false
#
#   Reach_(new)                                         Clean_Text
# 0         134  Cita Iniciado por El_Bunk Alguien a visto a es...
# 1         134  Cita Iniciado por El_Bunk Alguien a visto a es...
# 2        2036  No se sabe si es verdad pero y que en Cali aga...
# 3       15215  Marica que piensan esos venezolanos del video ...
# 4         214  para la obtencion del registro civil Ademas de...
#
# [5 rows x 26 columns]

# %%
#len(base.loc[(base['Categorías_prueba_-_Denuncia']=='X') & (base['Categorías_prueba_-_Xenofobia']=='X')])

# %% [markdown]
# # Merge de bases
# Se corre un ejemplo pequeño como prueba

# %%
print("Tamaño de la base: " + str(base.shape))
# Out:
# Tamaño de la base: (195780, 26)

# %%
base
# Out:
#                          Date  \
# 0       2021-02-16 23:59:00.0
# 1       2021-02-16 23:59:00.0
# 2       2021-02-16 23:49:42.0
# 3       2021-02-16 23:49:03.0
# 4       2021-02-16 23:48:36.0
# ...                       ...
# 195775  2020-05-18 02:46:24.0
# 195776  2020-05-18 02:43:00.0
# 195777  2020-05-18 02:39:03.0
# 195778  2020-05-18 02:38:58.0
# 195779  2020-05-18 02:37:56.0
#
#                                                   Snippet            Domain  \
# 0       Cita: Iniciado por El_Bunk Alguien a visto a e...   denunciando.com
# 1       Cita: Iniciado por El_Bunk Alguien a visto a e...   denunciando.com
# 2       No se sabe si es verdad.. pero y que en Cali a...       twitter.com
# 3       Marica que piensan esos venezolanos del video ...       twitter.com
# 4       ...para la obtención del registro civil. Ademá...  laopinion.com.co
# ...                                                   ...               ...
# 195775  ...Según una encuesta realizada por el Observa...     elpais.com.co
# 195776  Seguimos abriendo corredores humanitarios para...       twitter.com
# 195777  @JulioMontoya @herreravaillant @jguaido @SOYJU...       twitter.com
# 195778  @CifuentesArte @intiasprilla Hablan de todo pe...       twitter.com
# 195779  @sierrinni @paula_amc Las hamburguesas que vie...       twitter.com
#
#        Sentiment               City_Code Account_Type             Author  \
# 0        neutral                     NaN          NaN  ayudante de santa
# 1        neutral                     NaN          NaN         panchito69
# 2       negative       COL.Bogota.Bogota   individual           elcalvok
# 3       negative  COL.Antioquia.Medellin   individual       EiderHenaodj
# 4       negative                     NaN          NaN       Magaly Rubio
# ...          ...                     ...          ...                ...
# 195775  negative                     NaN          NaN                NaN
# 195776  positive       COL.Bogota.Bogota   individual       transitometa
# 195777   neutral       COL.Bogota.Bogota   individual      villafaejaime
# 195778  negative       COL.Bogota.Bogota   individual      newball_sonny
# 195779   neutral       COL.Bogota.Bogota   individual           rankmark
#
#             City   Gender Hashtags  ... Thread_Entry_Type  \
# 0            NaN  unknown      NaN  ...              post
# 1            NaN  unknown      NaN  ...              post
# 2         Bogota  unknown      NaN  ...              post
# 3       Medellin  unknown      NaN  ...              post
# 4            NaN   female      NaN  ...              post
# ...          ...      ...      ...  ...               ...
# 195775       NaN  unknown      NaN  ...              post
# 195776    Bogota  unknown      NaN  ...              post
# 195777    Bogota     male      NaN  ...             reply
# 195778    Bogota     male      NaN  ...             reply
# 195779    Bogota     male      NaN  ...             reply
#
#        Total_Monthly_Visitors Twitter_Followers Twitter_Following  \
# 0                      225000                 0                 0
# 1                      225000                 0                 0
# 2                  6000000000              3164              2344
# 3                  6000000000             28706               173
# 4                      366000                 0                 0
# ...                       ...               ...               ...
# 195775                 795000                 0                 0
# 195776             6000000000               251                98
# 195777             6000000000               152               761
# 195778             6000000000               344              1246
# 195779             6000000000                84               299
#
#        Twitter_Reply_Count Twitter_Retweets Twitter_Tweets Twitter_Verified  \
# 0                        0                0              0            false
# 1                        0                0              0            false
# 2                        0                0         133900            false
# 3                        3                2          53035            false
# 4                        0                0              0            false
# ...                    ...              ...            ...              ...
# 195775                   0                0              0            false
# 195776                   0                0            195            false
# 195777                   0                0          11835            false
# 195778                   0                0           4105            false
# 195779                   1                0           8470            false
#
#        Reach_(new)                                         Clean_Text
# 0              134  Cita Iniciado por El_Bunk Alguien a visto a es...
# 1              134  Cita Iniciado por El_Bunk Alguien a visto a es...
# 2             2036  No se sabe si es verdad pero y que en Cali aga...
# 3            15215  Marica que piensan esos venezolanos del video ...
# 4              214  para la obtencion del registro civil Ademas de...
# ...            ...                                                ...
# 195775         443  Segun una encuesta realizada por el Observator...
# 195776           0  Seguimos abriendo corredores humanitarios para...
# 195777           0  Senor cuales democratas Venezolanos Quien elig...
# 195778           0  Hablan de todo pero no hablan de los venezolan...
# 195779           0  Las hamburguesas que vienen con huevo generalm...
#
# [195780 rows x 26 columns]
