# %%
#!pip install TikTokApi
#!pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
from TikTokApi import TikTokApi
import pandas as pd
import numpy as np
import re

# %%
TikTokApi
# Out:
# TikTokApi.tiktok.TikTokApi

# %%
n_videos = 5
username = 'elpumajoseluisr'
user_videos = TikTokApi.byUsername(username, count=n_videos)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15524/1711598651.py in <module>
#       1 n_videos = 5
#       2 username = 'elpumajoseluisr'
# ----> 3 user_videos = TikTokApi.byUsername(username, count=n_videos)
#
# AttributeError: type object 'TikTokApi' has no attribute 'byUsername'
