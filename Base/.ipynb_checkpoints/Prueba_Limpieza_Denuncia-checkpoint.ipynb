# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
'''
Created on Wed Jan 20 20:58:09 2021
 
@author: diegoalejandrobermudezsierra josefernandobarreradeplaza
'''
'''Vamos a verificar que usted tenga su espacio de trabajo actualizado, omitir si se siente confiado al respecto'''
import pandas as pd
import re
import string
import numpy as np
import funciones as fn

#Estos comandos se usan en caso de crar nuevas funciones y estas no se esten importando correctamente
#dir(fn)
#import importlib
#importlib.reload(mod)

# %% [markdown]
# # Limpieza de Base de Menciones de Xenofobia
# Este notebook explicado sirve como guía para la limpieza de un archivo ```.xlsx``` extraído de Brandwatch que captura la conversación de migrantes venezolanos para un periodo determinado. En la primera versión del documento se usa el Piloto Barómetro 2021

# %%
# Definimos la ubicación del archivo
path = input('Escriba la ruta del archivo - ')
#Importamos la base de datos que descargamos con los tweets de brandwatch 
xenofobia=pd.read_excel(path)
del path
xenofobia.head(11)
# Out:
# Escriba la ruta del archivo - /Users/diegoalejandrobermudezsierra/OneDrive - Universidad de los Andes/BAROMETRO DE XENOFOBIA/XENOFOBIA/mentions_xenofobia.xlsx
#    Mention Data Export                    Unnamed: 1  \
# 0             Mentions             1 to 3427 of 3427
# 1           Project Id                    1998268711
# 2             Query Id                  [2000132802]
# 3           Start Date  Tue Dec 01 05:00:00 UTC 2020
# 4             End Date  Fri Jan 01 05:00:00 UTC 2021
# 5             Category                     Xenofobia
# 6   Xthread Entry Type                         share
# 7                  NaN                           NaN
# 8                  NaN                      Query Id
# 9                    1                    2000132802
# 10                   2                    2000132802
#
#                           Unnamed: 2               Unnamed: 3  \
# 0                                NaN                      NaN
# 1                                NaN                      NaN
# 2                                NaN                      NaN
# 3                                NaN                      NaN
# 4                                NaN                      NaN
# 5                                NaN                      NaN
# 6                                NaN                      NaN
# 7                                NaN                      NaN
# 8                         Query Name                     Date
# 9   [Q [ Barometro Migrante Colombia  2021-01-01 04:48:06.000
# 10  [Q [ Barometro Migrante Colombia  2021-01-01 04:40:12.000
#
#                                            Unnamed: 4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                               Title
# 9                                                 NaN
# 10  @nostrabamus69 Recibiendo el año con Glenfiddi...
#
#                                            Unnamed: 5  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                             Snippet
# 9                                       Veneco carbón
# 10  @nostrabamus69 Recibiendo el año con Glenfiddi...
#
#                                            Unnamed: 6  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                           Full Text
# 9                                       Veneco carbón
# 10  @nostrabamus69 Recibiendo el año con Glenfiddi...
#
#                                            Unnamed: 7   Unnamed: 8 Unnamed: 9  \
# 0                                                 NaN          NaN        NaN
# 1                                                 NaN          NaN        NaN
# 2                                                 NaN          NaN        NaN
# 3                                                 NaN          NaN        NaN
# 4                                                 NaN          NaN        NaN
# 5                                                 NaN          NaN        NaN
# 6                                                 NaN          NaN        NaN
# 7                                                 NaN          NaN        NaN
# 8                                                 Url       Domain  Sentiment
# 9   http://oscardy.tumblr.com/post/639082416656531456   tumblr.com    neutral
# 10  http://twitter.com/thegreafer/statuses/1344865...  twitter.com    neutral
#
#     ...             Unnamed: 81             Unnamed: 82  \
# 0   ...                     NaN                     NaN
# 1   ...                     NaN                     NaN
# 2   ...                     NaN                     NaN
# 3   ...                     NaN                     NaN
# 4   ...                     NaN                     NaN
# 5   ...                     NaN                     NaN
# 6   ...                     NaN                     NaN
# 7   ...                     NaN                     NaN
# 8   ...  Categoría Barometro v3  Categoría Barometro v4
# 9   ...               Xenofobia                     NaN
# 10  ...               Xenofobia                     NaN
#
#                                           Unnamed: 83 Unnamed: 84  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7                                                 NaN         NaN
# 8                                   Categorías prueba    Ciudades
# 9   Denuncia, Xenofobia, denuncia xenofobia cl, de...         NaN
# 10  Denuncia, Xenofobia, denuncia xenofobia cl, de...      Bogota
#
#               Unnamed: 85          Unnamed: 86 Unnamed: 87  \
# 0                     NaN                  NaN         NaN
# 1                     NaN                  NaN         NaN
# 2                     NaN                  NaN         NaN
# 3                     NaN                  NaN         NaN
# 4                     NaN                  NaN         NaN
# 5                     NaN                  NaN         NaN
# 6                     NaN                  NaN         NaN
# 7                     NaN                  NaN         NaN
# 8   Dimensiones Barometro  Dimensiones Estudio   Fronteras
# 9                     NaN                  NaN         NaN
# 10                    NaN                  NaN         NaN
#
#                       Unnamed: 88       Unnamed: 89      Unnamed: 90
# 0                             NaN               NaN              NaN
# 1                             NaN               NaN              NaN
# 2                             NaN               NaN              NaN
# 3                             NaN               NaN              NaN
# 4                             NaN               NaN              NaN
# 5                             NaN               NaN              NaN
# 6                             NaN               NaN              NaN
# 7                             NaN               NaN              NaN
# 8   Medios Colombianos por Ciudad  excluir keywords  nuevas ciudades
# 9                             NaN               NaN              NaN
# 10                            NaN               NaN              NaN
#
# [11 rows x 91 columns]

# %%
xenofobia=fn.limpieza_base(xenofobia)
xenofobia.head()
# Out:
# Escriba la fila donde se encuentran los nombres de las columnas - 8
#      Query_Id                        Query_Name                     Date  \
# 0  2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 04:48:06.000
# 1  2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 04:40:12.000
# 2  2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 04:34:51.000
# 3  2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 04:34:15.000
# 4  2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 04:30:54.000
#
#                                                Title  \
# 0                                                NaN
# 1  @nostrabamus69 Recibiendo el año con Glenfiddi...
# 2                                  feliz año venecos
# 3  Estamos borrachas nivel: estamos escuchando lo...
# 4                 @OspinaPauce Venecos hijos de puta
#
#                                              Snippet  \
# 0                                      Veneco carbón
# 1  @nostrabamus69 Recibiendo el año con Glenfiddi...
# 2                                  feliz año venecos
# 3  Estamos borrachas nivel: estamos escuchando lo...
# 4                 @OspinaPauce Venecos hijos de puta
#
#                                            Full_Text  \
# 0                                      Veneco carbón
# 1  @nostrabamus69 Recibiendo el año con Glenfiddi...
# 2                                  feliz año venecos
# 3  Estamos borrachas nivel: estamos escuchando lo...
# 4                 @OspinaPauce Venecos hijos de puta
#
#                                                  Url       Domain Sentiment  \
# 0  http://oscardy.tumblr.com/post/639082416656531456   tumblr.com   neutral
# 1  http://twitter.com/thegreafer/statuses/1344865...  twitter.com   neutral
# 2  http://twitter.com/_ajmsy/statuses/13448646415...  twitter.com  positive
# 3  http://twitter.com/iVanv___/statuses/134486448...  twitter.com   neutral
# 4  http://twitter.com/ricardovill71/statuses/1344...  twitter.com  negative
#
#   Emotion  ... Categoría_Barometro_v3 Categoría_Barometro_v4  \
# 0     NaN  ...              Xenofobia                    NaN
# 1     NaN  ...              Xenofobia                    NaN
# 2     NaN  ...              Xenofobia                    NaN
# 3     NaN  ...              Xenofobia                    NaN
# 4     NaN  ...              Xenofobia              Xenofobia
#
#                                    Categorías_prueba      Ciudades  \
# 0  Denuncia, Xenofobia, denuncia xenofobia cl, de...           NaN
# 1  Denuncia, Xenofobia, denuncia xenofobia cl, de...        Bogota
# 2  Denuncia, Xenofobia, denuncia xenofobia cl, de...  Barranquilla
# 3  Denuncia, Xenofobia, denuncia xenofobia cl, de...        Bogota
# 4  Denuncia, Xenofobia, denuncia xenofobia cl, de...        Bogota
#
#   Dimensiones_Barometro Dimensiones_Estudio Fronteras  \
# 0                   NaN                 NaN       NaN
# 1                   NaN                 NaN       NaN
# 2                   NaN                 NaN       NaN
# 3                   NaN                 NaN       NaN
# 4                   NaN                 NaN       NaN
#
#   Medios_Colombianos_por_Ciudad excluir_keywords nuevas_ciudades
# 0                           NaN              NaN             NaN
# 1                           NaN              NaN             NaN
# 2                           NaN              NaN             NaN
# 3                           NaN              NaN             NaN
# 4                           NaN              NaN             NaN
#
# [5 rows x 90 columns]

# %%
# Vamos a quedarnos solamente con los tweets que tienen tags de xenofobia. Primero, filtramos las columnas con tags de xenofobia
sub = "Xenofobia"
xenofobia["Contiene_Xenofobia"]= xenofobia["Categoría_Barometro_v4"].str.find(sub)
xenofobia[['Contiene_Xenofobia', 'Categoría_Barometro_v4']]
# Out:
#       Contiene_Xenofobia Categoría_Barometro_v4
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 3                    NaN                    NaN
# 4                    0.0              Xenofobia
# ...                  ...                    ...
# 3422                 NaN                    NaN
# 3423                 NaN                    NaN
# 3424                 NaN                    NaN
# 3425                 NaN                    NaN
# 3426                 NaN                    NaN
#
# [3427 rows x 2 columns]

# %%
# Se crea una nueva base con solo los tags de Xenofobia 
xenofobia_clean = xenofobia[xenofobia['Contiene_Xenofobia']<9.0]
print(xenofobia_clean[['Contiene_Xenofobia', 'Categoría_Barometro_v4']])
print('Se reportaron ' + str(len(xenofobia_clean)) + ' mensajes xenofobos')
# Out:
#       Contiene_Xenofobia Categoría_Barometro_v4
# 4                    0.0              Xenofobia
# 5                    0.0              Xenofobia
# 6                    0.0              Xenofobia
# 14                   0.0              Xenofobia
# 15                   0.0              Xenofobia
# ...                  ...                    ...
# 3410                 0.0              Xenofobia
# 3412                 0.0              Xenofobia
# 3416                 0.0              Xenofobia
# 3418                 0.0              Xenofobia
# 3420                 0.0              Xenofobia
#
# [1086 rows x 2 columns]
# Se reportaron 1086 mensajes xenofobos

# %%
# Importamos autores de medios
text = open("medios.txt","r")
print(text)
medios = list()
for line in text:
    line = line.rsplit("OR")
    line = line[0].strip()
    if line.find(".") == -1:
        line = "@" + line
    medios.append(line)
medios
# Out:
# <_io.TextIOWrapper name='medios.txt' mode='r' encoding='UTF-8'>
# ['@RevistaSemana',
#  '@larepublica_co',
#  '@Portafolioco',
#  '@RevistaDinero',
#  '@NoticiasCaracol',
#  '@NoticiasRCN',
#  '@Citytv',
#  '@InstitucionalTV',
#  '@Canal1Colombia',
#  '@SenalColombia',
#  '@CABLENOTICIAS',
#  '@CanalCapital',
#  '@CanalTreceCo',
#  '@NoticiasUno',
#  '@NTN24',
#  '@lafm',
#  '@BluRadioCo',
#  '@dinersrevista',
#  '@colombiareports',
#  '@mundoinstante',
#  '@pulzo',
#  '@PublimetroCol',
#  '@RedPrensaVerde',
#  'semana.com',
#  'larepublica.co',
#  'portafolio.co',
#  'dinero.com',
#  'noticias.caracoltv.com',
#  'noticias.canalrcn.com',
#  'citytv.com.co',
#  'canalinstitucional.tv',
#  'noticias.canal1.com.co',
#  'senalcolombia.tv',
#  'cablenoticias.tv',
#  'canalcapital.gov.co',
#  'canaltrece.com.co',
#  'noticiasuno.com',
#  'ntn24.com',
#  'lafm.com.co',
#  'bluradio.com',
#  'revistadiners.com.co',
#  'colombiareports.com',
#  'elmundoalinstante.com',
#  'pulzo.com',
#  'publimetro.co',
#  'redprensaverde.org',
#  '@elheraldoco',
#  '@LaLibertadCo',
#  '@CanalTelecaribe',
#  '@QhuboQuilla',
#  '@adnbarranquilla',
#  'diariolalibertad.com',
#  'telecaribe.co',
#  'qhubo.com',
#  'diarioadn.co',
#  '@ELTIEMPO',
#  '@elespectador',
#  '@ElNuevoSiglo',
#  '@malpensante',
#  '@RevistaLNE',
#  '@citypaperbogota',
#  '@BogotaPost',
#  '@QhuboBogota',
#  '@adncolombia',
#  '@Gatopardocom',
#  'elespectador.com',
#  'elnuevosiglo.com.co',
#  'elmalpensante.com',
#  'lanotaeconomica.com.co',
#  'thecitypaperbogota.com',
#  'thebogotapost.com',
#  'qhubobogota.com',
#  'diarioadn.co',
#  'gatopardo.com',
#  '@Diarioccidente',
#  '@elpaiscali',
#  '@TelepacificoTV',
#  '@Noti90Minutos',
#  '@Redsonoraradio',
#  '@QhuboCali',
#  '@adncali',
#  'elpais.com.co',
#  'telepacifico.com',
#  '90minutos.co',
#  'redsonoraradio.net',
#  'qhubocali.com',
#  'diarioadn.co',
#  '@laopinioncucuta',
#  '@QhuboCucuta',
#  '@TvcucutaC',
#  '@noticucuta',
#  '@TUKANAL',
#  '@CucutaEsNoticia',
#  '@LaVozDelNorteAM',
#  '@CaracolCucuta',
#  'qhubo.com',
#  'tvcucuta.com',
#  'noticucuta3.blogspot.com',
#  'tukanal.tv',
#  'cucutaesnoticia.com',
#  '@elcolombiano',
#  '@Teleantioquia',
#  '@Telemedellin',
#  '@minuto30com',
#  '@QhuboMedallo',
#  '@ADNMedellin',
#  '@hora13noticias',
#  '@Centropolis_med',
#  '@elpalpitar',
#  '@ActualidadPol',
#  '@DespiertaAnt',
#  '@vivirpoblado',
#  'teleantioquia.co',
#  'telemedellin.tv',
#  'minuto30.com',
#  'qhubo.com',
#  'diarioadn.co',
#  'h13n.com',
#  'centropolismedellin.com',
#  'elpalpitar.com',
#  'actualidad.com.co',
#  'despiertaantioquia.com',
#  'vivirenelpoblado.com']

# %%
# Vamos a guardar la lista de autores. Primero policia, luego medios tradicionales y después, alternos
medios_policia = ["@PoliciaBogota", "@region6policia", "@region7policia", "@Region8Policia", "@Region2Policia", "@Region3Policia", "@Region1Policia",
                    "@Region4Policia", "@Region5Policia", "@PoliciaNarino", "@DevalPolicia", "@PoliciaMeta", "@PoliciaMedellin", "@PoliciaBoyaca",
                    "@PoliciaMzales", "@PoliciaVillavo", "@PoliciaBmanga", "@PoliciaCali", "@PoliciaDEMAG", "@PoliciaCmarca", "@Policiantioquia",
                    "@PoliciaCucuta", "@PoliciaQuindio", "@Policia_Caldas", "@SucrePolicia", "@PoliciaVichada", "@PoliciaGuainia",
                    "@PoliciaArauca", "@PoliciaCasanare", "@GuajiraPolicia", "@PoliciaVaupes", "@PoliciaChoco", "@PoliciaDepuy",
                    "@PoliciaUraba", "@PoliciAtlantico", "@PoliciaDECOR", "@PoliciaNteSder", "@HuilaPolicia", "@PoliciaBolivar", "@PoliciaCaqueta",
                    "@PoliciaDeris", "@PoliciaDeTolima", "@PoliciaDEMAM", "@PoliciaMTunja", "@PoliciaMonteria", "@PoliciAmazonas", "@PoliciaDeCesar",
                    "@PoliciaSanyProv", "@PoliciaPasto", "@PoliciaStander", "@PoliciaStaMarta", "@PoliciaPereira", "@PoliciaIbague", "@PoliciaPopayan", 
                    "@PoliciaCtagena", "@PoliciaColombia"] 
medios_policia
# Out:
# ['@PoliciaBogota',
#  '@region6policia',
#  '@region7policia',
#  '@Region8Policia',
#  '@Region2Policia',
#  '@Region3Policia',
#  '@Region1Policia',
#  '@Region4Policia',
#  '@Region5Policia',
#  '@PoliciaNarino',
#  '@DevalPolicia',
#  '@PoliciaMeta',
#  '@PoliciaMedellin',
#  '@PoliciaBoyaca',
#  '@PoliciaMzales',
#  '@PoliciaVillavo',
#  '@PoliciaBmanga',
#  '@PoliciaCali',
#  '@PoliciaDEMAG',
#  '@PoliciaCmarca',
#  '@Policiantioquia',
#  '@PoliciaCucuta',
#  '@PoliciaQuindio',
#  '@Policia_Caldas',
#  '@SucrePolicia',
#  '@PoliciaVichada',
#  '@PoliciaGuainia',
#  '@PoliciaArauca',
#  '@PoliciaCasanare',
#  '@GuajiraPolicia',
#  '@PoliciaVaupes',
#  '@PoliciaChoco',
#  '@PoliciaDepuy',
#  '@PoliciaUraba',
#  '@PoliciAtlantico',
#  '@PoliciaDECOR',
#  '@PoliciaNteSder',
#  '@HuilaPolicia',
#  '@PoliciaBolivar',
#  '@PoliciaCaqueta',
#  '@PoliciaDeris',
#  '@PoliciaDeTolima',
#  '@PoliciaDEMAM',
#  '@PoliciaMTunja',
#  '@PoliciaMonteria',
#  '@PoliciAmazonas',
#  '@PoliciaDeCesar',
#  '@PoliciaSanyProv',
#  '@PoliciaPasto',
#  '@PoliciaStander',
#  '@PoliciaStaMarta',
#  '@PoliciaPereira',
#  '@PoliciaIbague',
#  '@PoliciaPopayan',
#  '@PoliciaCtagena',
#  '@PoliciaColombia']

# %%
#Medios alternativos
text = open("alternos.txt","r")
print(text)
alternos = list()
for line in text:
    line = line.strip()
    alternos.append(line)
alternos
# Out:
# <_io.TextIOWrapper name='alternos.txt' mode='r' encoding='UTF-8'>
# ['D_C_Bogota OR',
#  'Agencia_API OR',
#  'ArgumentosyOpi OR',
#  'lasillavacia OR',
#  'noticucuta OR',
#  '2minutosco OR',
#  'Elsonajeroweb OR',
#  'siaradio OR',
#  'noticierolaruta OR',
#  'AlertaPaisa OR',
#  'orientesetuguia OR',
#  'acuariotv OR',
#  'cncnoticias OR',
#  'Informativoan OR',
#  'MiPutumayo OR',
#  'zonacero OR',
#  'AtlanticoEmi OR',
#  'primeronoticiaa1 OR',
#  'primeronoticiaa OR',
#  'CVnoticiastv OR',
#  'LaLibertadCo OR',
#  'CanalTropicaltv OR',
#  'elambito OR',
#  'NorteSeguro2018 OR',
#  'areacucuta OR',
#  'CucutaDenuncia OR',
#  'WALLTHER_VE OR',
#  'noticucuta OR',
#  'NorteNoticiasCu OR',
#  'EnterateCali OR',
#  'norte_periodico OR',
#  'canalguacari OR',
#  'TwiterosCali OR',
#  'YaCelacanto OR',
#  'HablaManizales OR',
#  'tintiando OR',
#  'NCTNOTICIAS OR',
#  '1anoticiass OR',
#  'OsBoyaca OR',
#  'aldianoticiasco OR',
#  'LaIndependenci1 OR',
#  'Prensalibcasan OR',
#  'elconucoacacias OR',
#  'EIExpedienteCol OR',
#  'hablalonoticias OR',
#  '7NNoticias OR',
#  'ElPregonar OR',
#  '45SegundosCom OR',
#  'AlPuntoCol OR',
#  'ColmundoRadio OR',
#  'ElVenezolanoCo OR',
#  'ExtraColombia OR',
#  'HSBnoticias OR',
#  'rodrigoprensa OR',
#  'Yariguies1027 OR',
#  'BLUSantanderes OR',
#  'Villavoalreves OR',
#  'Region_365 OR',
#  'ElInformador_SM OR',
#  'Seguimiento OR',
#  'elrotativoc OR',
#  'vernoticiassan1 OR',
#  'DiarioDelNorte OR',
#  'NoticiasGuajira OR',
#  'laregionalnet OR',
#  'elpaisvallenato OR',
#  'Soyquintopoder OR',
#  'PrensaLlanera OR',
#  'croniquindio OR',
#  'agenciaNDS OR',
#  'ASAKERW OR',
#  'transmisora720 OR',
#  'pvirtualcom OR',
#  'SuperPopayan OR',
#  'HoyDiarioMag OR',
#  'CHICACERETE OR',
#  'el_regionales OR',
#  'NoticiasBQ OR',
#  'elhomenoticias OR',
#  'HSBnoticias OR',
#  'HablemeC OR',
#  'elhomenoticias OR',
#  'confidencialcol OR',
#  'AlertaTolima OR',
#  'QHUBOTOLIMA OR',
#  'hesnoticia OR',
#  'norte_periodico OR',
#  'RioNoticiasCo OR',
#  'CHICACERETE OR',
#  'Coneolavozdelpu OR',
#  'lalenguacaribe OR',
#  'diarioriente OR',
#  'noticiasyabq OR',
#  'laotraverdadBAQ OR',
#  'noticoopercom OR',
#  'noticiasyabq OR',
#  'latertuliakilla OR',
#  'diarioelfrente OR',
#  'TvcucutaC OR',
#  'HoyNoticias2 OR',
#  'lareporteria OR',
#  'CasanareonlineC OR',
#  'LATALPAZ OR',
#  'Cambio24Oficial OR',
#  'LaJornadaco OR',
#  'RadioMagdalena OR',
#  'EventosStaMta OR',
#  'LaGuajira_ OR',
#  'hernandomontes6 OR',
#  'TuValledupar OR',
#  'croniquindio OR',
#  'SomosAgroNotas OR',
#  'SASComCreativa OR',
#  'CostaNoticiasTV OR',
#  'duvanedo OR',
#  'AlInformativo OR',
#  'NPIndependiente OR',
#  'kesedice OR',
#  'atntelevision OR',
#  'anticorrupto26_ OR',
#  'FronteraInforma OR',
#  'Horadelaverdad OR',
#  'SantamartaAD OR',
#  'LGCundinamarca OR',
#  'Caracol1170AM OR',
#  'lavibrante OR',
#  'Newsradio7arauc OR',
#  'ImpactoMundo_ OR',
#  'ElkanalTunja OR',
#  'fronteravivanew OR',
#  'momento24co OR',
#  'AnalisisUrbano OR',
#  'SeguridadCucuta OR',
#  'CucutaSeguridad OR',
#  'FunemeTito OR',
#  'El_NuevoOriente OR',
#  'radiosantafentc OR',
#  'kienyke OR',
#  'periodispublico OR',
#  'diariodelsur.com.co OR',
#  'atlinnovacion.com OR',
#  'diariolalibertad.com OR',
#  'elcolombiano.com OR',
#  'extra.com.co OR',
#  'diariodelcauca.com.co OR',
#  'hoydiariodelmagdalena.com.co OR',
#  'diariodelhuila.com OR',
#  'costanoticias.com OR',
#  'areacucuta.com OR',
#  'confidencialcolombia.com OR',
#  'radiosantafe.com']

# %%
#Búsqueda de tweets que citan a los autores
todos_medios = medios + medios_policia + alternos
datos = fn.search_autor(xenofobia_clean, tuple(todos_medios))
datos
# Out:
#         Query_Id                        Query_Name                     Date  \
# 20    2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 01:14:20.000
# 162   2000132802  [Q [ Barometro Migrante Colombia  2020-12-30 21:34:59.000
# 217   2000132802  [Q [ Barometro Migrante Colombia  2020-12-30 13:05:20.000
# 224   2000132802  [Q [ Barometro Migrante Colombia  2020-12-30 06:34:59.000
# 232   2000132802  [Q [ Barometro Migrante Colombia  2020-12-30 03:10:08.000
# ...          ...                               ...                      ...
# 3373  2000132802  [Q [ Barometro Migrante Colombia  2020-12-01 22:30:05.000
# 3378  2000132802  [Q [ Barometro Migrante Colombia  2020-12-01 21:45:12.000
# 3379  2000132802  [Q [ Barometro Migrante Colombia  2020-12-01 21:40:45.000
# 3381  2000132802  [Q [ Barometro Migrante Colombia  2020-12-01 21:27:00.000
# 3382  2000132802  [Q [ Barometro Migrante Colombia  2020-12-01 21:25:39.000
#
#                                                   Title  \
# 20    @radiosupercali @PoliciaCali @SeguridadCali Fu...
# 162   @Citytv Definitivamente no se puede con esos v...
# 217   @Citytv El pueblo nos estamos cansado de esas ...
# 224   @elespectador Ojalá q todos los mamertos colom...
# 232   @lafm Bobo hp, cómo no ya se deshizo de más de...
# ...                                                 ...
# 3373             @Citytv VENECOS, HIJOS DE PUTA VENECOS
# 3378                 @NoticiasCaracol Venecos de mierda
# 3379                                @Citytv Venecos hps
# 3381  @Citytv Venecos hijos de puta terminaron de jo...
# 3382  @Citytv Jaaaa x sapos como @PoliciaColombia @P...
#
#                                                 Snippet  \
# 20    @radiosupercali @PoliciaCali @SeguridadCali Fu...
# 162   @Citytv Definitivamente no se puede con esos v...
# 217   @Citytv El pueblo nos estamos cansado de esas ...
# 224   @elespectador Ojalá q todos los mamertos colom...
# 232   @lafm Bobo hp, cómo no ya se deshizo de más de...
# ...                                                 ...
# 3373             @Citytv VENECOS, HIJOS DE PUTA VENECOS
# 3378                 @NoticiasCaracol Venecos de mierda
# 3379                                @Citytv Venecos hps
# 3381  @Citytv Venecos hijos de puta terminaron de jo...
# 3382  @Citytv Jaaaa x sapos como @PoliciaColombia @P...
#
#                                               Full_Text  \
# 20    @radiosupercali @PoliciaCali @SeguridadCali Fu...
# 162   @Citytv Definitivamente no se puede con esos v...
# 217   @Citytv El pueblo nos estamos cansado de esas ...
# 224   @elespectador Ojalá q todos los mamertos colom...
# 232   @lafm Bobo hp, cómo no ya se deshizo de más de...
# ...                                                 ...
# 3373             @Citytv VENECOS, HIJOS DE PUTA VENECOS
# 3378                 @NoticiasCaracol Venecos de mierda
# 3379                                @Citytv Venecos hps
# 3381  @Citytv Venecos hijos de puta terminaron de jo...
# 3382  @Citytv Jaaaa x sapos como @PoliciaColombia @P...
#
#                                                     Url       Domain  \
# 20    http://twitter.com/nomercy0681/statuses/134481...  twitter.com
# 162   http://twitter.com/Angie272016/statuses/134439...  twitter.com
# 217   http://twitter.com/AJavi38/statuses/1344268333...  twitter.com
# 224   http://twitter.com/andrekpab8509/statuses/1344...  twitter.com
# 232   http://twitter.com/wassabysocial/statuses/1344...  twitter.com
# ...                                                 ...          ...
# 3373  http://twitter.com/JorgdOz/statuses/1333901208...  twitter.com
# 3378  http://twitter.com/julianamaya0178/statuses/13...  twitter.com
# 3379  http://twitter.com/masterRREA/statuses/1333888...  twitter.com
# 3381  http://twitter.com/JuanDa1/statuses/1333885332...  twitter.com
# 3382  http://twitter.com/gearce77/statuses/133388499...  twitter.com
#
#      Sentiment Emotion  ... Categoría_Barometro_v4  \
# 20     neutral     NaN  ...              Xenofobia
# 162   negative     NaN  ...              Xenofobia
# 217   negative     NaN  ...              Xenofobia
# 224   positive     NaN  ...              Xenofobia
# 232   negative     NaN  ...              Xenofobia
# ...        ...     ...  ...                    ...
# 3373  negative     NaN  ...              Xenofobia
# 3378  negative     NaN  ...              Xenofobia
# 3379   neutral     NaN  ...              Xenofobia
# 3381  negative     NaN  ...              Xenofobia
# 3382  negative     NaN  ...              Xenofobia
#
#                                       Categorías_prueba  Ciudades  \
# 20    Denuncia, Xenofobia, denuncia xenofobia cl, de...      Cali
# 162   Denuncia, Xenofobia, denuncia xenofobia cl, de...    Bogota
# 217   Denuncia, Xenofobia, denuncia xenofobia cl, de...    Bogota
# 224   Denuncia, Xenofobia, denuncia xenofobia cl, de...  Medellin
# 232   Denuncia, Xenofobia, denuncia xenofobia cl, de...    Bogota
# ...                                                 ...       ...
# 3373  Denuncia, Xenofobia, denuncia xenofobia cl, de...    Bogota
# 3378  Denuncia, Xenofobia, denuncia xenofobia cl, de...       NaN
# 3379  Denuncia, Xenofobia, denuncia xenofobia cl, de...    Bogota
# 3381  Denuncia, Xenofobia, denuncia xenofobia cl, de...    Bogota
# 3382  Denuncia, Xenofobia, denuncia xenofobia cl, de...    Bogota
#
#      Dimensiones_Barometro Dimensiones_Estudio Fronteras  \
# 20                     NaN                 NaN       NaN
# 162              Seguridad                 NaN       NaN
# 217              Seguridad                 NaN       NaN
# 224                    NaN                 NaN       NaN
# 232                    NaN                 NaN       NaN
# ...                    ...                 ...       ...
# 3373                   NaN                 NaN       NaN
# 3378                   NaN                 NaN       NaN
# 3379                   NaN                 NaN       NaN
# 3381                   NaN                 NaN       NaN
# 3382                   NaN                 NaN       NaN
#
#      Medios_Colombianos_por_Ciudad excluir_keywords nuevas_ciudades  \
# 20                             NaN              NaN             NaN
# 162                            NaN              NaN             NaN
# 217                            NaN              NaN             NaN
# 224                            NaN              NaN             NaN
# 232                            NaN              NaN             NaN
# ...                            ...              ...             ...
# 3373                           NaN              NaN             NaN
# 3378                           NaN              NaN             NaN
# 3379                           NaN              NaN             NaN
# 3381                           NaN              NaN             NaN
# 3382                           NaN              NaN             NaN
#
#      Contiene_Xenofobia
# 20                  0.0
# 162                 0.0
# 217                 0.0
# 224                 0.0
# 232                 0.0
# ...                 ...
# 3373                0.0
# 3378                0.0
# 3379                0.0
# 3381                0.0
# 3382                0.0
#
# [106 rows x 91 columns]

# %%
datos['Snippet']
# Out:
# 20      @radiosupercali @PoliciaCali @SeguridadCali Fu...
# 162     @Citytv Definitivamente no se puede con esos v...
# 217     @Citytv El pueblo nos estamos cansado de esas ...
# 224     @elespectador Ojalá q todos los mamertos colom...
# 232     @lafm Bobo hp, cómo no ya se deshizo de más de...
#                               ...
# 3373               @Citytv VENECOS, HIJOS DE PUTA VENECOS
# 3378                   @NoticiasCaracol Venecos de mierda
# 3379                                  @Citytv Venecos hps
# 3381    @Citytv Venecos hijos de puta terminaron de jo...
# 3382    @Citytv Jaaaa x sapos como @PoliciaColombia @P...
# Name: Snippet, Length: 106, dtype: object

# %%
#Base consolidada
xenofobia_clean = fn.label_base(xenofobia_clean, tuple(todos_medios))
xenofobia_clean['Cita_medios'] = pd.get_dummies(xenofobia_clean['Cita_medios'])
xenofobia_clean['Cita_medios']
# Out:
# /Users/diegoalejandrobermudezsierra/Documents/GitHub/BX/Base/funciones.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cita_medios'] = np.logical_or.reduce([df['Snippet'].str.contains(autor) for autor in autores])
# <ipython-input-42-744528eb934e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xenofobia_clean['Cita_medios'] = pd.get_dummies(xenofobia_clean['Cita_medios'])
# 4       1
# 5       1
# 6       1
# 14      1
# 15      1
#        ..
# 3410    1
# 3412    1
# 3416    1
# 3418    1
# 3420    1
# Name: Cita_medios, Length: 1086, dtype: uint8

# %%
xenofobia_clean[xenofobia_clean['Cita_medios'] == 0]['Snippet']
# Out:
# 20      @radiosupercali @PoliciaCali @SeguridadCali Fu...
# 162     @Citytv Definitivamente no se puede con esos v...
# 217     @Citytv El pueblo nos estamos cansado de esas ...
# 224     @elespectador Ojalá q todos los mamertos colom...
# 232     @lafm Bobo hp, cómo no ya se deshizo de más de...
#                               ...
# 3373               @Citytv VENECOS, HIJOS DE PUTA VENECOS
# 3378                   @NoticiasCaracol Venecos de mierda
# 3379                                  @Citytv Venecos hps
# 3381    @Citytv Venecos hijos de puta terminaron de jo...
# 3382    @Citytv Jaaaa x sapos como @PoliciaColombia @P...
# Name: Snippet, Length: 106, dtype: object

# %%
i = 0
for msg in xenofobia_clean[xenofobia_clean['Cita_medios'] == 0]['Snippet']:
    i += 1
    print(str(i) + ". " + msg)
# Out:
# 1. @radiosupercali @PoliciaCali @SeguridadCali Fuera a todos esos hp venecos
# 2. @Citytv Definitivamente no se puede con esos venecos,, acá si son los malandros, matan y roban y exigen, pero vallan a su ciudad haber si hacen lo mismo ahí si no tienen los pantalones bien puestos esos hp
# 3. @Citytv El pueblo nos estamos cansado de esas RATAS VENECOS nos toca armarnos
# 4. @elespectador Ojalá q todos los mamertos colombianos vean esta maravillosa noticia y se vayan de Colombia con destino directo su mesias venezolano
# 5. @lafm Bobo hp, cómo no ya se deshizo de más de 5millones de sus venecos, solo los que se han ido, sin contar los muertos... Los únicos de otras nacionalidades son los @PartidoFARC , cómo santrich... Que payaso este gripe hijo de sus mil putas madres del @NicolasMaduro
# 94. @pulzo No digan extranjeros, digan VENECOS HPTAS!
# 95. muchos se quejan que nuestra @PoliciaColombia maltrata atropella etc. los izquierdosos de MIERD. y periodistas amarillistas muestran videos pero siempre les hace falta un pedazo.. pregúntele a cualquier venezolano o dominicano a ver que tal es la policía de su pais. hpts pendejos
# 96. @minuto30com DEBE SER VENEZOLANO ESOS SON LOS Q ESTAN DANDOLE CUCHILLO A TODO EL MUNDO PARA ROBAR Y PARA TODO FUERA VENEZOLANOS DE COLOMBIA
# 97. @NoticiasCaracol Quisque extranjeros son venecos nos les de miedo decir que son venezolanos que son ratas extranjeros los de Austria o Bélgica que hablan otro idioma pero extranjeros esas ratas de venezolanos
# 98. @NoticiasCaracol Digan venezolanos alias los venecos hptas
# 99. @NoticiasCaracol Venecos hijos de puta, toca exterminarlos de aqui
# 100. @Venezoguaro0210 @NoticiasCaracol Igual Venecos de mierda. Largo de nuestro país.
# 101. @NoticiasCaracol Esos venezolanos son la plaga, peor que el coronavirus.
# 102. @Citytv VENECOS, HIJOS DE PUTA VENECOS
# 103. @NoticiasCaracol Venecos de mierda
# 104. @Citytv Venecos hps
# 105. @Citytv Venecos hijos de puta terminaron de joder a Bogotá.
# 106. @Citytv Jaaaa x sapos como @PoliciaColombia @PoliciaBogota los defiende la comunidad coge a esas RATAS Venecos robando o matando e intentamos darles paloterapia y llegan a defender a los amigos

# %% [markdown]
# # El código aquí abajo aplica para el AntCod de Diego

# %%
#Tomamos solo la columna Full Text
tweets=pd.DataFrame(xenofobia.Full_Text)
tweets.head()
# Out:
#                                            Full_Text
# 0                                      Veneco carbón
# 1  @nostrabamus69 Recibiendo el año con Glenfiddi...
# 2                                  feliz año venecos
# 3  Estamos borrachas nivel: estamos escuchando lo...
# 4                 @OspinaPauce Venecos hijos de puta

# %%
#Limpiamos los tweets
#Eliminamos todos los @Usuario (i.e. @ClaudiaLopez)
tweets['Clean_Text']=tweets.Full_Text.replace('@\\w+', '', regex=True)
#Eliminamos todos los signos de puntuación
tweets['Clean_Text']=tweets.Clean_Text.replace(r'[^\w\s]+', '', regex=True)
#Remplazamos los acentos de las palabras y los emojis
tweets['Clean_Text']=tweets.Clean_Text.str.normalize('NFKD')\
        .str.encode('ascii', errors='ignore')\
        .str.decode('utf-8')
#Eliminamos los dobles espacios 
tweets['Clean_Text']=tweets.Clean_Text.replace('\s+', ' ', regex=True).str.strip()

# %%
#Exportamos la base limpia en formato txt
path="/Users/diegoalejandrobermudezsierra/OneDrive - Universidad de los Andes/BAROMETRO DE XENOFOBIA/XENOFOBIA/Xenofobia_Clean.txt"
tweets.Clean_Text.to_csv(path, header=None, index=None)

#Para efectos del ejercico de afinar la regla de Xenofobia dejamos los
#"Tweets unicos"
path="/Users/diegoalejandrobermudezsierra/OneDrive - Universidad de los Andes/BAROMETRO DE XENOFOBIA/XENOFOBIA/Xenofobia_Clean_Unicos.txt"
tweets_unicos=pd.DataFrame(tweets.Clean_Text.unique())
tweets_unicos.to_csv(path, header=None, index=None)
