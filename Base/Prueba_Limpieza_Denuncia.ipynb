# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
'''
Created on Wed Jan 20 20:58:09 2021
 
@author: diegoalejandrobermudezsierra josefernandobarreradeplaza
'''
'''Vamos a verificar que usted tenga su espacio de trabajo actualizado, omitir si se siente confiado al respecto'''
import pandas as pd
import re
import string
import numpy as np
import funciones as fn

# %% [markdown]
# # Limpieza de Base de Menciones de Xenofobia
# Este notebook explicado sirve como guía para la limpieza de un archivo ```.xlsx``` extraído de Brandwatch que captura la conversación de migrantes venezolanos para un periodo determinado. En la primera versión del documento se usa el Piloto Barómetro 2021

# %%
# Definimos la ubicación del archivo
path = input('Escriba la ruta del archivo - ')
#Importamos la base de datos que descargamos con los tweets de brandwatch 
xenofobia=pd.read_excel(path)
del path
xenofobia.head(11)
# Out:
# Escriba la ruta del archivo - /Users/diegoalejandrobermudezsierra/OneDrive - Universidad de los Andes/BAROMETRO DE XENOFOBIA/XENOFOBIA/mentions_xenofobia.xlsx
#    Mention Data Export                    Unnamed: 1  \
# 0             Mentions             1 to 3427 of 3427
# 1           Project Id                    1998268711
# 2             Query Id                  [2000132802]
# 3           Start Date  Tue Dec 01 05:00:00 UTC 2020
# 4             End Date  Fri Jan 01 05:00:00 UTC 2021
# 5             Category                     Xenofobia
# 6   Xthread Entry Type                         share
# 7                  NaN                           NaN
# 8                  NaN                      Query Id
# 9                    1                    2000132802
# 10                   2                    2000132802
#
#                           Unnamed: 2               Unnamed: 3  \
# 0                                NaN                      NaN
# 1                                NaN                      NaN
# 2                                NaN                      NaN
# 3                                NaN                      NaN
# 4                                NaN                      NaN
# 5                                NaN                      NaN
# 6                                NaN                      NaN
# 7                                NaN                      NaN
# 8                         Query Name                     Date
# 9   [Q [ Barometro Migrante Colombia  2021-01-01 04:48:06.000
# 10  [Q [ Barometro Migrante Colombia  2021-01-01 04:40:12.000
#
#                                            Unnamed: 4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                               Title
# 9                                                 NaN
# 10  @nostrabamus69 Recibiendo el año con Glenfiddi...
#
#                                            Unnamed: 5  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                             Snippet
# 9                                       Veneco carbón
# 10  @nostrabamus69 Recibiendo el año con Glenfiddi...
#
#                                            Unnamed: 6  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                           Full Text
# 9                                       Veneco carbón
# 10  @nostrabamus69 Recibiendo el año con Glenfiddi...
#
#                                            Unnamed: 7   Unnamed: 8 Unnamed: 9  \
# 0                                                 NaN          NaN        NaN
# 1                                                 NaN          NaN        NaN
# 2                                                 NaN          NaN        NaN
# 3                                                 NaN          NaN        NaN
# 4                                                 NaN          NaN        NaN
# 5                                                 NaN          NaN        NaN
# 6                                                 NaN          NaN        NaN
# 7                                                 NaN          NaN        NaN
# 8                                                 Url       Domain  Sentiment
# 9   http://oscardy.tumblr.com/post/639082416656531456   tumblr.com    neutral
# 10  http://twitter.com/thegreafer/statuses/1344865...  twitter.com    neutral
#
#     ...             Unnamed: 81             Unnamed: 82  \
# 0   ...                     NaN                     NaN
# 1   ...                     NaN                     NaN
# 2   ...                     NaN                     NaN
# 3   ...                     NaN                     NaN
# 4   ...                     NaN                     NaN
# 5   ...                     NaN                     NaN
# 6   ...                     NaN                     NaN
# 7   ...                     NaN                     NaN
# 8   ...  Categoría Barometro v3  Categoría Barometro v4
# 9   ...               Xenofobia                     NaN
# 10  ...               Xenofobia                     NaN
#
#                                           Unnamed: 83 Unnamed: 84  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7                                                 NaN         NaN
# 8                                   Categorías prueba    Ciudades
# 9   Denuncia, Xenofobia, denuncia xenofobia cl, de...         NaN
# 10  Denuncia, Xenofobia, denuncia xenofobia cl, de...      Bogota
#
#               Unnamed: 85          Unnamed: 86 Unnamed: 87  \
# 0                     NaN                  NaN         NaN
# 1                     NaN                  NaN         NaN
# 2                     NaN                  NaN         NaN
# 3                     NaN                  NaN         NaN
# 4                     NaN                  NaN         NaN
# 5                     NaN                  NaN         NaN
# 6                     NaN                  NaN         NaN
# 7                     NaN                  NaN         NaN
# 8   Dimensiones Barometro  Dimensiones Estudio   Fronteras
# 9                     NaN                  NaN         NaN
# 10                    NaN                  NaN         NaN
#
#                       Unnamed: 88       Unnamed: 89      Unnamed: 90
# 0                             NaN               NaN              NaN
# 1                             NaN               NaN              NaN
# 2                             NaN               NaN              NaN
# 3                             NaN               NaN              NaN
# 4                             NaN               NaN              NaN
# 5                             NaN               NaN              NaN
# 6                             NaN               NaN              NaN
# 7                             NaN               NaN              NaN
# 8   Medios Colombianos por Ciudad  excluir keywords  nuevas ciudades
# 9                             NaN               NaN              NaN
# 10                            NaN               NaN              NaN
#
# [11 rows x 91 columns]

# %%
xenofobia=fn.limpieza_base(xenofobia)
xenofobia.head()
# Out:
# Escriba la fila donde se encuentran los nombres de las columnas - 8
#      Query_Id                        Query_Name                     Date  \
# 0  2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 04:48:06.000
# 1  2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 04:40:12.000
# 2  2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 04:34:51.000
# 3  2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 04:34:15.000
# 4  2000132802  [Q [ Barometro Migrante Colombia  2021-01-01 04:30:54.000
#
#                                                Title  \
# 0                                                NaN
# 1  @nostrabamus69 Recibiendo el año con Glenfiddi...
# 2                                  feliz año venecos
# 3  Estamos borrachas nivel: estamos escuchando lo...
# 4                 @OspinaPauce Venecos hijos de puta
#
#                                              Snippet  \
# 0                                      Veneco carbón
# 1  @nostrabamus69 Recibiendo el año con Glenfiddi...
# 2                                  feliz año venecos
# 3  Estamos borrachas nivel: estamos escuchando lo...
# 4                 @OspinaPauce Venecos hijos de puta
#
#                                            Full_Text  \
# 0                                      Veneco carbón
# 1  @nostrabamus69 Recibiendo el año con Glenfiddi...
# 2                                  feliz año venecos
# 3  Estamos borrachas nivel: estamos escuchando lo...
# 4                 @OspinaPauce Venecos hijos de puta
#
#                                                  Url       Domain Sentiment  \
# 0  http://oscardy.tumblr.com/post/639082416656531456   tumblr.com   neutral
# 1  http://twitter.com/thegreafer/statuses/1344865...  twitter.com   neutral
# 2  http://twitter.com/_ajmsy/statuses/13448646415...  twitter.com  positive
# 3  http://twitter.com/iVanv___/statuses/134486448...  twitter.com   neutral
# 4  http://twitter.com/ricardovill71/statuses/1344...  twitter.com  negative
#
#   Emotion  ... Categoría_Barometro_v3 Categoría_Barometro_v4  \
# 0     NaN  ...              Xenofobia                    NaN
# 1     NaN  ...              Xenofobia                    NaN
# 2     NaN  ...              Xenofobia                    NaN
# 3     NaN  ...              Xenofobia                    NaN
# 4     NaN  ...              Xenofobia              Xenofobia
#
#                                    Categorías_prueba      Ciudades  \
# 0  Denuncia, Xenofobia, denuncia xenofobia cl, de...           NaN
# 1  Denuncia, Xenofobia, denuncia xenofobia cl, de...        Bogota
# 2  Denuncia, Xenofobia, denuncia xenofobia cl, de...  Barranquilla
# 3  Denuncia, Xenofobia, denuncia xenofobia cl, de...        Bogota
# 4  Denuncia, Xenofobia, denuncia xenofobia cl, de...        Bogota
#
#   Dimensiones_Barometro Dimensiones_Estudio Fronteras  \
# 0                   NaN                 NaN       NaN
# 1                   NaN                 NaN       NaN
# 2                   NaN                 NaN       NaN
# 3                   NaN                 NaN       NaN
# 4                   NaN                 NaN       NaN
#
#   Medios_Colombianos_por_Ciudad excluir_keywords nuevas_ciudades
# 0                           NaN              NaN             NaN
# 1                           NaN              NaN             NaN
# 2                           NaN              NaN             NaN
# 3                           NaN              NaN             NaN
# 4                           NaN              NaN             NaN
#
# [5 rows x 90 columns]

# %%
# Vamos a quedarnos solamente con los tweets que tienen tags de xenofobia. Primero, filtramos las columnas con tags de xenofobia
sub = "Xenofobia"
xenofobia["Contiene_Xenofobia"]= xenofobia["Categoría_Barometro_v4"].str.find(sub)
xenofobia[['Contiene_Xenofobia', 'Categoría_Barometro_v4']]
# Out:
#       Contiene_Xenofobia Categoría_Barometro_v4
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 3                    NaN                    NaN
# 4                    NaN                    NaN
# ...                  ...                    ...
# 4995                 NaN                    NaN
# 4996                 NaN                    NaN
# 4997                 NaN                    NaN
# 4998                 9.0     Denuncia Xenofobia
# 4999                 NaN                    NaN
#
# [5000 rows x 2 columns]

# %%
# Se crea una nueva base con solo los tags de Xenofobia 
xenofobia_clean = xenofobia[xenofobia['Contiene_Xenofobia']<9.0]
print(xenofobia_clean[['Contiene_Xenofobia', 'Categoría_Barometro_v4']])
print('Se reportaron ' + str(len(xenofobia_clean)) + ' mensajes xenofobos')
# Out:
#       Contiene_Xenofobia Categoría_Barometro_v4
# 16                   0.0              Xenofobia
# 20                   0.0              Xenofobia
# 48                   0.0              Xenofobia
# 58                   0.0              Xenofobia
# 82                   0.0              Xenofobia
# ...                  ...                    ...
# 4879                 0.0              Xenofobia
# 4916                 0.0              Xenofobia
# 4932                 0.0              Xenofobia
# 4948                 0.0              Xenofobia
# 4961                 0.0              Xenofobia
#
# [149 rows x 2 columns]
# Se reportaron 149 mensajes xenofobos

# %%
# Importamos autores de medios
text = open("medios.txt","r")
print(text)
medios = list()
for line in text:
    line = line.rsplit("OR")
    line = line[0].strip()
    if line.find(".") == -1:
        line = "@" + line
    medios.append(line)
medios
# Out:
# <_io.TextIOWrapper name='medios.txt' mode='r' encoding='cp1252'>
# ['@RevistaSemana',
#  '@larepublica_co',
#  '@Portafolioco',
#  '@RevistaDinero',
#  '@NoticiasCaracol',
#  '@NoticiasRCN',
#  '@Citytv',
#  '@InstitucionalTV',
#  '@Canal1Colombia',
#  '@SenalColombia',
#  '@CABLENOTICIAS',
#  '@CanalCapital',
#  '@CanalTreceCo',
#  '@NoticiasUno',
#  '@NTN24',
#  '@lafm',
#  '@BluRadioCo',
#  '@dinersrevista',
#  '@colombiareports',
#  '@mundoinstante',
#  '@pulzo',
#  '@PublimetroCol',
#  '@RedPrensaVerde',
#  'semana.com',
#  'larepublica.co',
#  'portafolio.co',
#  'dinero.com',
#  'noticias.caracoltv.com',
#  'noticias.canalrcn.com',
#  'citytv.com.co',
#  'canalinstitucional.tv',
#  'noticias.canal1.com.co',
#  'senalcolombia.tv',
#  'cablenoticias.tv',
#  'canalcapital.gov.co',
#  'canaltrece.com.co',
#  'noticiasuno.com',
#  'ntn24.com',
#  'lafm.com.co',
#  'bluradio.com',
#  'revistadiners.com.co',
#  'colombiareports.com',
#  'elmundoalinstante.com',
#  'pulzo.com',
#  'publimetro.co',
#  'redprensaverde.org',
#  '@elheraldoco',
#  '@LaLibertadCo',
#  '@CanalTelecaribe',
#  '@QhuboQuilla',
#  '@adnbarranquilla',
#  'diariolalibertad.com',
#  'telecaribe.co',
#  'qhubo.com',
#  'diarioadn.co',
#  '@ELTIEMPO',
#  '@elespectador',
#  '@ElNuevoSiglo',
#  '@malpensante',
#  '@RevistaLNE',
#  '@citypaperbogota',
#  '@BogotaPost',
#  '@QhuboBogota',
#  '@adncolombia',
#  '@Gatopardocom',
#  'elespectador.com',
#  'elnuevosiglo.com.co',
#  'elmalpensante.com',
#  'lanotaeconomica.com.co',
#  'thecitypaperbogota.com',
#  'thebogotapost.com',
#  'qhubobogota.com',
#  'diarioadn.co',
#  'gatopardo.com',
#  '@Diarioccidente',
#  '@elpaiscali',
#  '@TelepacificoTV',
#  '@Noti90Minutos',
#  '@Redsonoraradio',
#  '@QhuboCali',
#  '@adncali',
#  'elpais.com.co',
#  'telepacifico.com',
#  '90minutos.co',
#  'redsonoraradio.net',
#  'qhubocali.com',
#  'diarioadn.co',
#  '@laopinioncucuta',
#  '@QhuboCucuta',
#  '@TvcucutaC',
#  '@areacucuta',
#  '@noticucuta',
#  '@TUKANAL',
#  '@CucutaEsNoticia',
#  '@LaVozDelNorteAM',
#  '@CaracolCucuta',
#  'qhubo.com',
#  'tvcucuta.com',
#  'areacucuta.com',
#  'noticucuta3.blogspot.com',
#  'tukanal.tv',
#  'cucutaesnoticia.com',
#  '@elcolombiano',
#  '@Teleantioquia',
#  '@Telemedellin',
#  '@minuto30com',
#  '@QhuboMedallo',
#  '@ADNMedellin',
#  '@hora13noticias',
#  '@Centropolis_med',
#  '@elpalpitar',
#  '@ActualidadPol',
#  '@DespiertaAnt',
#  '@vivirpoblado',
#  'teleantioquia.co',
#  'telemedellin.tv',
#  'minuto30.com',
#  'qhubo.com',
#  'diarioadn.co',
#  'h13n.com',
#  'centropolismedellin.com',
#  'elpalpitar.com',
#  'actualidad.com.co',
#  'despiertaantioquia.com',
#  'vivirenelpoblado.com']

# %%
# Vamos a guardar la lista de autores. Primero policia, luego medios tradicionales y después, alternos
medios_policia = ["@PoliciaBogota", "@region6policia", "@region7policia", "@Region8Policia", "@Region2Policia", "@Region3Policia", "@Region1Policia",
                    "@Region4Policia", "@Region5Policia", "@PoliciaNarino", "@DevalPolicia", "@PoliciaMeta", "@PoliciaMedellin", "@PoliciaBoyaca",
                    "@PoliciaMzales", "@PoliciaVillavo", "@PoliciaBmanga", "@PoliciaCali", "@PoliciaDEMAG", "@PoliciaCmarca", "@Policiantioquia",
                    "@PoliciaCucuta", "@PoliciaQuindio", "@Policia_Caldas", "@SucrePolicia", "@PoliciaVichada", "@PoliciaGuainia",
                    "@PoliciaArauca", "@PoliciaCasanare", "@GuajiraPolicia", "@PoliciaVaupes", "@PoliciaChoco", "@PoliciaDepuy",
                    "@PoliciaUraba", "@PoliciAtlantico", "@PoliciaDECOR", "@PoliciaNteSder", "@HuilaPolicia", "@PoliciaBolivar", "@PoliciaCaqueta",
                    "@PoliciaDeris", "@PoliciaDeTolima", "@PoliciaDEMAM", "@PoliciaMTunja", "@PoliciaMonteria", "@PoliciAmazonas", "@PoliciaDeCesar",
                    "@PoliciaSanyProv", "@PoliciaPasto", "@PoliciaStander", "@PoliciaStaMarta", "@PoliciaPereira", "@PoliciaIbague", "@PoliciaPopayan", 
                    "@PoliciaCtagena", "@PoliciaColombia"] 
medios_policia
# Out:
# ['@PoliciaBogota',
#  '@region6policia',
#  '@region7policia',
#  '@Region8Policia',
#  '@Region2Policia',
#  '@Region3Policia',
#  '@Region1Policia',
#  '@Region4Policia',
#  '@Region5Policia',
#  '@PoliciaNarino',
#  '@DevalPolicia',
#  '@PoliciaMeta',
#  '@PoliciaMedellin',
#  '@PoliciaBoyaca',
#  '@PoliciaMzales',
#  '@PoliciaVillavo',
#  '@PoliciaBmanga',
#  '@PoliciaCali',
#  '@PoliciaDEMAG',
#  '@PoliciaCmarca',
#  '@Policiantioquia',
#  '@PoliciaCucuta',
#  '@PoliciaQuindio',
#  '@Policia_Caldas',
#  '@SucrePolicia',
#  '@PoliciaVichada',
#  '@PoliciaGuainia',
#  '@PoliciaArauca',
#  '@PoliciaCasanare',
#  '@GuajiraPolicia',
#  '@PoliciaVaupes',
#  '@PoliciaChoco',
#  '@PoliciaDepuy',
#  '@PoliciaUraba',
#  '@PoliciAtlantico',
#  '@PoliciaDECOR',
#  '@PoliciaNteSder',
#  '@HuilaPolicia',
#  '@PoliciaBolivar',
#  '@PoliciaCaqueta',
#  '@PoliciaDeris',
#  '@PoliciaDeTolima',
#  '@PoliciaDEMAM',
#  '@PoliciaMTunja',
#  '@PoliciaMonteria',
#  '@PoliciAmazonas',
#  '@PoliciaDeCesar',
#  '@PoliciaSanyProv',
#  '@PoliciaPasto',
#  '@PoliciaStander',
#  '@PoliciaStaMarta',
#  '@PoliciaPereira',
#  '@PoliciaIbague',
#  '@PoliciaPopayan',
#  '@PoliciaCtagena',
#  '@PoliciaColombia']

# %%
#Medios alternativos
text = open("alternos.txt","r")
print(text)
alternos = list()
for line in text:
    line = line.strip()
    alternos.append(line)
alternos
# Out:
# <_io.TextIOWrapper name='alternos.txt' mode='r' encoding='cp1252'>
# ['@D_C_Bogota',
#  '@Agencia_API',
#  '@ArgumentosyOpi',
#  '@lasillavacia',
#  '@2minutosco',
#  '@Elsonajeroweb',
#  '@siaradio',
#  '@noticierolaruta',
#  '@NoticiasBQ',
#  '@elhomenoticias',
#  '@HSBnoticias',
#  '@HablemeC',
#  '@elhomenoticias',
#  '@confidencialcol',
#  '@AlertaTolima',
#  '@QHUBOTOLIMA',
#  '@hesnoticia',
#  '@norte_periodico',
#  '@RioNoticiasCo',
#  '@CHICACERETE',
#  '@Coneolavozdelpu',
#  '@lalenguacaribe',
#  '@AlertaPaisa',
#  '@diarioriente',
#  '@orientesetuguia',
#  '@acuariotv',
#  '@cncnoticias',
#  '@Informativoan',
#  '@MiPutumayo',
#  '@zonacero',
#  '@AtlanticoEmi',
#  '@primeronoticiaa1',
#  '@primeronoticiaa',
#  '@CVnoticiastv',
#  '@LaLibertadCo',
#  '@CanalTropicaltv',
#  '@elambito',
#  '@noticiasyabq',
#  '@laotraverdadBAQ',
#  '@noticoopercom',
#  '@noticiasyabq',
#  '@latertuliakilla',
#  '@diarioelfrente',
#  '@NorteSeguro2018',
#  '@areacucuta',
#  '@CucutaDenuncia',
#  '@WALLTHER_VE',
#  '@noticucuta',
#  '@NorteNoticiasCu',
#  '@TvcucutaC',
#  '@EnterateCali',
#  '@norte_periodico',
#  '@canalguacari',
#  '@TwiterosCali',
#  '@YaCelacanto',
#  '@HoyNoticias2',
#  '@HablaManizales',
#  '@tintiando',
#  '@NCTNOTICIAS',
#  '@1anoticiass',
#  '@OsBoyaca',
#  '@aldianoticiasco',
#  '@LaIndependenci1',
#  '@Prensalibcasan',
#  '@lareporteria',
#  '@CasanareonlineC',
#  '@elconucoacacias',
#  '@agenciaNDS',
#  '@hablalonoticias',
#  '@EIExpedienteCol',
#  '@7NNoticias',
#  '@ElPregonar',
#  '@45SegundosCom',
#  '@AlPuntoCol',
#  '@ColmundoRadio',
#  '@ElVenezolanoCo',
#  'diariodelsur.com.co',
#  'atlinnovacion.com',
#  'diariolalibertad.com',
#  'elcolombiano.com',
#  '@LATALPAZ',
#  '@ExtraColombia',
#  '@HSBnoticias',
#  'extra.com.co',
#  '@Cambio24Oficial',
#  '@rodrigoprensa',
#  '@LaJornadaco',
#  '@Yariguies1027',
#  '@BLUSantanderes',
#  '@Villavoalreves',
#  '@Region_365',
#  '@ElInformador_SM',
#  '@Seguimiento',
#  '@elrotativoc',
#  '@RadioMagdalena',
#  '@vernoticiassan1',
#  '@EventosStaMta',
#  '@DiarioDelNorte',
#  '@NoticiasGuajira',
#  '@LaGuajira_',
#  '@laregionalnet',
#  '@elpaisvallenato',
#  '@Soyquintopoder',
#  '@hernandomontes6',
#  '@TuValledupar',
#  '@PrensaLlanera',
#  '@croniquindio',
#  '@transmisora720',
#  '@agenciaNDS',
#  '@ASAKERW',
#  '@transmisora720',
#  '@pvirtualcom',
#  '@SuperPopayan',
#  'diariodelcauca.com.co',
#  'hoydiariodelmagdalena.com.co',
#  '@HoyDiarioMag',
#  '@CHICACERETE',
#  '@el_regionales',
#  'diariodelhuila.com']

# %%
#Búsqueda de tweets que citan a los autores
todos_medios = medios + medios_policia + alternos
def search_autor(df, autores):
    """
    Retorna una pequeña DataFrame en donde todas las filas tienen almenos una mención de medios o policía
    """
    return df[np.logical_or.reduce([df['Snippet'].str.contains(autor) for autor in autores])]

datos = search_autor(xenofobia_clean, tuple(todos_medios))
datos
# Out:
#         Query_Id                        Query_Name                     Date  \
# 258   2000132802  [Q [ Barometro Migrante Colombia  2021-01-16 21:34:16.000
# 301   2000132802  [Q [ Barometro Migrante Colombia  2021-01-16 20:45:41.000
# 580   2000132802  [Q [ Barometro Migrante Colombia  2021-01-16 16:14:18.000
# 1795  2000132802  [Q [ Barometro Migrante Colombia  2021-01-15 16:24:21.000
# 1857  2000132802  [Q [ Barometro Migrante Colombia  2021-01-15 15:35:45.000
# 3105  2000132802  [Q [ Barometro Migrante Colombia  2021-01-14 19:39:23.000
# 3290  2000132802  [Q [ Barometro Migrante Colombia  2021-01-14 16:44:44.000
# 3328  2000132802  [Q [ Barometro Migrante Colombia  2021-01-14 16:03:14.000
# 3404  2000132802  [Q [ Barometro Migrante Colombia  2021-01-14 15:04:50.000
# 4202  2000132802  [Q [ Barometro Migrante Colombia  2021-01-14 01:12:31.000
# 4325  2000132802  [Q [ Barometro Migrante Colombia  2021-01-14 00:24:37.000
# 4867  2000132802  [Q [ Barometro Migrante Colombia  2021-01-13 19:11:57.000
# 4877  2000132802  [Q [ Barometro Migrante Colombia  2021-01-13 19:02:18.000
#
#                                                   Title  \
# 258   @PoliciaMedellin @Guardianes_Ant @metrodemedel...
# 301   @Oscaralbertono6 @RevistaSemana para ustedes t...
# 580   @ernestoyamhure @RevistaSemana No va a tener  ...
# 1795  Delincuentes de nacionalidad venezolana, captu...
# 1857            @zonacero Pobre veneco, hasta ahí llegó
# 3105  @NoticiasCaracol En Colombia uno levanta una p...
# 3290  @NoticiasCaracol Abriendo la puerta a los espí...
# 3328  @NoticiasCaracol Según @NoticiasCaracol los ve...
# 3404  No hay para pagarle a los nuestros pero para t...
# 4202  @Portafolioco Pero que mas se podria esperar d...
# 4325  @zonacero Hp venezolanos vinieron fue Hacer da...
# 4867  @zonacero Que vaina con los venezolanos, que p...
# 4877  @ClaudiaLopez @NoticiasCaracol @DirectorPolici...
#
#                                                 Snippet  \
# 258   @PoliciaMedellin @Guardianes_Ant @metrodemedel...
# 301   @Oscaralbertono6 @RevistaSemana para ustedes t...
# 580   @ernestoyamhure @RevistaSemana No va a tener n...
# 1795  Delincuentes de nacionalidad venezolana, captu...
# 1857            @zonacero Pobre veneco, hasta ahí llegó
# 3105  @NoticiasCaracol En Colombia uno levanta una p...
# 3290  @NoticiasCaracol Abriendo la puerta a los espí...
# 3328  @NoticiasCaracol Según @NoticiasCaracol los ve...
# 3404  No hay para pagarle a los nuestros pero para t...
# 4202  @Portafolioco Pero que mas se podria esperar d...
# 4325  @zonacero Hp venezolanos vinieron fue Hacer da...
# 4867  @zonacero Que vaina con los venezolanos, que p...
# 4877  @ClaudiaLopez @NoticiasCaracol @DirectorPolici...
#
#                                                     Url       Domain  \
# 258   http://twitter.com/Federic48838141/statuses/13...  twitter.com
# 301   http://twitter.com/marwhite01/statuses/1350544...  twitter.com
# 580   http://twitter.com/arlex1977/statuses/13504764...  twitter.com
# 1795  http://twitter.com/rijecas/statuses/1350116622...  twitter.com
# 1857  http://twitter.com/FelipeM63037655/statuses/13...  twitter.com
# 3105  http://twitter.com/CALDILLA/statuses/134980331...  twitter.com
# 3290  http://twitter.com/JohnLeytonDiaz/statuses/134...  twitter.com
# 3328  http://twitter.com/fafajardor/statuses/1349748...  twitter.com
# 3404  http://twitter.com/elmonosanchezof/statuses/13...  twitter.com
# 4202  http://twitter.com/MartisaenzSaenz/statuses/13...  twitter.com
# 4325  http://twitter.com/Katturo1/statuses/134951271...  twitter.com
# 4867  http://twitter.com/felimartimer/statuses/13494...  twitter.com
# 4877  http://twitter.com/YUDY69BELTRAN/statuses/1349...  twitter.com
#
#      Sentiment Emotion Page_Type  ...  \
# 258    neutral     NaN   twitter  ...
# 301   negative     NaN   twitter  ...
# 580   negative     NaN   twitter  ...
# 1795   neutral     NaN   twitter  ...
# 1857  negative     NaN   twitter  ...
# 3105  negative     NaN   twitter  ...
# 3290  negative     NaN   twitter  ...
# 3328  negative     NaN   twitter  ...
# 3404   neutral     NaN   twitter  ...
# 4202  negative     NaN   twitter  ...
# 4325  negative     NaN   twitter  ...
# 4867  negative     NaN   twitter  ...
# 4877  negative     NaN   twitter  ...
#
#                                       Categorías_prueba      Ciudades  \
# 258   Denuncia, Xenofobia, denuncia xenofobia cl, de...      Medellin
# 301                              denuncia xenofobia col        Bogota
# 580                              denuncia xenofobia col        Bogota
# 1795  Denuncia, denuncia xenofobia cl, denuncia xeno...        Bogota
# 1857  Denuncia, Xenofobia, denuncia xenofobia cl, de...        Bogota
# 3105  Denuncia, denuncia xenofobia cl, denuncia xeno...        Bogota
# 3290                  Xenofobia, denuncia xenofobia col          Cali
# 3328  Denuncia, Xenofobia, denuncia xenofobia cl, de...        Bogota
# 3404                             denuncia xenofobia col          Cali
# 4202  Denuncia, Xenofobia, denuncia xenofobia cl, de...        Bogota
# 4325  Denuncia, denuncia xenofobia cl, denuncia xeno...  Barranquilla
# 4867  Denuncia, Xenofobia, denuncia xenofobia cl, de...  Barranquilla
# 4877  Denuncia, denuncia xenofobia cl, denuncia xeno...        Bogota
#
#         Dimensiones_Barometro Dimensiones_Estudio Fronteras Medios  \
# 258                       NaN                 NaN       NaN    NaN
# 301                       NaN                 NaN       NaN    NaN
# 580                       NaN                 NaN       NaN    NaN
# 1795                Seguridad                 NaN       NaN    NaN
# 1857  Discriminaciòn clasista                 NaN       NaN    NaN
# 3105                Seguridad                 NaN       NaN    NaN
# 3290                      NaN                 NaN       NaN    NaN
# 3328                      NaN                 NaN       NaN    NaN
# 3404                      NaN                 NaN       NaN    NaN
# 4202  Discriminaciòn clasista                 NaN       NaN    NaN
# 4325                      NaN                 NaN       NaN    NaN
# 4867                      NaN                 NaN       NaN    NaN
# 4877                Seguridad                 NaN       NaN    NaN
#
#      Medios_Colombianos_por_Ciudad excluir_keywords nuevas_ciudades  \
# 258                            NaN              NaN             NaN
# 301                            NaN              NaN             NaN
# 580                            NaN              NaN             NaN
# 1795                           NaN              NaN             NaN
# 1857                           NaN              NaN             NaN
# 3105                           NaN   nacionalidades             NaN
# 3290                           NaN              NaN             NaN
# 3328                           NaN   nacionalidades             NaN
# 3404                           NaN              NaN             NaN
# 4202                           NaN              NaN             NaN
# 4325                           NaN              NaN             NaN
# 4867                           NaN              NaN             NaN
# 4877                           NaN              NaN             NaN
#
#      Contiene_Xenofobia
# 258                 0.0
# 301                 0.0
# 580                 0.0
# 1795                0.0
# 1857                0.0
# 3105                0.0
# 3290                0.0
# 3328                0.0
# 3404                0.0
# 4202                0.0
# 4325                0.0
# 4867                0.0
# 4877                0.0
#
# [13 rows x 92 columns]

# %%
datos['Snippet']
# Out:
# 258     @PoliciaMedellin @Guardianes_Ant @metrodemedel...
# 301     @Oscaralbertono6 @RevistaSemana para ustedes t...
# 580     @ernestoyamhure @RevistaSemana No va a tener n...
# 1795    Delincuentes de nacionalidad venezolana, captu...
# 1857              @zonacero Pobre veneco, hasta ahí llegó
# 3105    @NoticiasCaracol En Colombia uno levanta una p...
# 3290    @NoticiasCaracol Abriendo la puerta a los espí...
# 3328    @NoticiasCaracol Según @NoticiasCaracol los ve...
# 3404    No hay para pagarle a los nuestros pero para t...
# 4202    @Portafolioco Pero que mas se podria esperar d...
# 4325    @zonacero Hp venezolanos vinieron fue Hacer da...
# 4867    @zonacero Que vaina con los venezolanos, que p...
# 4877    @ClaudiaLopez @NoticiasCaracol @DirectorPolici...
# Name: Snippet, dtype: object

# %%
#Base consolidada
def label_base(df, autores):
    """
    Retorna una pequeña DataFrame en donde todas las filas tienen almenos una mención de medios o policía
    """
    df['Cita_medios'] = np.logical_or.reduce([df['Snippet'].str.contains(autor) for autor in autores])
    return df

xenofobia_clean = label_base(xenofobia_clean, tuple(todos_medios))
xenofobia_clean['Cita_medios'] = pd.get_dummies(xenofobia_clean['Cita_medios'])
xenofobia_clean['Cita_medios']
# Out:
# <ipython-input-99-a7967235191e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cita_medios'] = np.logical_or.reduce([df['Snippet'].str.contains(autor) for autor in autores])
# <ipython-input-99-a7967235191e>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xenofobia_clean['Cita_medios'] = pd.get_dummies(xenofobia_clean['Cita_medios'])
# 16      1
# 20      1
# 48      1
# 58      1
# 82      1
#        ..
# 4879    1
# 4916    1
# 4932    1
# 4948    1
# 4961    1
# Name: Cita_medios, Length: 149, dtype: uint8

# %%
xenofobia_clean[xenofobia_clean['Cita_medios'] == 0]['Snippet']
# Out:
# 258     @PoliciaMedellin @Guardianes_Ant @metrodemedel...
# 301     @Oscaralbertono6 @RevistaSemana para ustedes t...
# 580     @ernestoyamhure @RevistaSemana No va a tener n...
# 1795    Delincuentes de nacionalidad venezolana, captu...
# 1857              @zonacero Pobre veneco, hasta ahí llegó
# 3105    @NoticiasCaracol En Colombia uno levanta una p...
# 3290    @NoticiasCaracol Abriendo la puerta a los espí...
# 3328    @NoticiasCaracol Según @NoticiasCaracol los ve...
# 3404    No hay para pagarle a los nuestros pero para t...
# 4202    @Portafolioco Pero que mas se podria esperar d...
# 4325    @zonacero Hp venezolanos vinieron fue Hacer da...
# 4867    @zonacero Que vaina con los venezolanos, que p...
# 4877    @ClaudiaLopez @NoticiasCaracol @DirectorPolici...
# Name: Snippet, dtype: object

# %%
i = 0
for msg in xenofobia_clean[xenofobia_clean['Cita_medios'] == 0]['Snippet']:
    i += 1
    print(str(i) + ". " + msg)
# Out:
# 1. @PoliciaMedellin @Guardianes_Ant @metrodemedellin @FiscaliaCol @region6policia @PoliciaColombia @2020noticiasC @AlertaPaisa @minuto30com @QHuboMedallo CUANDO SACARAN TODOS ESTOS HP VENECOS Q VIVEN ACA ROBANDO
# 2. @Oscaralbertono6 @RevistaSemana para ustedes tood es montaje si setrata delos cubanos.venezolanos chinos y rusos aah si y de los iranies que estan arrazando venezuala, gebtusa quenodia colombia y se desvuven oor los terroristas y sus caalnchinar que asco potq no se oargan para alla a vivir el paraíso
# 3. @ernestoyamhure @RevistaSemana No va a tener ninguna trascendencia romper relaciones o despachar sus diplomático, por q el mal ya esta incrustado, hay políticos colombianos a el servicio e intereses cubanos y venezolanos. Los une un sueño bolivariano y socialista lo cual les hace perder la identidad nacional
# 4. Delincuentes de nacionalidad venezolana, capturados CAI GALÁN @PoliciaBogota. https://t.co/N2mb36KHhK
# 5. @zonacero Pobre veneco, hasta ahí llegó
# 6. @NoticiasCaracol En Colombia uno levanta una piedra y sale una rata venezolana más haciendo maldades entra solo escoria de ese país......no hay quien los tranque ......
# 7. @NoticiasCaracol Abriendo la puerta a los espías cubanos y venecos, nos cree tontos este comunista, revocatoria ya!
# 8. @NoticiasCaracol Según @NoticiasCaracol los venezolanos no son personas, estos medios colombianos son unos hijos de puta de primera
# 9. No hay para pagarle a los nuestros pero para toda clase de tegua y chamán cubano y venezolano pagado a través de un tercero SI HAY .... #calico @TwiterosCali @CaliWebCo @elpaiscali @Noti90Minutos https://t.co/IUPBW4NIL3
# 10. @Portafolioco Pero que mas se podria esperar de este PAYASO en el poder...pobre Venezuela y venezolanos
# 11. @zonacero Hp venezolanos vinieron fue Hacer daño aqui. Deportenlos sin compasión
# 12. @zonacero Que vaina con los venezolanos, que plaga tan brava esa gente, todo lo malo de alla se vino para colombia
# 13. @ClaudiaLopez @NoticiasCaracol @DirectorPolicia @PoliciaColombia @cuadrantes @123_Bogota DG127bis No 91-12 esta bicicleteria es un nido de ratas guardan lo que se roban contrata venezolanos aparte no deja anden y ocupa media calle con unos conos el TERCER PISO LO CONSTRUYERON SIN LICENCIA https://t.co/UqfqlCUHZW

# %% [markdown]
# # El código aquí abajo aplica para el AntCod de Diego

# %%
#Tomamos solo la columna Full Text
tweets=pd.DataFrame(xenofobia.Full_Text)
tweets.head()
# Out:
#                                            Full_Text
# 0                                      Veneco carbón
# 1  @nostrabamus69 Recibiendo el año con Glenfiddi...
# 2                                  feliz año venecos
# 3  Estamos borrachas nivel: estamos escuchando lo...
# 4                 @OspinaPauce Venecos hijos de puta

# %%
#Limpiamos los tweets
#Eliminamos todos los @Usuario (i.e. @ClaudiaLopez)
tweets['Clean_Text']=tweets.Full_Text.replace('@\\w+', '', regex=True)
#Eliminamos todos los signos de puntuación
tweets['Clean_Text']=tweets.Clean_Text.replace(r'[^\w\s]+', '', regex=True)
#Remplazamos los acentos de las palabras y los emojis
tweets['Clean_Text']=tweets.Clean_Text.str.normalize('NFKD')\
        .str.encode('ascii', errors='ignore')\
        .str.decode('utf-8')
#Eliminamos los dobles espacios 
tweets['Clean_Text']=tweets.Clean_Text.replace('\s+', ' ', regex=True).str.strip()

# %%
#Exportamos la base limpia en formato txt
path="/Users/diegoalejandrobermudezsierra/OneDrive - Universidad de los Andes/BAROMETRO DE XENOFOBIA/XENOFOBIA/Xenofobia_Clean.txt"
tweets.Clean_Text.to_csv(path, header=None, index=None)

#Para efectos del ejercico de afinar la regla de Xenofobia dejamos los
#"Tweets unicos"
path="/Users/diegoalejandrobermudezsierra/OneDrive - Universidad de los Andes/BAROMETRO DE XENOFOBIA/XENOFOBIA/Xenofobia_Clean_Unicos.txt"
tweets_unicos=pd.DataFrame(tweets.Clean_Text.unique())
tweets_unicos.to_csv(path, header=None, index=None)
