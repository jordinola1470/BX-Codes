# %% [markdown]
# # Generación de base para el mapa

# %%
import numpy as np
import pandas as pd
from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)

# %%
base_1 = pd.read_csv("mensajes_13_mar_21_mar.csv")
base_2 = pd.read_csv("mensajes_22_mar_25_mar.csv")
base_3 = pd.read_csv("mensajes_26_mar_31_mar.csv")
base_racismo_1 = base_1.append(base_2)
base_racismo = base_racismo_1.append(base_3)
base_racismo['Count'] = 1
base_racismo
# Out:
#        Network                                        Message URL  \
# 0    Instagram           https://www.instagram.com/p/CbZFBRbg3x0/
# 1      Twitter  https://twitter.com/MiguelVallejoB2/statuses/1...
# 2      Twitter  https://twitter.com/gnajjjj/statuses/150611684...
# 3      Twitter  https://twitter.com/gnajjjj/statuses/150611611...
# 4      Twitter  https://twitter.com/cassimskatelml/statuses/15...
# ..         ...                                                ...
# 558    Twitter  https://twitter.com/anacroniacondes/statuses/1...
# 559    Twitter  https://twitter.com/mtzmonroy2/statuses/150759...
# 560    Twitter  https://twitter.com/BrandonCortes9/statuses/15...
# 561    Twitter  https://twitter.com/tammu_kiddox/statuses/1507...
# 562    Twitter  https://twitter.com/BrandonCortes9/statuses/15...
#
#              Profile                Date  \
# 0                NaN  3/21/2022 11:57 pm
# 1    MiguelVallejoB2  3/21/2022 11:56 pm
# 2            gnajjjj  3/21/2022 11:53 pm
# 3            gnajjjj  3/21/2022 11:50 pm
# 4     cassimskatelml  3/21/2022 11:49 pm
# ..               ...                 ...
# 558  anacroniacondes   3/26/2022 1:34 am
# 559       mtzmonroy2   3/26/2022 1:27 am
# 560   BrandonCortes9   3/26/2022 1:24 am
# 561     tammu_kiddox  3/26/2022 12:26 am
# 562   BrandonCortes9  3/26/2022 12:22 am
#
#                                                Message     Type Content Type  \
# 0    Ofrezco estos dos talleres durante esta semana...  Message        Photo
# 1    mikelegorreta @MigeGs58 @azucenau @Radio_Formu...  Mention    Text Only
# 2    En realidad todo complejo de inferioridad care...  Message         Link
# 3    No. Más bien porque un zoquete resentido quiso...  Message         Link
# 4    Clasistas nomás https://t.co/kyvelatrD7 | QT: ...  Message         Link
# ..                                                 ...      ...          ...
# 558  mishifustofeles También se puso clasista la co...  Mention        Photo
# 559  ChumelTorres Me corto un huevo si algún Chairo...  Mention    Text Only
# 560               prieto__n 😂😂😂 jajaja ok ok xD jajaja  Mention    Text Only
# 561  JacintoLagunas1 @estibalizfeito Pero los hombr...  Mention    Text Only
# 562  prieto__n Tonto jajajaja pero en realidad no e...  Mention    Text Only
#
#      Followers  Engagements                            Location Gender  Age  \
# 0            0          251                                 NaN    NaN  NaN
# 1           85            0                              Mexico    Men  NaN
# 2         1759            9  Colonia Lindavista, México, Mexico    NaN  NaN
# 3         1759            4  Colonia Lindavista, México, Mexico    NaN  NaN
# 4          210            0                              Mexico    Men  NaN
# ..         ...          ...                                 ...    ...  ...
# 558        140            1                              Mexico    Men  NaN
# 559        181            1           Jiutepec, Morelos, Mexico    Men  NaN
# 560        385            1                              Mexico    NaN  NaN
# 561         65            1              Toluca, México, Mexico  Women  NaN
# 562        385            1                              Mexico    NaN  NaN
#
#      Likes  Dislikes  Comments  Shares     Theme  Count
# 0      244         0         7       0       NaN      1
# 1        0         0         0       0       NaN      1
# 2        7         0         2       0      Odio      1
# 3        4         0         0       0  Backlash      1
# 4        0         0         0       0       NaN      1
# ..     ...       ...       ...     ...       ...    ...
# 558      1         0         0       0       NaN      1
# 559      1         0         0       0       NaN      1
# 560      0         0         1       0       NaN      1
# 561      1         0         0       0    Género      1
# 562      0         0         1       0       NaN      1
#
# [2347 rows x 18 columns]

# %%
base_negativa = pd.read_csv("mensajes_negativos_13_mar_31_mar.csv")
base_negativa['Count_negativo'] = 1
base_negativa.rename({"Followers": "Followers_negativo",	"Engagements": "Engagements_negativo", "Age":"Age_negativo", "Likes":"Likes_negativos",	
                      "Dislikes":"Dislikes_negativo",	"Comments":"Comments_negativo",	"Shares":"Shares_negativo"}, inplace=True, axis=1)
base_negativa
# Out:
#        Network                                        Message URL  \
# 0      Twitter  https://twitter.com/ArturoRiba/statuses/150972...
# 1      Twitter  https://twitter.com/OrtollServando/statuses/15...
# 2    Instagram           https://www.instagram.com/p/CbydKL9NQeL/
# 3      Twitter  https://twitter.com/BryanToriz1/statuses/15096...
# 4      Twitter  https://twitter.com/alejandrogodi01/statuses/1...
# ..         ...                                                ...
# 655    Twitter  https://twitter.com/ProfesorEGN/statuses/15031...
# 656    Twitter  https://twitter.com/capingalexsan/statuses/150...
# 657    Twitter  https://twitter.com/ElisaVillalvazo/statuses/1...
# 658    Twitter  https://twitter.com/angelisiordia_/statuses/15...
# 659    Twitter  https://twitter.com/chefjesusmx/statuses/15031...
#
#              Profile                Date  \
# 0         ArturoRiba  3/31/2022 10:49 pm
# 1     OrtollServando   3/31/2022 8:49 pm
# 2                NaN   3/31/2022 8:29 pm
# 3        BryanToriz1   3/31/2022 8:03 pm
# 4    alejandrogodi01   3/31/2022 7:55 pm
# ..               ...                 ...
# 655      ProfesorEGN   3/13/2022 6:37 pm
# 656    capingalexsan   3/13/2022 6:07 pm
# 657  ElisaVillalvazo   3/13/2022 4:37 pm
# 658   angelisiordia_   3/13/2022 4:33 pm
# 659      chefjesusmx   3/13/2022 4:19 pm
#
#                                                Message     Type Content Type  \
# 0    marcouriel13 @berruetagf Deplorable actitud de...  Mention    Text Only
# 1     Biologictime:\n\n"México es racista y clasista."  Mention    Text Only
# 2    Hoy en el #diadelavisibilidadtrans \nExaminémo...  Message        Photo
# 3    Guzzodz @MisDerechosLGBT @abrahamendieta @Salm...  Mention    Text Only
# 4    Los ataques por racismo en EEUU, no quedan sol...  Message        Photo
# ..                                                 ...      ...          ...
# 655  HernanGomezB @AgustinLaje Lo que pasa es que t...  Mention    Text Only
# 656  mansacalab El racismo "de rebote" por serlo, n...  Mention    Text Only
# 657  Los panistas lacayos, gatos de las empresas CO...  Message        Photo
# 658  Ayer que leí que nos señalaron por un acto de ...  Message        Photo
# 659  Jajaja ahora resulta, neta si quiere seguir en...  Message         Link
#
#      Followers_negativo  Engagements_negativo  \
# 0                   156                     1
# 1                  6393                     0
# 2                     0                   222
# 3                  1128                     3
# 4                    98                     1
# ..                  ...                   ...
# 655                 270                    30
# 656                 331                     6
# 657                1273                     0
# 658                  99                     1
# 659                 285                     2
#
#                              Location Gender  Age_negativo  Likes_negativos  \
# 0        Tlalpan, Mexico City, Mexico    NaN           NaN                1
# 1              Colima, Colima, Mexico    NaN           NaN                0
# 2                                 NaN    NaN           NaN              216
# 3                              Mexico    Men           NaN                0
# 4     Cuauhtemoc, Mexico City, Mexico    Men           NaN                1
# ..                                ...    ...           ...              ...
# 655   Xochimilco, Mexico City, Mexico    NaN           NaN               27
# 656       Casa Blanca, Puebla, Mexico    NaN           NaN                4
# 657      Guadalajara, Jalisco, Mexico  Women           NaN                0
# 658         Jiutepec, Morelos, Mexico  Women           NaN                1
# 659  Oaxaca de Juarez, Oaxaca, Mexico    NaN           NaN                1
#
#      Dislikes_negativo  Comments_negativo  Shares_negativo     Theme  \
# 0                    0                  0                0  Backlash
# 1                    0                  0                0       NaN
# 2                    0                  6                0    Género
# 3                    0                  3                0       NaN
# 4                    0                  0                0       NaN
# ..                 ...                ...              ...       ...
# 655                  0                  1                2       NaN
# 656                  0                  2                0       NaN
# 657                  0                  0                0       NaN
# 658                  0                  0                0       NaN
# 659                  0                  1                0       NaN
#
#      Count_negativo
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 655               1
# 656               1
# 657               1
# 658               1
# 659               1
#
# [660 rows x 18 columns]

# %%
base_agrupada = base_racismo.groupby('Location').sum()
base_agrupada['Splitted'] = base_agrupada.index.str.split(',')
base_agrupada.loc[:, 'Ciudad'] = base_agrupada.Splitted.map(lambda x: x[0])
try:
    base_agrupada.loc[:, 'Estado'] = base_agrupada.Splitted.str[1].str.strip()
    base_agrupada.loc[:, 'País'] = base_agrupada.Splitted.str[2].str.strip()
    base_agrupada.drop('Splitted', inplace=True, axis=1)
    base_agrupada_mexico_positiva = base_agrupada[base_agrupada['País'] == "Mexico"]
except:
    print("Do Nothing")
base_agrupada_mexico_positiva
# Out:
#                                       Followers  Engagements  Age  Likes  \
# Location
# Acambaro, Guanajuato, Mexico                  9            0  0.0      0
# Acapulco de Juarez, Guerrero, Mexico      50123           61  0.0     42
# Acatlan de Osorio, Puebla, Mexico            39            0  0.0      0
# Acayucan, Veracruz, Mexico                  178            2  0.0      1
# Actopan, Hidalgo, Mexico                     84            1  0.0      1
# ...                                         ...          ...  ...    ...
# Yautepec, Morelos, Mexico                  1044            3  0.0      3
# Zacatecas, Zacatecas, Mexico               6905           29  0.0     23
# Zacatelco, Tlaxcala, Mexico                 168           13  0.0     12
# Zapotlanejo, Jalisco, Mexico                567           14  0.0     11
# Zumpango, México, Mexico                    934            1  0.0      1
#
#                                       Dislikes  Comments  Shares  Count  \
# Location
# Acambaro, Guanajuato, Mexico                 0         0       0      1
# Acapulco de Juarez, Guerrero, Mexico         0         2      17     11
# Acatlan de Osorio, Puebla, Mexico            0         0       0      1
# Acayucan, Veracruz, Mexico                   0         1       0      2
# Actopan, Hidalgo, Mexico                     0         0       0      1
# ...                                        ...       ...     ...    ...
# Yautepec, Morelos, Mexico                    0         0       0      1
# Zacatecas, Zacatecas, Mexico                 0         2       4      8
# Zacatelco, Tlaxcala, Mexico                  0         0       1      1
# Zapotlanejo, Jalisco, Mexico                 0         2       1      1
# Zumpango, México, Mexico                     0         0       0      4
#
#                                                   Ciudad      Estado    País
# Location
# Acambaro, Guanajuato, Mexico                    Acambaro  Guanajuato  Mexico
# Acapulco de Juarez, Guerrero, Mexico  Acapulco de Juarez    Guerrero  Mexico
# Acatlan de Osorio, Puebla, Mexico      Acatlan de Osorio      Puebla  Mexico
# Acayucan, Veracruz, Mexico                      Acayucan    Veracruz  Mexico
# Actopan, Hidalgo, Mexico                         Actopan     Hidalgo  Mexico
# ...                                                  ...         ...     ...
# Yautepec, Morelos, Mexico                       Yautepec     Morelos  Mexico
# Zacatecas, Zacatecas, Mexico                   Zacatecas   Zacatecas  Mexico
# Zacatelco, Tlaxcala, Mexico                    Zacatelco    Tlaxcala  Mexico
# Zapotlanejo, Jalisco, Mexico                 Zapotlanejo     Jalisco  Mexico
# Zumpango, México, Mexico                        Zumpango      México  Mexico
#
# [188 rows x 11 columns]

# %%
base_agrupada = base_negativa.groupby('Location').sum()
base_agrupada['Splitted'] = base_agrupada.index.str.split(',')
base_agrupada.loc[:, 'Ciudad'] = base_agrupada.Splitted.map(lambda x: x[0])
try:
    base_agrupada.loc[:, 'Estado'] = base_agrupada.Splitted.str[1].str.strip()
    base_agrupada.loc[:, 'País'] = base_agrupada.Splitted.str[2].str.strip()
    base_agrupada.drop('Splitted', inplace=True, axis=1)
    base_agrupada_mexico_negativa = base_agrupada[base_agrupada['País'] == "Mexico"]
except:
    print("Do Nothing")
base_agrupada_mexico_negativa
# Out:
#                                         Followers_negativo  \
# Location
# Acapulco de Juarez, Guerrero, Mexico                  8094
# Acayucan, Veracruz, Mexico                              89
# Aguascalientes, Aguascalientes, Mexico               14624
# Apatzingan, Michoacán, Mexico                          611
# Apizaco, Tlaxcala, Mexico                              238
# ...                                                    ...
# Xalapa de Enriquez, Veracruz, Mexico                  2383
# Xochimilco, Mexico City, Mexico                       4618
# Xonacatlan, México, Mexico                             330
# Zacatecas, Zacatecas, Mexico                           104
# Zumpango, México, Mexico                                37
#
#                                         Engagements_negativo  Age_negativo  \
# Location
# Acapulco de Juarez, Guerrero, Mexico                       6           0.0
# Acayucan, Veracruz, Mexico                                 2           0.0
# Aguascalientes, Aguascalientes, Mexico                    66           0.0
# Apatzingan, Michoacán, Mexico                              0           0.0
# Apizaco, Tlaxcala, Mexico                                  1           0.0
# ...                                                      ...           ...
# Xalapa de Enriquez, Veracruz, Mexico                       2           0.0
# Xochimilco, Mexico City, Mexico                           33           0.0
# Xonacatlan, México, Mexico                                 0           0.0
# Zacatecas, Zacatecas, Mexico                               0           0.0
# Zumpango, México, Mexico                                   1           0.0
#
#                                         Likes_negativos  Dislikes_negativo  \
# Location
# Acapulco de Juarez, Guerrero, Mexico                  3                  0
# Acayucan, Veracruz, Mexico                            1                  0
# Aguascalientes, Aguascalientes, Mexico               21                  0
# Apatzingan, Michoacán, Mexico                         0                  0
# Apizaco, Tlaxcala, Mexico                             0                  0
# ...                                                 ...                ...
# Xalapa de Enriquez, Veracruz, Mexico                  1                  0
# Xochimilco, Mexico City, Mexico                      28                  0
# Xonacatlan, México, Mexico                            0                  0
# Zacatecas, Zacatecas, Mexico                          0                  0
# Zumpango, México, Mexico                              1                  0
#
#                                         Comments_negativo  Shares_negativo  \
# Location
# Acapulco de Juarez, Guerrero, Mexico                    0                3
# Acayucan, Veracruz, Mexico                              1                0
# Aguascalientes, Aguascalientes, Mexico                 45                0
# Apatzingan, Michoacán, Mexico                           0                0
# Apizaco, Tlaxcala, Mexico                               0                1
# ...                                                   ...              ...
# Xalapa de Enriquez, Veracruz, Mexico                    0                1
# Xochimilco, Mexico City, Mexico                         3                2
# Xonacatlan, México, Mexico                              0                0
# Zacatecas, Zacatecas, Mexico                            0                0
# Zumpango, México, Mexico                                0                0
#
#                                         Count_negativo              Ciudad  \
# Location
# Acapulco de Juarez, Guerrero, Mexico                 2  Acapulco de Juarez
# Acayucan, Veracruz, Mexico                           1            Acayucan
# Aguascalientes, Aguascalientes, Mexico               3      Aguascalientes
# Apatzingan, Michoacán, Mexico                        2          Apatzingan
# Apizaco, Tlaxcala, Mexico                            1             Apizaco
# ...                                                ...                 ...
# Xalapa de Enriquez, Veracruz, Mexico                 2  Xalapa de Enriquez
# Xochimilco, Mexico City, Mexico                      4          Xochimilco
# Xonacatlan, México, Mexico                           1          Xonacatlan
# Zacatecas, Zacatecas, Mexico                         1           Zacatecas
# Zumpango, México, Mexico                             1            Zumpango
#
#                                                 Estado    País
# Location
# Acapulco de Juarez, Guerrero, Mexico          Guerrero  Mexico
# Acayucan, Veracruz, Mexico                    Veracruz  Mexico
# Aguascalientes, Aguascalientes, Mexico  Aguascalientes  Mexico
# Apatzingan, Michoacán, Mexico                Michoacán  Mexico
# Apizaco, Tlaxcala, Mexico                     Tlaxcala  Mexico
# ...                                                ...     ...
# Xalapa de Enriquez, Veracruz, Mexico          Veracruz  Mexico
# Xochimilco, Mexico City, Mexico            Mexico City  Mexico
# Xonacatlan, México, Mexico                      México  Mexico
# Zacatecas, Zacatecas, Mexico                 Zacatecas  Mexico
# Zumpango, México, Mexico                        México  Mexico
#
# [105 rows x 11 columns]

# %%
base_agrupada_estados_mexico_positiva = base_agrupada_mexico_positiva.groupby("Estado").sum()
base_agrupada_estados_mexico_negativa = base_agrupada_mexico_negativa.groupby("Estado").sum()
base_agrupada_estados_mexico = pd.merge(left=base_agrupada_estados_mexico_negativa, right=base_agrupada_estados_mexico_positiva, right_on=base_agrupada_estados_mexico_positiva.index , left_on=base_agrupada_estados_mexico_negativa.index, how='inner')
base_agrupada_estados_mexico.rename({'key_0':'Estado'}, inplace=True, axis=1)
base_agrupada_estados_mexico
# Out:
#              Estado  Followers_negativo  Engagements_negativo  Age_negativo  \
# 0    Aguascalientes               14624                    66           0.0
# 1   Baja California                3064                     1           0.0
# 2           Chiapas                2508                    53           0.0
# 3         Chihuahua                1108                     0           0.0
# 4          Coahuila                6796                     0           0.0
# 5            Colima               13528                     3           0.0
# 6        Guanajuato               41265                    56           0.0
# 7          Guerrero                8094                     6           0.0
# 8           Hidalgo                4951                   191           0.0
# 9           Jalisco               81220                   243           0.0
# 10      Mexico City             1075148                  2903           0.0
# 11        Michoacán                3213                    16           0.0
# 12          Morelos                4859                    41           0.0
# 13           México               60918                   232           0.0
# 14          Nayarit                1048                     2           0.0
# 15       Nuevo León               43103                   191           0.0
# 16           Oaxaca                2309                     6           0.0
# 17           Puebla               11644                    39           0.0
# 18        Querétaro               32260                   254           0.0
# 19          Sinaloa                1177                     2           0.0
# 20           Sonora               72581                    67           0.0
# 21          Tabasco              116478                   194           0.0
# 22       Tamaulipas                7088                    10           0.0
# 23         Tlaxcala                 238                     1           0.0
# 24         Veracruz               24809                   122           0.0
# 25          Yucatán               17413                   208           0.0
# 26        Zacatecas                 104                     0           0.0
#
#     Likes_negativos  Dislikes_negativo  Comments_negativo  Shares_negativo  \
# 0                21                  0                 45                0
# 1                 1                  0                  0                0
# 2                39                  0                  4               10
# 3                 0                  0                  0                0
# 4                 0                  0                  0                0
# 5                 2                  0                  1                0
# 6                41                  0                 12                3
# 7                 3                  0                  0                3
# 8               165                  0                  9               17
# 9               165                  0                 30               48
# 10             2282                  0                134              487
# 11                8                  0                  0                8
# 12               27                  0                  6                8
# 13              175                  0                 13               44
# 14                1                  0                  0                1
# 15              170                  0                 14                7
# 16                4                  0                  1                1
# 17               28                  0                  5                6
# 18              216                  0                  9               29
# 19                2                  0                  0                0
# 20               47                  0                  9               11
# 21              147                  0                  8               39
# 22                7                  0                  2                1
# 23                0                  0                  0                1
# 24               97                  0                  7               18
# 25              174                  0                 16               18
# 26                0                  0                  0                0
#
#     Count_negativo  Followers  Engagements  Age  Likes  Dislikes  Comments  \
# 0                3      86272          500  0.0    320         0        69
# 1                4      26731          124  0.0    100         0        17
# 2                5      13788           97  0.0     67         0        10
# 3                1       1339            1  0.0      1         0         0
# 4                1      13592            0  0.0      0         0         0
# 5                5      15775           10  0.0      8         0         2
# 6               14     116135          299  0.0    248         0        22
# 7                2      50123           61  0.0     42         0         2
# 8                7      28280          258  0.0    214         0        17
# 9               46     263558          532  0.0    388         0        72
# 10             201    5596304        14487  0.0  11186         0       612
# 11               9      11260          590  0.0    539         0        12
# 12              17      29498           73  0.0     46         0        16
# 13              70     307648          965  0.0    761         0        67
# 14               1       2688            6  0.0      3         0         1
# 15              40     215385         1723  0.0   1110         0        75
# 16               5      11606           84  0.0     56         0         2
# 17              20     242062          211  0.0    150         0        28
# 18              18     210638          482  0.0    404         0        27
# 19               1       8549           24  0.0     21         0         1
# 20              16     131694          178  0.0    128         0        29
# 21               8     407465         6254  0.0   4577         0       490
# 22               9      11004           23  0.0     17         0         4
# 23               1       3808           15  0.0     13         0         0
# 24              15      57930          282  0.0    212         0        25
# 25              17      49306          320  0.0    252         0        22
# 26               1      12639           38  0.0     31         0         2
#
#     Shares  Count
# 0      111     18
# 1        7     41
# 2       20     18
# 3        0      2
# 4        0      2
# 5        0     10
# 6       29     62
# 7       17     11
# 8       27     26
# 9       72    139
# 10    2689    687
# 11      39     20
# 12      11     53
# 13     137    275
# 14       2      3
# 15     538    160
# 16      26     16
# 17      33     84
# 18      51     77
# 19       2     10
# 20      21     44
# 21    1187     39
# 22       2     21
# 23       2      8
# 24      45     50
# 25      46     39
# 26       5     16

# %%
from sklearn import preprocessing
normalized_arr = preprocessing.normalize(base_agrupada_estados_mexico['Engagements'].to_numpy().reshape(1,-1))
rounded_arr = lambda x: round(x,4)
vfunc = np.vectorize(rounded_arr)
vfunc(normalized_arr)
# Out:
# array([[3.130e-02, 7.800e-03, 6.100e-03, 1.000e-04, 0.000e+00, 6.000e-04,
#         1.870e-02, 3.800e-03, 1.620e-02, 3.340e-02, 9.082e-01, 3.700e-02,
#         4.600e-03, 6.050e-02, 4.000e-04, 1.080e-01, 5.300e-03, 1.320e-02,
#         3.020e-02, 1.500e-03, 1.120e-02, 3.921e-01, 1.400e-03, 9.000e-04,
#         1.770e-02, 2.010e-02, 2.400e-03]])

# %%
scaler = preprocessing.MinMaxScaler()
base_agrupada_estados_mexicos_counts = base_agrupada_estados_mexico[['Estado','Count', 'Count_negativo']]
base_agrupada_estados_mexicos_counts.rename({'key_0': 'Estado'}, axis=1, inplace=True)
base_agrupada_estados_mexicos_counts.set_index('Estado', inplace=True)
base_agrupada_estados_mexicos_counts['% Odio'] = base_agrupada_estados_mexicos_counts['Count_negativo']/base_agrupada_estados_mexicos_counts['Count']
base_agrupada_estados_mexicos_counts.to_csv("Base_estados_mexicanos_completa.csv")
base_agrupada_estados_mexicos_counts
# Out:
# C:\Users\JOSE\anaconda3\envs\nltkenv\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\JOSE\AppData\Local\Temp/ipykernel_4720/4022730869.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_agrupada_estados_mexicos_counts['% Odio'] = base_agrupada_estados_mexicos_counts['Count_negativo']/base_agrupada_estados_mexicos_counts['Count']
#                  Count  Count_negativo    % Odio
# Estado
# Aguascalientes      18               3  0.166667
# Baja California     41               4  0.097561
# Chiapas             18               5  0.277778
# Chihuahua            2               1  0.500000
# Coahuila             2               1  0.500000
# Colima              10               5  0.500000
# Guanajuato          62              14  0.225806
# Guerrero            11               2  0.181818
# Hidalgo             26               7  0.269231
# Jalisco            139              46  0.330935
# Mexico City        687             201  0.292576
# Michoacán           20               9  0.450000
# Morelos             53              17  0.320755
# México             275              70  0.254545
# Nayarit              3               1  0.333333
# Nuevo León         160              40  0.250000
# Oaxaca              16               5  0.312500
# Puebla              84              20  0.238095
# Querétaro           77              18  0.233766
# Sinaloa             10               1  0.100000
# Sonora              44              16  0.363636
# Tabasco             39               8  0.205128
# Tamaulipas          21               9  0.428571
# Tlaxcala             8               1  0.125000
# Veracruz            50              15  0.300000
# Yucatán             39              17  0.435897
# Zacatecas           16               1  0.062500

# %%
names = base_agrupada_estados_mexicos_counts.columns
d = scaler.fit_transform(base_agrupada_estados_mexicos_counts)
scaled_df = pd.DataFrame(d, columns=names)
scaled_df['Estado'] = base_agrupada_estados_mexico.Estado
scaled_df.set_index('Estado', inplace=True)
scaled_df.head(8)
# Out:
#                     Count  Count_negativo    % Odio
# Estado
# Aguascalientes   0.023358           0.010  0.238095
# Baja California  0.056934           0.015  0.080139
# Chiapas          0.023358           0.020  0.492063
# Chihuahua        0.000000           0.000  1.000000
# Coahuila         0.000000           0.000  1.000000
# Colima           0.011679           0.020  1.000000
# Guanajuato       0.087591           0.065  0.373272
# Guerrero         0.013139           0.005  0.272727

# %%
fulled_df = pd.merge(left= scaled_df, right= base_agrupada_estados_mexico, left_on=scaled_df.index, right_on=base_agrupada_estados_mexico.Estado, how="inner")
fulled_df.rename({'key_0':'Estado', 'Followers_x':'Followers_n'
                 , 'Engagements_x':'Engagements_n', 'Count_x':'Count_n'
                 , 'Count_y':'Count', 'Followers_y':'Followers', 'Engagements_y':'Engagements', 'Count_negativo_y':'Count_negativo'}, inplace=True, axis=1)
fulled_df.columns
# Out:
# Index(['Estado', 'Count_n', 'Count_negativo_x', '% Odio', 'Estado',
#        'Followers_negativo', 'Engagements_negativo', 'Age_negativo',
#        'Likes_negativos', 'Dislikes_negativo', 'Comments_negativo',
#        'Shares_negativo', 'Count_negativo', 'Followers', 'Engagements', 'Age',
#        'Likes', 'Dislikes', 'Comments', 'Shares', 'Count'],
#       dtype='object')

# %%
fulled_df[['Count_negativo', 'Count_negativo_x', '% Odio', 'Count']]
# Out:
#     Count_negativo  Count_negativo_x    % Odio  Count
# 0                3             0.010  0.238095     18
# 1                4             0.015  0.080139     41
# 2                5             0.020  0.492063     18
# 3                1             0.000  1.000000      2
# 4                1             0.000  1.000000      2
# 5                5             0.020  1.000000     10
# 6               14             0.065  0.373272     62
# 7                2             0.005  0.272727     11
# 8                7             0.030  0.472527     26
# 9               46             0.225  0.613566    139
# 10             201             1.000  0.525889    687
# 11               9             0.040  0.885714     20
# 12              17             0.080  0.590296     53
# 13              70             0.345  0.438961    275
# 14               1             0.000  0.619048      3
# 15              40             0.195  0.428571    160
# 16               5             0.020  0.571429     16
# 17              20             0.095  0.401361     84
# 18              18             0.085  0.391466     77
# 19               1             0.000  0.085714     10
# 20              16             0.075  0.688312     44
# 21               8             0.035  0.326007     39
# 22               9             0.040  0.836735     21
# 23               1             0.000  0.142857      8
# 24              15             0.070  0.542857     50
# 25              17             0.080  0.853480     39
# 26               1             0.000  0.000000     16

# %%
scaled_df.to_excel("Base_estados_mexicanos_normalizada.xlsx")
scaled_df.to_csv("Base_estados_mexicanos_normalizada.csv")

# %% [markdown]
# # Recibimiento base racismo por Equipo RacismoMx

# %%
import pandas as pd
import numpy as np
path = r"D:\Trabajo\Barómetro\BX\Racismo" + "\\"
base_marcada = pd.read_excel(path + "Base_preliminar_marcada_por_mexico.xlsx")
base_marcada["Count_negativo"] = base_marcada["Count_negativo"].replace("Na","NaN")
base_marcada = base_marcada[base_marcada["Count_negativo"] != "NaN"]
base_marcada = base_marcada[base_marcada["Count_negativo"] != np.nan]
base_marcada.dropna(subset=["Count_negativo"],inplace=True)
base_marcada["Count_negativo"] = base_marcada["Count_negativo"].astype(int)
print(pd.unique(base_marcada["Count_negativo"]))
base_marcada.head(4)
# Out:
# [1 0]
#    Unnamed: 0                                        Message URL  \
# 0           0  https://twitter.com/Padawanmx/statuses/1494174...
# 4           9  https://twitter.com/cepia2011/statuses/1494144...
# 5          10  https://twitter.com/IQAlfo81/statuses/14941402...
# 6          11  https://twitter.com/pablinskiki/statuses/14941...
#
#    Count_negativo_BX Content Type      Profile                Date  \
# 0                  0         Link    Padawanmx  2/16/2022 11:57 pm
# 4                  0    Text Only    cepia2011   2/16/2022 9:58 pm
# 5                  0         Link     IQAlfo81   2/16/2022 9:42 pm
# 6                  1    Text Only  pablinskiki   2/16/2022 9:41 pm
#
#                                              Message     Type Content Type.1  \
# 0  Como sabes que un twittero es un pendejo?\n\nU...  Message           Link
# 4  grankan23 @yan_al_sur Si, si , el rollo neolib...  Mention      Text Only
# 5  La mejor respuesta que he leído hacia un montó...  Message           Link
# 6   MizzRat69 @roberto_snts Sigue llorando… racista.  Mention      Text Only
#
#    Followers  ...  Likes Dislikes Comments  Shares  Theme       Estado  \
# 0       1836  ...      1        0        0       0      0      Morelos
# 4        130  ...      1        0        0       0      0  Mexico City
# 5        921  ...      2        0        0       0      0       México
# 6       1206  ...      1        0        1       0      0  Mexico City
#
#      País  Count Count_negativo Unnamed: 23
# 0  Mexico      1              1         NaN
# 4  Mexico      1              0         NaN
# 5  Mexico      1              0         NaN
# 6  Mexico      1              0         NaN
#
# [4 rows x 24 columns]

# %%
base_agrupada_estados_mexico_negativa = base_marcada.groupby("Estado").sum()
base_agrupada_estados_mexico_negativa["Estado_copia"] = base_agrupada_estados_mexico_negativa.index
base_agrupada_estados_mexico_negativa
# Out:
#                  Unnamed: 0  Count_negativo_BX  Followers  Engagements  Age  \
# Estado
# Aguascalientes         9324                  8      11366           14    0
# Baja California       13865                  5      10498           30    0
# Chiapas                5567                  3       2626            6    0
# Coahuila               3528                  2      13847            3    0
# Colima                 3136                  2       6908            6    0
# Guanajuato            18247                  8      85491          356    0
# Guerrero              11088                  7      40442           66    0
# Hidalgo                2719                  3        511            3    0
# Jalisco               64974                 40      69054          245    0
# Mexico City          195313                122     704399         2886    0
# Michoacán             10609                  6       3532           24    0
# Morelos               27697                 17       8559           15    0
# México                94939                 54     135004          228    0
# Nayarit                 176                  1         45            0    0
# Nuevo León            55290                 35     296193          300    0
# Oaxaca                 7685                  5     110884          184    0
# Puebla                20112                  6      41207           60    0
# Querétaro             24270                 12     157836          148    0
# San Luis Potosí        4680                  1      12643           25    0
# Sinaloa                6511                  3      12481           87    0
# Sonora                24537                 19      50163           90    0
# Tabasco                5962                  1      16812            9    0
# Tamaulipas             1992                  1      16751            5    0
# Tlaxcala               3797                  2        866            4    0
# Veracruz              10000                  8       9544           19    0
# Yucatán                8245                  6     111347           51    0
# Zacatecas              2343                  2       3939           12    0
#
#                  Likes  Dislikes  Comments  Shares  Count  Count_negativo  \
# Estado
# Aguascalientes      11         0         2       1     12               7
# Baja California     18         0         9       3     13               5
# Chiapas              5         0         0       1      6               1
# Coahuila             2         0         1       0      4               0
# Colima               4         0         2       0      5               3
# Guanajuato         282         0        30      44     23              10
# Guerrero            52         0         5       9     12               5
# Hidalgo              1         0         1       1      4               2
# Jalisco            205         0        31       9     76              35
# Mexico City       2161         0       225     500    224              90
# Michoacán           15         0         0       9     11               1
# Morelos             10         0         4       1     25               8
# México             171         0        31      26     97              45
# Nayarit              0         0         0       0      1               0
# Nuevo León         229         0        42      29     68              41
# Oaxaca             161         0        13      10     11               3
# Puebla              38         0        10      12     23              12
# Querétaro          125         0        15       8     31              14
# San Luis Potosí     17         0         5       3      4               4
# Sinaloa             77         0         6       4      7               4
# Sonora              64         0        18       8     31              20
# Tabasco              7         0         0       2      7               4
# Tamaulipas           2         0         2       1      3               1
# Tlaxcala             3         0         1       0      4               3
# Veracruz            15         0         2       2     13               4
# Yucatán             36         0        10       5     13               4
# Zacatecas            8         0         4       0      3               0
#
#                     Estado_copia
# Estado
# Aguascalientes    Aguascalientes
# Baja California  Baja California
# Chiapas                  Chiapas
# Coahuila                Coahuila
# Colima                    Colima
# Guanajuato            Guanajuato
# Guerrero                Guerrero
# Hidalgo                  Hidalgo
# Jalisco                  Jalisco
# Mexico City          Mexico City
# Michoacán              Michoacán
# Morelos                  Morelos
# México                    México
# Nayarit                  Nayarit
# Nuevo León            Nuevo León
# Oaxaca                    Oaxaca
# Puebla                    Puebla
# Querétaro              Querétaro
# San Luis Potosí  San Luis Potosí
# Sinaloa                  Sinaloa
# Sonora                    Sonora
# Tabasco                  Tabasco
# Tamaulipas            Tamaulipas
# Tlaxcala                Tlaxcala
# Veracruz                Veracruz
# Yucatán                  Yucatán
# Zacatecas              Zacatecas

# %%
from sklearn import preprocessing
normalized_arr = preprocessing.normalize(base_agrupada_estados_mexico_negativa['Engagements'].to_numpy().reshape(1,-1))
rounded_arr = lambda x: round(x,4)
vfunc = np.vectorize(rounded_arr)
vfunc(normalized_arr)
# Out:
# array([[0.0047, 0.0101, 0.002 , 0.001 , 0.002 , 0.1204, 0.0223, 0.001 ,
#         0.0829, 0.976 , 0.0081, 0.0051, 0.0771, 0.    , 0.1015, 0.0622,
#         0.0203, 0.0501, 0.0085, 0.0294, 0.0304, 0.003 , 0.0017, 0.0014,
#         0.0064, 0.0172, 0.0041]])

# %%
scaler = preprocessing.MinMaxScaler()
base_agrupada_estados_mexicos_counts = base_agrupada_estados_mexico_negativa[['Estado_copia','Count', 'Count_negativo']]
base_agrupada_estados_mexicos_counts['% Odio'] = base_agrupada_estados_mexicos_counts['Count_negativo']/base_agrupada_estados_mexicos_counts['Count']
base_agrupada_estados_mexicos_counts.to_csv("Base_estados_mexicanos_completa.csv")
base_agrupada_estados_mexicos_counts
# Out:
# <ipython-input-42-64ac7aee48aa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_agrupada_estados_mexicos_counts['% Odio'] = base_agrupada_estados_mexicos_counts['Count_negativo']/base_agrupada_estados_mexicos_counts['Count']
#                     Estado_copia  Count  Count_negativo    % Odio
# Estado
# Aguascalientes    Aguascalientes     12               7  0.583333
# Baja California  Baja California     13               5  0.384615
# Chiapas                  Chiapas      6               1  0.166667
# Coahuila                Coahuila      4               0  0.000000
# Colima                    Colima      5               3  0.600000
# Guanajuato            Guanajuato     23              10  0.434783
# Guerrero                Guerrero     12               5  0.416667
# Hidalgo                  Hidalgo      4               2  0.500000
# Jalisco                  Jalisco     76              35  0.460526
# Mexico City          Mexico City    224              90  0.401786
# Michoacán              Michoacán     11               1  0.090909
# Morelos                  Morelos     25               8  0.320000
# México                    México     97              45  0.463918
# Nayarit                  Nayarit      1               0  0.000000
# Nuevo León            Nuevo León     68              41  0.602941
# Oaxaca                    Oaxaca     11               3  0.272727
# Puebla                    Puebla     23              12  0.521739
# Querétaro              Querétaro     31              14  0.451613
# San Luis Potosí  San Luis Potosí      4               4  1.000000
# Sinaloa                  Sinaloa      7               4  0.571429
# Sonora                    Sonora     31              20  0.645161
# Tabasco                  Tabasco      7               4  0.571429
# Tamaulipas            Tamaulipas      3               1  0.333333
# Tlaxcala                Tlaxcala      4               3  0.750000
# Veracruz                Veracruz     13               4  0.307692
# Yucatán                  Yucatán     13               4  0.307692
# Zacatecas              Zacatecas      3               0  0.000000

# %% [markdown]
# # Gráficas

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import pandas as pd
from io import StringIO
base_graficas = pd.read_csv("Base_estados_mexicanos_completa.csv")
base_graficas.rename({'Count_negativo_y':'Count_negativo'}, inplace = True, axis = 1 )
base_graficas.sort_values("Count_negativo", inplace=True, ascending=False)
base_graficas['Total_Nacional'] = base_graficas['Count'].sum()
base_graficas['Participación % Nacional'] = base_graficas['Count']/base_graficas['Total_Nacional']
base_graficas.to_excel("Base_grafica_barras.xlsx")
base_graficas
# Out:
#              Estado  Count  Count_negativo    % Odio  Total_Nacional  \
# 10      Mexico City    687             201  0.292576            1931
# 13           México    275              70  0.254545            1931
# 9           Jalisco    139              46  0.330935            1931
# 15       Nuevo León    160              40  0.250000            1931
# 17           Puebla     84              20  0.238095            1931
# 18        Querétaro     77              18  0.233766            1931
# 25          Yucatán     39              17  0.435897            1931
# 12          Morelos     53              17  0.320755            1931
# 20           Sonora     44              16  0.363636            1931
# 24         Veracruz     50              15  0.300000            1931
# 6        Guanajuato     62              14  0.225806            1931
# 22       Tamaulipas     21               9  0.428571            1931
# 11        Michoacán     20               9  0.450000            1931
# 21          Tabasco     39               8  0.205128            1931
# 8           Hidalgo     26               7  0.269231            1931
# 5            Colima     10               5  0.500000            1931
# 2           Chiapas     18               5  0.277778            1931
# 16           Oaxaca     16               5  0.312500            1931
# 1   Baja California     41               4  0.097561            1931
# 0    Aguascalientes     18               3  0.166667            1931
# 7          Guerrero     11               2  0.181818            1931
# 19          Sinaloa     10               1  0.100000            1931
# 14          Nayarit      3               1  0.333333            1931
# 23         Tlaxcala      8               1  0.125000            1931
# 4          Coahuila      2               1  0.500000            1931
# 3         Chihuahua      2               1  0.500000            1931
# 26        Zacatecas     16               1  0.062500            1931
#
#     Participación % Nacional
# 10                  0.355774
# 13                  0.142413
# 9                   0.071983
# 15                  0.082859
# 17                  0.043501
# 18                  0.039876
# 25                  0.020197
# 12                  0.027447
# 20                  0.022786
# 24                  0.025893
# 6                   0.032108
# 22                  0.010875
# 11                  0.010357
# 21                  0.020197
# 8                   0.013465
# 5                   0.005179
# 2                   0.009322
# 16                  0.008286
# 1                   0.021233
# 0                   0.009322
# 7                   0.005697
# 19                  0.005179
# 14                  0.001554
# 23                  0.004143
# 4                   0.001036
# 3                   0.001036
# 26                  0.008286

# %%
base_graficas = base_graficas[0:5]
#base_graficas.drop(columns = ["Estado_copia"], inplace=True)
base_graficas
# Out:
#          Estado  Count  Count_negativo    % Odio  Total_Nacional  \
# 10  Mexico City    687             201  0.292576            1931
# 13       México    275              70  0.254545            1931
# 9       Jalisco    139              46  0.330935            1931
# 15   Nuevo León    160              40  0.250000            1931
# 17       Puebla     84              20  0.238095            1931
#
#     Participación % Nacional
# 10                  0.355774
# 13                  0.142413
# 9                   0.071983
# 15                  0.082859
# 17                  0.043501

# %%
base_graficas.columns
# Out:
# Index(['Estado', 'Count', 'Count_negativo', '% Odio', 'Total_Nacional',
#        'Participación % Nacional'],
#       dtype='object')

# %%
x_ = base_graficas.columns[0]
y_ = base_graficas.columns[3]
y_2 = base_graficas.columns[5]
data1 = base_graficas[[x_, y_]]
data2 = base_graficas[[x_, y_2]]
plt.figure(figsize=(15,8))
ax = sns.barplot(x=x_,y=y_,data=data1)
width_scale = 0.45
for bar in ax.containers[0]:
    bar.set_width(bar.get_width() * width_scale)
ax.yaxis.set_major_formatter(PercentFormatter(1))
ax.figure.text(0.4, 0,'Nota: Las columnas corresponden con los ejes. Fuente: Elaboración propia con datos de Sproutsocial.', fontsize=12)
ax.grid(False)
ax2 = ax.twinx()
sns.barplot(x=x_,y=y_2,data=data2,alpha=0.7,hatch='xx',ax=ax2)
for bar in ax2.containers[0]:
    x = bar.get_x()
    w = bar.get_width()
    bar.set_x(x + w * (1 - width_scale))
    bar.set_width(w *  width_scale)
ax2.yaxis.set_major_formatter(PercentFormatter(1))
ax2.grid(False)
plt.savefig("out.png") 
plt.show()

# %%
# Pegar las bases
base_1 = pd.read_csv("mensajes_13_mar_21_mar.csv")
base_2 = pd.read_csv("mensajes_22_mar_25_mar.csv")
base_3 = pd.read_csv("mensajes_26_mar_31_mar.csv")
base_racismo_1 = base_1.append(base_2)
base_racismo = base_racismo_1.append(base_3)
base_racismo['Splitted'] = base_racismo['Location'].str.split(',')
try:
    base_racismo.loc[:, 'Estado'] = base_racismo.Splitted.str[1].str.strip()
    base_racismo.loc[:, 'País'] = base_racismo.Splitted.str[2].str.strip()
    base_racismo.loc[:, 'Ciudad'] = base_racismo.Splitted.map(lambda x: x[0])
except:
    print("Do Nothing.")
base_racismo['Count'] = 1
base_negativa = pd.read_csv("mensajes_negativos_13_mar_31_mar.csv")
base_negativa['Count_negativo'] = 1
base_negativa.rename({"Followers": "Followers_negativo",	"Engagements": "Engagements_negativo", "Age":"Age_negativo", "Likes":"Likes_negativos",	
                      "Dislikes":"Dislikes_negativo",	"Comments":"Comments_negativo",	"Shares":"Shares_negativo"}, inplace=True, axis=1)
base_negativa = base_negativa[['Message URL','Count_negativo']]
base_negativa
# Out:
# Do Nothing.
#                                            Message URL  Count_negativo
# 0    https://twitter.com/ArturoRiba/statuses/150972...               1
# 1    https://twitter.com/OrtollServando/statuses/15...               1
# 2             https://www.instagram.com/p/CbydKL9NQeL/               1
# 3    https://twitter.com/BryanToriz1/statuses/15096...               1
# 4    https://twitter.com/alejandrogodi01/statuses/1...               1
# ..                                                 ...             ...
# 655  https://twitter.com/ProfesorEGN/statuses/15031...               1
# 656  https://twitter.com/capingalexsan/statuses/150...               1
# 657  https://twitter.com/ElisaVillalvazo/statuses/1...               1
# 658  https://twitter.com/angelisiordia_/statuses/15...               1
# 659  https://twitter.com/chefjesusmx/statuses/15031...               1
#
# [660 rows x 2 columns]

# %%
base_merged = pd.merge(right=base_racismo , left=base_negativa, left_on = "Message URL", right_on = "Message URL", how="right")
base_merged.fillna(0, inplace = True)
base_merged
# Out:
#                                             Message URL  Count_negativo  \
# 0              https://www.instagram.com/p/CbZFBRbg3x0/             0.0
# 1     https://twitter.com/MiguelVallejoB2/statuses/1...             0.0
# 2     https://twitter.com/gnajjjj/statuses/150611684...             0.0
# 3     https://twitter.com/gnajjjj/statuses/150611611...             0.0
# 4     https://twitter.com/cassimskatelml/statuses/15...             0.0
# ...                                                 ...             ...
# 2342  https://twitter.com/anacroniacondes/statuses/1...             1.0
# 2343  https://twitter.com/mtzmonroy2/statuses/150759...             1.0
# 2344  https://twitter.com/BrandonCortes9/statuses/15...             0.0
# 2345  https://twitter.com/tammu_kiddox/statuses/1507...             1.0
# 2346  https://twitter.com/BrandonCortes9/statuses/15...             0.0
#
#         Network          Profile                Date  \
# 0     Instagram                0  3/21/2022 11:57 pm
# 1       Twitter  MiguelVallejoB2  3/21/2022 11:56 pm
# 2       Twitter          gnajjjj  3/21/2022 11:53 pm
# 3       Twitter          gnajjjj  3/21/2022 11:50 pm
# 4       Twitter   cassimskatelml  3/21/2022 11:49 pm
# ...         ...              ...                 ...
# 2342    Twitter  anacroniacondes   3/26/2022 1:34 am
# 2343    Twitter       mtzmonroy2   3/26/2022 1:27 am
# 2344    Twitter   BrandonCortes9   3/26/2022 1:24 am
# 2345    Twitter     tammu_kiddox  3/26/2022 12:26 am
# 2346    Twitter   BrandonCortes9  3/26/2022 12:22 am
#
#                                                 Message     Type Content Type  \
# 0     Ofrezco estos dos talleres durante esta semana...  Message        Photo
# 1     mikelegorreta @MigeGs58 @azucenau @Radio_Formu...  Mention    Text Only
# 2     En realidad todo complejo de inferioridad care...  Message         Link
# 3     No. Más bien porque un zoquete resentido quiso...  Message         Link
# 4     Clasistas nomás https://t.co/kyvelatrD7 | QT: ...  Message         Link
# ...                                                 ...      ...          ...
# 2342  mishifustofeles También se puso clasista la co...  Mention        Photo
# 2343  ChumelTorres Me corto un huevo si algún Chairo...  Mention    Text Only
# 2344               prieto__n 😂😂😂 jajaja ok ok xD jajaja  Mention    Text Only
# 2345  JacintoLagunas1 @estibalizfeito Pero los hombr...  Mention    Text Only
# 2346  prieto__n Tonto jajajaja pero en realidad no e...  Mention    Text Only
#
#       Followers  Engagements  ...  Age Likes  Dislikes  Comments  Shares  \
# 0             0          251  ...  0.0   244         0         7       0
# 1            85            0  ...  0.0     0         0         0       0
# 2          1759            9  ...  0.0     7         0         2       0
# 3          1759            4  ...  0.0     4         0         0       0
# 4           210            0  ...  0.0     0         0         0       0
# ...         ...          ...  ...  ...   ...       ...       ...     ...
# 2342        140            1  ...  0.0     1         0         0       0
# 2343        181            1  ...  0.0     1         0         0       0
# 2344        385            1  ...  0.0     0         0         1       0
# 2345         65            1  ...  0.0     1         0         0       0
# 2346        385            1  ...  0.0     0         0         1       0
#
#          Theme                                Splitted   Estado    País Count
# 0            0                                       0        0       0     1
# 1            0                                [Mexico]        0       0     1
# 2         Odio  [Colonia Lindavista,  México,  Mexico]   México  Mexico     1
# 3     Backlash  [Colonia Lindavista,  México,  Mexico]   México  Mexico     1
# 4            0                                [Mexico]        0       0     1
# ...        ...                                     ...      ...     ...   ...
# 2342         0                                [Mexico]        0       0     1
# 2343         0           [Jiutepec,  Morelos,  Mexico]  Morelos  Mexico     1
# 2344         0                                [Mexico]        0       0     1
# 2345    Género              [Toluca,  México,  Mexico]   México  Mexico     1
# 2346         0                                [Mexico]        0       0     1
#
# [2347 rows x 22 columns]

# %%
base_merged.to_excel("Base_preliminar.xlsx")

# %%
# Analisis por autores y 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import pandas as pd
from io import StringIO
#base_marcada = pd.read_excel("Base_preliminar_marcada_por_mexico.xlsx")
base_marcada = pd.read_excel("Base_preliminar.xlsx")
base_marcada["Count_negativo"] = base_marcada["Count_negativo"].replace("Na","NaN")
base_marcada = base_marcada[base_marcada["Count_negativo"] != "NaN"]
base_marcada = base_marcada[base_marcada["Count_negativo"] != np.nan]
base_marcada = base_marcada[base_marcada["Profile"] != 0]
base_marcada.dropna(subset=["Count_negativo"],inplace=True)
base_marcada["Count_negativo"] = base_marcada["Count_negativo"].astype(int)
base_marcada.head(5)
# Out:
#    Unnamed: 0                                        Message URL  \
# 1           1  https://twitter.com/MiguelVallejoB2/statuses/1...
# 2           2  https://twitter.com/gnajjjj/statuses/150611684...
# 3           3  https://twitter.com/gnajjjj/statuses/150611611...
# 4           4  https://twitter.com/cassimskatelml/statuses/15...
# 5           5  https://twitter.com/ricardoms09/statuses/15061...
#
#    Count_negativo  Network          Profile                Date  \
# 1               0  Twitter  MiguelVallejoB2  3/21/2022 11:56 pm
# 2               0  Twitter          gnajjjj  3/21/2022 11:53 pm
# 3               0  Twitter          gnajjjj  3/21/2022 11:50 pm
# 4               0  Twitter   cassimskatelml  3/21/2022 11:49 pm
# 5               0  Twitter      ricardoms09  3/21/2022 11:49 pm
#
#                                              Message     Type Content Type  \
# 1  mikelegorreta @MigeGs58 @azucenau @Radio_Formu...  Mention    Text Only
# 2  En realidad todo complejo de inferioridad care...  Message         Link
# 3  No. Más bien porque un zoquete resentido quiso...  Message         Link
# 4  Clasistas nomás https://t.co/kyvelatrD7 | QT: ...  Message         Link
# 5  elnarrador Jajajajaja ¿ya se enojó? Resentido ...  Mention    Text Only
#
#    Followers  ...  Age Likes Dislikes  Comments  Shares     Theme  \
# 1         85  ...    0     0        0         0       0         0
# 2       1759  ...    0     7        0         2       0      Odio
# 3       1759  ...    0     4        0         0       0  Backlash
# 4        210  ...    0     0        0         0       0         0
# 5         95  ...    0     0        0         1       0  Backlash
#
#                                        Splitted  Estado    País Count
# 1                                    ['Mexico']       0       0     1
# 2  ['Colonia Lindavista', ' México', ' Mexico']  México  Mexico     1
# 3  ['Colonia Lindavista', ' México', ' Mexico']  México  Mexico     1
# 4                                    ['Mexico']       0       0     1
# 5         ['Casa Blanca', ' Puebla', ' Mexico']  Puebla  Mexico     1
#
# [5 rows x 23 columns]

# %%
base_marcada_discriminación = base_marcada[base_marcada["Count_negativo"] == 1]
base_autores = base_marcada_discriminación.groupby("Profile").sum()
base_autores
# Out:
#                  Unnamed: 0  Count_negativo  Followers  Engagements  Age  \
# Profile
# 2_xipa_                 631               1        216           18    0
# 308Jeannie             2129               1        136            0    0
# 555Kaliman              815               1       1263            0    0
# 7757Kami               1136               1        461            0    0
# 7828900d8314452         666               1         26            2    0
# ...                     ...             ...        ...          ...  ...
# yosoyMH                 606               1       2477            2    0
# z_z_uki                 836               1        621            1    0
# zapoteco               2126               1       1067            0    0
# zolzh                  2160               1        479            2    0
# zombiedarkelf          1186               2        440            1    0
#
#                  Likes  Dislikes  Comments  Shares  Count
# Profile
# 2_xipa_             12         0         3       3      1
# 308Jeannie           0         0         0       0      1
# 555Kaliman           0         0         0       0      1
# 7757Kami             0         0         0       0      1
# 7828900d8314452      2         0         0       0      1
# ...                ...       ...       ...     ...    ...
# yosoyMH              1         0         0       1      1
# z_z_uki              1         0         0       0      1
# zapoteco             0         0         0       0      1
# zolzh                2         0         0       0      1
# zombiedarkelf        1         0         0       0      2
#
# [457 rows x 10 columns]

# %%
pd.unique(base_autores["Count_negativo"])
# Out:
# array([ 1,  2,  3,  4,  5,  6, 33,  9])

# %%
base_autores.sort_values("Count_negativo", inplace=True, ascending=False)
base_autores.head(15)
# Out:
#                  Unnamed: 0  Count_negativo  Followers  Engagements  Age  \
# Profile
# JuampiSwan            37047              33      12045           24    0
# juan_wiechers50        7844               9         18           62    0
# VicMac123              5522               6      34878           28    0
# _FerLeonMex            9509               6        948            9    0
# ElRobDeLosAutos        5227               6       8232            3    0
# Jacquie_LHoist        10997               5     104525          852    0
# EdgarSimentalM         5704               5        720            4    0
# JoaqunValladar1        5214               4        776           12    0
# Cecilia66090812        5591               4        524            5    0
# Hiramtorres            7684               4      28272          101    0
# VilchisJuan1           4697               4        164            0    0
# carlocasno11141        3708               4        396            5    0
# TiinValentin           4259               4       4828           16    0
# Jo_ran_                2955               3       5940           18    0
# BalamMarlin            5742               3        747            2    0
#
#                  Likes  Dislikes  Comments  Shares  Count
# Profile
# JuampiSwan           2         0        22       0     33
# juan_wiechers50     49         0         1      12      9
# VicMac123           20         0         5       3      6
# _FerLeonMex          6         0         1       2      6
# ElRobDeLosAutos      1         0         2       0      6
# Jacquie_LHoist     675         0        31     146      5
# EdgarSimentalM       3         0         1       0      5
# JoaqunValladar1      5         0         0       7      4
# Cecilia66090812      3         0         2       0      4
# Hiramtorres         60         0        17      24      4
# VilchisJuan1         0         0         0       0      4
# carlocasno11141      1         0         4       0      4
# TiinValentin        14         0         2       0      4
# Jo_ran_             14         0         3       1      3
# BalamMarlin          0         0         2       0      3

# %%
palette = sns.color_palette("Reds",n_colors=15)
palette.reverse()
base_autores_discriminación = base_autores[0:15]
base_autores_discriminación.rename(inplace=True,  columns={"Count_negativo" : "Número de mensajes de discriminación"})
plt.figure(figsize=(15,8))
ax = sns.barplot(x=base_autores_discriminación.index,y=base_autores_discriminación["Número de mensajes de discriminación"],data=base_autores_discriminación, palette = palette)
for item in ax.get_xticklabels():
    item.set_rotation(90)
plt.show()
# Out:
# C:\Users\JOSE\anaconda3\envs\nltkenv\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
base_autores.sort_values("Engagements", inplace=True, ascending=False)
base_autores.head(15)
# Out:
#                  Unnamed: 0  Count_negativo  Followers  Engagements  Age  \
# Profile
# Jacquie_LHoist        10997               5     104525          852    0
# AlinaDuarte_           1979               1      54148          464    0
# OphCourse              1942               1     439668          411    0
# jet1403                1549               2      35102          305    0
# julietaetznab           551               1      21165          304    0
# alviruela               653               1      12703          226    0
# DrAntorse               687               1       2986          189    0
# ZuritaCarpio           1328               2      90730          181    0
# DavidSoteloR           2152               1        689          120    0
# Hiramtorres            7684               4      28272          101    0
# Chincoya_DuranG        1833               1        297           98    0
# varamburucano          2401               2      14172           83    0
# AriMariscal             820               1       1538           81    0
# SalmaLuevano           2204               1      13186           66    0
# svegaf                 5146               3      20922           64    0
#
#                  Likes  Dislikes  Comments  Shares  Count
# Profile
# Jacquie_LHoist     675         0        31     146      5
# AlinaDuarte_       335         0         9     120      1
# OphCourse          389         0         7      15      1
# jet1403            236         0         5      64      2
# julietaetznab      230         0         3      71      1
# alviruela          195         0         6      25      1
# DrAntorse          164         0         8      17      1
# ZuritaCarpio       140         0         4      37      2
# DavidSoteloR       106         0        14       0      1
# Hiramtorres         60         0        17      24      4
# Chincoya_DuranG     80         0         3      15      1
# varamburucano       71         0         4       8      2
# AriMariscal         77         0         3       1      1
# SalmaLuevano        21         0        45       0      1
# svegaf              56         0         4       4      3

# %%
base_autores_discriminación = base_autores[0:15]
#base_autores_discriminación.rename(inplace=True,  columns={"Count_negativo" : "Número de mensajes de discriminación"})
plt.figure(figsize=(15,8))
base_autores_discriminación.rename(inplace=True,  columns={"Engagements" : "Engagements de mensajes de discriminación"})
ax = sns.barplot(x=base_autores_discriminación.index,y=base_autores_discriminación["Engagements de mensajes de discriminación"],data=base_autores_discriminación, palette = palette)
for item in ax.get_xticklabels():
    item.set_rotation(90)
plt.show()

# %%
# Base de datos publicaciones con mas engagement
base_marcada_discriminación = base_marcada[base_marcada["Count_negativo"] == 1]
base_marcada_discriminación.sort_values("Engagements", inplace=True, ascending=False)
base_marcada_discriminación
# Out:
# C:\Users\JOSE\anaconda3\envs\nltkenv\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#       Unnamed: 0                                        Message URL  \
# 2211        2211  https://twitter.com/Jacquie_LHoist/statuses/15...
# 1979        1979  https://twitter.com/AlinaDuarte_/statuses/1508...
# 1942        1942  https://twitter.com/OphCourse/statuses/1509005...
# 551          551  https://twitter.com/julietaetznab/statuses/150...
# 722          722  https://twitter.com/jet1403/statuses/150375548...
# ...          ...                                                ...
# 1939        1939  https://twitter.com/CerezacCampos/statuses/150...
# 1937        1937  https://twitter.com/juan_wiechers50/statuses/1...
# 591          591  https://twitter.com/JuampiSwan/statuses/150440...
# 1933        1933  https://twitter.com/Omar84249207/statuses/1509...
# 17            17  https://twitter.com/emmeee25/statuses/15061109...
#
#       Count_negativo  Network          Profile                Date  \
# 2211               1  Twitter   Jacquie_LHoist   3/27/2022 1:30 pm
# 1979               1  Twitter     AlinaDuarte_   3/29/2022 3:06 pm
# 1942               1  Twitter        OphCourse  3/29/2022 11:10 pm
# 551                1  Twitter    julietaetznab   3/17/2022 3:12 pm
# 722                1  Twitter          jet1403  3/15/2022 11:30 am
# ...              ...      ...              ...                 ...
# 1939               1  Twitter    CerezacCampos  3/29/2022 11:25 pm
# 1937               1  Twitter  juan_wiechers50  3/29/2022 11:57 pm
# 591                1  Twitter       JuampiSwan   3/17/2022 6:12 am
# 1933               1  Twitter     Omar84249207  3/30/2022 12:23 am
# 17                 1  Twitter         emmeee25  3/21/2022 11:30 pm
#
#                                                 Message     Type Content Type  \
# 2211  Como expresidenta y fundadora de @COPRED_CDMX ...  Message    Text Only
# 1979  Una pensaría que sería a través de movilizacio...  Message    Text Only
# 1942  Como sea, LOS VEO. En unos meses llorando porq...  Mention    Text Only
# 551   Defensores de los derechos humanos en defensa ...  Message    Text Only
# 722   En algo tiene razón   @EVerastegui La visión d...  Message    Text Only
# ...                                                 ...      ...          ...
# 1939  Los chairos Hipócritas son los Clasistas, Raci...  Message         Link
# 1937  El_Universal_Mx Esta ardido como siempre que e...  Mention    Text Only
# 591   BroHetCurioso @rompelavabos Al usar el término...  Mention    Text Only
# 1933  GlezRR @StarbucksMex Lo que estás haciendo es ...  Mention    Text Only
# 17      Jajajaja siempre amaré la palabra naco, idk why  Message    Text Only
#
#       Followers  ...  Age Likes Dislikes  Comments  Shares  Theme  \
# 2211      20905  ...    0   540        0        26     120      0
# 1979      54148  ...    0   335        0         9     120      0
# 1942     439668  ...    0   389        0         7      15      0
# 551       21165  ...    0   230        0         3      71      0
# 722       17551  ...    0   182        0         4      47      0
# ...         ...  ...  ...   ...      ...       ...     ...    ...
# 1939        711  ...    0     0        0         0       0      0
# 1937          2  ...    0     0        0         0       0      0
# 591         365  ...    0     0        0         0       0      0
# 1933        122  ...    0     0        0         0       0      0
# 17          107  ...    0     0        0         0       0   Odio
#
#                                                Splitted       Estado    País  \
# 2211            ['Coyoacan', ' Mexico City', ' Mexico']  Mexico City  Mexico
# 1979          ['Cuauhtemoc', ' Mexico City', ' Mexico']  Mexico City  Mexico
# 1942   ['Colonia del Valle', ' Mexico City', ' Mexico']  Mexico City  Mexico
# 551           ['Cuauhtemoc', ' Mexico City', ' Mexico']  Mexico City  Mexico
# 722       ['Miguel Hidalgo', ' Mexico City', ' Mexico']  Mexico City  Mexico
# ...                                                 ...          ...     ...
# 1939                                         ['Mexico']            0       0
# 1937          ['Jesus del Monte', ' México', ' Mexico']       México  Mexico
# 591   ['Magdalena Contreras', ' Mexico City', ' Mexi...  Mexico City  Mexico
# 1933          ['Cuauhtemoc', ' Mexico City', ' Mexico']  Mexico City  Mexico
# 17       ['Xalapa de Enriquez', ' Veracruz', ' Mexico']     Veracruz  Mexico
#
#      Count
# 2211     1
# 1979     1
# 1942     1
# 551      1
# 722      1
# ...    ...
# 1939     1
# 1937     1
# 591      1
# 1933     1
# 17       1
#
# [615 rows x 23 columns]

# %%
base_marcada_discriminación = base_marcada_discriminación[0:10]
base_marcada_discriminación
# Out:
#       Unnamed: 0                                        Message URL  \
# 2211        2211  https://twitter.com/Jacquie_LHoist/statuses/15...
# 1979        1979  https://twitter.com/AlinaDuarte_/statuses/1508...
# 1942        1942  https://twitter.com/OphCourse/statuses/1509005...
# 551          551  https://twitter.com/julietaetznab/statuses/150...
# 722          722  https://twitter.com/jet1403/statuses/150375548...
# 653          653  https://twitter.com/alviruela/statuses/1504094...
# 687          687  https://twitter.com/DrAntorse/statuses/1503856...
# 538          538  https://twitter.com/ZuritaCarpio/statuses/1504...
# 2152        2152  https://twitter.com/DavidSoteloR/statuses/1508...
# 1833        1833  https://twitter.com/Chincoya_DuranG/statuses/1...
#
#       Count_negativo  Network          Profile                Date  \
# 2211               1  Twitter   Jacquie_LHoist   3/27/2022 1:30 pm
# 1979               1  Twitter     AlinaDuarte_   3/29/2022 3:06 pm
# 1942               1  Twitter        OphCourse  3/29/2022 11:10 pm
# 551                1  Twitter    julietaetznab   3/17/2022 3:12 pm
# 722                1  Twitter          jet1403  3/15/2022 11:30 am
# 653                1  Twitter        alviruela   3/16/2022 9:56 am
# 687                1  Twitter        DrAntorse   3/15/2022 6:12 pm
# 538                1  Twitter     ZuritaCarpio   3/17/2022 4:35 pm
# 2152               1  Twitter     DavidSoteloR  3/28/2022 12:09 am
# 1833               1  Twitter  Chincoya_DuranG  3/31/2022 11:14 am
#
#                                                 Message     Type Content Type  \
# 2211  Como expresidenta y fundadora de @COPRED_CDMX ...  Message    Text Only
# 1979  Una pensaría que sería a través de movilizacio...  Message    Text Only
# 1942  Como sea, LOS VEO. En unos meses llorando porq...  Mention    Text Only
# 551   Defensores de los derechos humanos en defensa ...  Message    Text Only
# 722   En algo tiene razón   @EVerastegui La visión d...  Message    Text Only
# 653   ChumelTorres Otra paradoja de la derecha: Prom...  Mention    Text Only
# 687   Los casos no habían permitido aplicar la persp...  Message    Text Only
# 538   En realidad se le acusa de privación ilegal de...  Message         Link
# 2152  LeonKrauze En forma cobarde y alevosa un actor...  Mention    Text Only
# 1833  Cómo primer legislador No Binario en el Congre...  Message        Photo
#
#       Followers  ...  Age Likes Dislikes  Comments  Shares   Theme  \
# 2211      20905  ...    0   540        0        26     120       0
# 1979      54148  ...    0   335        0         9     120       0
# 1942     439668  ...    0   389        0         7      15       0
# 551       21165  ...    0   230        0         3      71       0
# 722       17551  ...    0   182        0         4      47       0
# 653       12703  ...    0   195        0         6      25       0
# 687        2986  ...    0   164        0         8      17  Género
# 538       45365  ...    0   128        0         3      35       0
# 2152        689  ...    0   106        0        14       0       0
# 1833        297  ...    0    80        0         3      15       0
#
#                                               Splitted       Estado    País  \
# 2211           ['Coyoacan', ' Mexico City', ' Mexico']  Mexico City  Mexico
# 1979         ['Cuauhtemoc', ' Mexico City', ' Mexico']  Mexico City  Mexico
# 1942  ['Colonia del Valle', ' Mexico City', ' Mexico']  Mexico City  Mexico
# 551          ['Cuauhtemoc', ' Mexico City', ' Mexico']  Mexico City  Mexico
# 722      ['Miguel Hidalgo', ' Mexico City', ' Mexico']  Mexico City  Mexico
# 653           ['El Pueblito', ' Querétaro', ' Mexico']    Querétaro  Mexico
# 687         ['Pachuca de Soto', ' Hidalgo', ' Mexico']      Hidalgo  Mexico
# 538            ['Villahermosa', ' Tabasco', ' Mexico']      Tabasco  Mexico
# 2152                                        ['Mexico']            0       0
# 1833            ['Banderilla', ' Veracruz', ' Mexico']     Veracruz  Mexico
#
#      Count
# 2211     1
# 1979     1
# 1942     1
# 551      1
# 722      1
# 653      1
# 687      1
# 538      1
# 2152     1
# 1833     1
#
# [10 rows x 23 columns]

# %%
base_marcada_discriminación.to_excel("Top_10_mensajes_de_discriminacion_engagements.xlsx")

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import pandas as pd
from io import StringIO
base_graficas = pd.read_excel("Base_grafica_barras.xlsx")
base_graficas.sort_values("Count_negativo", inplace=True, ascending=False)
base_graficas['Total_Nacional'] = base_graficas['Count'].sum()
base_graficas['Participación % Nacional'] = base_graficas['Count']/base_graficas['Total_Nacional']
base_graficas['Total_Nacional_Negativo'] = base_graficas['Count_negativo'].sum()
base_graficas
# Out:
#     Unnamed: 0           Estado     Estado_copia  Count  Count_negativo  \
# 0            9      Mexico City      Mexico City    224              90
# 1           12           México           México     97              45
# 2           14       Nuevo León       Nuevo León     68              41
# 3            8          Jalisco          Jalisco     76              35
# 4           20           Sonora           Sonora     31              20
# 5           17        Querétaro        Querétaro     31              14
# 6           16           Puebla           Puebla     23              12
# 7            5       Guanajuato       Guanajuato     23              10
# 8           11          Morelos          Morelos     25               8
# 9            0   Aguascalientes   Aguascalientes     12               7
# 10           1  Baja California  Baja California     13               5
# 11           6         Guerrero         Guerrero     12               5
# 15          19          Sinaloa          Sinaloa      7               4
# 16          21          Tabasco          Tabasco      7               4
# 13          25          Yucatán          Yucatán     13               4
# 14          18  San Luis Potosí  San Luis Potosí      4               4
# 12          24         Veracruz         Veracruz     13               4
# 17          15           Oaxaca           Oaxaca     11               3
# 18           4           Colima           Colima      5               3
# 19          23         Tlaxcala         Tlaxcala      4               3
# 20           7          Hidalgo          Hidalgo      4               2
# 21          10        Michoacán        Michoacán     11               1
# 22           2          Chiapas          Chiapas      6               1
# 23          22       Tamaulipas       Tamaulipas      3               1
# 24          13          Nayarit          Nayarit      1               0
# 25           3         Coahuila         Coahuila      4               0
# 26          26        Zacatecas        Zacatecas      3               0
#
#     % Odio Nacional  % Odio Regional  Total_Nacional  \
# 0          0.276074         0.401786             731
# 1          0.138037         0.463918             731
# 2          0.125767         0.602941             731
# 3          0.107362         0.460526             731
# 4          0.061350         0.645161             731
# 5          0.042945         0.451613             731
# 6          0.036810         0.521739             731
# 7          0.030675         0.434783             731
# 8          0.024540         0.320000             731
# 9          0.021472         0.583333             731
# 10         0.015337         0.384615             731
# 11         0.015337         0.416667             731
# 15         0.012270         0.571429             731
# 16         0.012270         0.571429             731
# 13         0.012270         0.307692             731
# 14         0.012270         1.000000             731
# 12         0.012270         0.307692             731
# 17         0.009202         0.272727             731
# 18         0.009202         0.600000             731
# 19         0.009202         0.750000             731
# 20         0.006135         0.500000             731
# 21         0.003067         0.090909             731
# 22         0.003067         0.166667             731
# 23         0.003067         0.333333             731
# 24         0.000000         0.000000             731
# 25         0.000000         0.000000             731
# 26         0.000000         0.000000             731
#
#     Participación % Nacional  Total_Nacional_Negativo
# 0                   0.306430                      326
# 1                   0.132695                      326
# 2                   0.093023                      326
# 3                   0.103967                      326
# 4                   0.042408                      326
# 5                   0.042408                      326
# 6                   0.031464                      326
# 7                   0.031464                      326
# 8                   0.034200                      326
# 9                   0.016416                      326
# 10                  0.017784                      326
# 11                  0.016416                      326
# 15                  0.009576                      326
# 16                  0.009576                      326
# 13                  0.017784                      326
# 14                  0.005472                      326
# 12                  0.017784                      326
# 17                  0.015048                      326
# 18                  0.006840                      326
# 19                  0.005472                      326
# 20                  0.005472                      326
# 21                  0.015048                      326
# 22                  0.008208                      326
# 23                  0.004104                      326
# 24                  0.001368                      326
# 25                  0.005472                      326
# 26                  0.004104                      326

# %%
base_graficas = base_graficas[0:5]
base_graficas.drop(columns = ["Estado_copia"], inplace=True)
base_graficas
# Out:
# C:\Users\usuario\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    Unnamed: 0       Estado  Count  Count_negativo  % Odio Nacional  \
# 0           9  Mexico City    224              90         0.276074
# 1          12       México     97              45         0.138037
# 2          14   Nuevo León     68              41         0.125767
# 3           8      Jalisco     76              35         0.107362
# 4          20       Sonora     31              20         0.061350
#
#    % Odio Regional  Total_Nacional  Participación % Nacional  \
# 0         0.401786             731                  0.306430
# 1         0.463918             731                  0.132695
# 2         0.602941             731                  0.093023
# 3         0.460526             731                  0.103967
# 4         0.645161             731                  0.042408
#
#    Total_Nacional_Negativo
# 0                      326
# 1                      326
# 2                      326
# 3                      326
# 4                      326

# %%
x_ = base_graficas.columns[1]
y_ = base_graficas.columns[4]
y_2 = base_graficas.columns[7]
data1 = base_graficas[[x_, y_]]
data2 = base_graficas[[x_, y_2]]
plt.figure(figsize=(15,8))
ax = sns.barplot(x=x_,y=y_,data=data1)
width_scale = 0.45
for bar in ax.containers[0]:
    bar.set_width(bar.get_width() * width_scale)
ax.yaxis.set_major_formatter(PercentFormatter(1))
ax.figure.text(0.4, 0,'Nota: Las columnas corresponden con los ejes. Fuente: Elaboración propia con datos de Sproutsocial.', fontsize=12)
ax.grid(False)
ax2 = ax.twinx()
sns.barplot(x=x_,y=y_2,data=data2,alpha=0.7,hatch='xx',ax=ax2)
for bar in ax2.containers[0]:
    x = bar.get_x()
    w = bar.get_width()
    bar.set_x(x + w * (1 - width_scale))
    bar.set_width(w *  width_scale)
ax2.grid(False)
plt.savefig("out.png") 
plt.show()
