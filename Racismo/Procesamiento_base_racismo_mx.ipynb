# %% [markdown]
# # Generación de base para el mapa

# %%
import numpy as np
import pandas as pd

# %%
base_1 = pd.read_csv("mensajes_7_feb_16_feb.csv")
base_2 = pd.read_csv("mensajes_17_feb_28_feb.csv")
base_racismo = base_1.append(base_2)
base_racismo['Count'] = 1
base_racismo
# Out:
#      Network                                        Message URL  \
# 0    Twitter  https://twitter.com/Padawanmx/statuses/1494174...
# 1    Twitter  https://twitter.com/leo_poblete/statuses/14941...
# 2    Twitter  https://twitter.com/DiversidadCDMX/statuses/14...
# 3    Twitter  https://twitter.com/mavagomez_/statuses/149416...
# 4    Twitter  https://twitter.com/mavagomez_/statuses/149416...
# ..       ...                                                ...
# 948  Twitter  https://twitter.com/josephmendez4/statuses/149...
# 949  Twitter  https://twitter.com/Rideonbeat/statuses/149418...
# 950  Twitter  https://twitter.com/dandrestruction/statuses/1...
# 951  Twitter  https://twitter.com/narudordnajela/statuses/14...
# 952  Twitter  https://twitter.com/ren_candia/statuses/149417...
#
#              Profile                Date  \
# 0          Padawanmx  2/16/2022 11:57 pm
# 1        leo_poblete  2/16/2022 11:43 pm
# 2     DiversidadCDMX  2/16/2022 11:37 pm
# 3         mavagomez_  2/16/2022 11:35 pm
# 4         mavagomez_  2/16/2022 11:33 pm
# ..               ...                 ...
# 948    josephmendez4  2/17/2022 12:49 am
# 949       Rideonbeat  2/17/2022 12:46 am
# 950  dandrestruction  2/17/2022 12:42 am
# 951   narudordnajela  2/17/2022 12:25 am
# 952       ren_candia  2/17/2022 12:11 am
#
#                                                Message     Type Content Type  \
# 0    Como sabes que un twittero es un pendejo?\n\nU...  Message         Link
# 1    Agradezco el apoyo de @FiscaliaCDMX, y del gob...  Message         Link
# 2    #Entérate La @FiscaliaCDMX vinculó a proceso a...  Message    Text Only
# 3    Que rabia me da ver a gente racista, sexista, ...  Message    Text Only
# 4    Fernandcc El racismo no es una opinión, es ign...  Mention    Text Only
# ..                                                 ...      ...          ...
# 948                           Todo es clasismo ahora 🤣  Message    Text Only
# 949  JotaKMaldonado1 De morro me gustaba, no había ...  Mention    Text Only
# 950  Pobre de la gringa, solo dijo que le mamaba la...  Message         Link
# 951  SergioSarmiento @M_OlgaSCordero Miserable clas...  Mention    Text Only
# 952  A los PANIAGUADOS CLASISTAS!! https://t.co/7Px...  Message         Link
#
#      Followers  Engagements                                Location Gender  \
# 0         1836            1             Cuernavaca, Morelos, Mexico    Men
# 1          344           13     Naucalpan de Juarez, México, Mexico    Men
# 2         6653          102  Colonia del Valle, Mexico City, Mexico    NaN
# 3        21280           97  Los Angeles, California, United States  Women
# 4        21280            3  Los Angeles, California, United States  Women
# ..         ...          ...                                     ...    ...
# 948        370            2                                Honduras    Men
# 949       1910            1  San Francisco Acuautla, México, Mexico    NaN
# 950         67            1                Ecatepec, México, Mexico    NaN
# 951        659            0   Las Delicias, Baja California, Mexico    NaN
# 952        469            0    Xalapa de Enriquez, Veracruz, Mexico    NaN
#
#      Age  Likes  Dislikes  Comments  Shares Theme  Count
# 0    NaN      1         0         0       0   NaN      1
# 1    NaN      9         0         1       3   NaN      1
# 2    NaN     67         0         1      34   NaN      1
# 3    NaN     93         0         0       4   NaN      1
# 4    NaN      2         0         1       0   NaN      1
# ..   ...    ...       ...       ...     ...   ...    ...
# 948  NaN      1         0         1       0   NaN      1
# 949  NaN      1         0         0       0   NaN      1
# 950  NaN      1         0         0       0   NaN      1
# 951  NaN      0         0         0       0   NaN      1
# 952  NaN      0         0         0       0   NaN      1
#
# [1691 rows x 18 columns]

# %%
base_negativa = pd.read_csv("mensajes_negativos_7_feb_28_feb.csv")
base_negativa['Count_negativo'] = 1
base_negativa.rename({"Followers": "Followers_negativo",	"Engagements": "Engagements_negativo", "Age":"Age_negativo", "Likes":"Likes_negativos",	
                      "Dislikes":"Dislikes_negativo",	"Comments":"Comments_negativo",	"Shares":"Shares_negativo"}, inplace=True, axis=1)
base_negativa
# Out:
#      Network                                        Message URL  \
# 0    Twitter  https://twitter.com/elcacabonita/statuses/1498...
# 1    Twitter  https://twitter.com/AxelGar56163124/statuses/1...
# 2    Twitter  https://twitter.com/jvalenci777/statuses/14985...
# 3    Twitter  https://twitter.com/Clau07Rocha/statuses/14985...
# 4    Twitter  https://twitter.com/Omttl83/statuses/149850127...
# ..       ...                                                ...
# 821  Twitter  https://twitter.com/raticio/statuses/149078884...
# 822  Twitter  https://twitter.com/Andres_Vingback/statuses/1...
# 823  Twitter  https://twitter.com/VilchisJuan1/statuses/1490...
# 824  Twitter  https://twitter.com/sirfelipon/statuses/149076...
# 825  Twitter  https://twitter.com/edavidmtzm/statuses/149076...
#
#              Profile                Date  \
# 0       elcacabonita  2/28/2022 11:39 pm
# 1    AxelGar56163124  2/28/2022 11:23 pm
# 2        jvalenci777  2/28/2022 11:16 pm
# 3        Clau07Rocha  2/28/2022 10:45 pm
# 4            Omttl83  2/28/2022 10:31 pm
# ..               ...                 ...
# 821          raticio    2/7/2022 3:45 pm
# 822  Andres_Vingback    2/7/2022 3:42 pm
# 823     VilchisJuan1    2/7/2022 3:07 pm
# 824       sirfelipon    2/7/2022 2:19 pm
# 825       edavidmtzm    2/7/2022 2:13 pm
#
#                                                Message     Type Content Type  \
# 0    Sus comentarios bien racistas de los del bar "...  Message    Text Only
# 1    jose5anchez Ni que ir a dormir maldito racista...  Mention        Photo
# 2    HoracioFranco @casa_lamm @_VicenteSerrano El m...  Mention    Text Only
# 3    bbcmundo Que triste 😢 cuándo dejarán de ver el...  Mention    Text Only
# 4    Tenía razón super Vlad, racistas, clasistas y ...  Message        Photo
# ..                                                 ...      ...          ...
# 821          yandellcr Cuidado lo demandan por racismo  Mention    Text Only
# 822  baritonoluna @OficialFrenaaa @gilbertolozanog ...  Mention    Text Only
# 823  Faitelson_ESPN Mexicanos. De verdad no sé Dan ...  Mention        Photo
# 824  #FelizLunes #FelizInicioDeSemanaLaboral y en F...  Message        Video
# 825  igrecf no sé que fue más clasista, que me lo d...  Mention    Text Only
#
#      Followers_negativo  Engagements_negativo  \
# 0                  1705                     1
# 1                   394                     2
# 2                  3345                     0
# 3                    91                    12
# 4                    20                     0
# ..                  ...                   ...
# 821                2130                     2
# 822                 354                     2
# 823                  41                     3
# 824                 234                     1
# 825                1027                     3
#
#                                      Location Gender  Age_negativo  \
# 0           Nacogdoches, Texas, United States    NaN           NaN
# 1                                   Guatemala    NaN           NaN
# 2         Naucalpan de Juarez, México, Mexico    NaN           NaN
# 3    Magdalena Contreras, Mexico City, Mexico    NaN           NaN
# 4       Ciudad Nezahualcoyotl, México, Mexico    NaN           NaN
# ..                                        ...    ...           ...
# 821                                Costa Rica    NaN           NaN
# 822                                    Mexico    Men           NaN
# 823    Santa Rosa Jauregui, Querétaro, Mexico    Men           NaN
# 824      Mejicanos, San Salvador, El Salvador  Women           NaN
# 825       Miguel Hidalgo, Mexico City, Mexico    Men           NaN
#
#      Likes_negativos  Dislikes_negativo  Comments_negativo  Shares_negativo  \
# 0                  1                  0                  0                0
# 1                  1                  0                  1                0
# 2                  0                  0                  0                0
# 3                 12                  0                  0                0
# 4                  0                  0                  0                0
# ..               ...                ...                ...              ...
# 821                2                  0                  0                0
# 822                0                  0                  2                0
# 823                3                  0                  0                0
# 824                1                  0                  0                0
# 825                3                  0                  0                0
#
#               Theme  Count_negativo
# 0               NaN               1
# 1               NaN               1
# 2               NaN               1
# 3               NaN               1
# 4               NaN               1
# ..              ...             ...
# 821             NaN               1
# 822        Backlash               1
# 823             NaN               1
# 824  Sexodiversidad               1
# 825             NaN               1
#
# [826 rows x 18 columns]

# %%
base_agrupada = base_racismo.groupby('Location').sum()
base_agrupada['Splitted'] = base_agrupada.index.str.split(',')
base_agrupada.loc[:, 'Ciudad'] = base_agrupada.Splitted.map(lambda x: x[0])
try:
    base_agrupada.loc[:, 'Estado'] = base_agrupada.Splitted.str[1].str.strip()
    base_agrupada.loc[:, 'País'] = base_agrupada.Splitted.str[2].str.strip()
    base_agrupada.drop('Splitted', inplace=True, axis=1)
    base_agrupada_mexico_positiva = base_agrupada[base_agrupada['País'] == "Mexico"]
except:
    print("Do Nothing")
base_agrupada_mexico_positiva
# Out:
#                                         Followers  Engagements  Age  Likes  \
# Location
# Acambaro, Guanajuato, Mexico                   89            0  0.0      0
# Acapulco de Juarez, Guerrero, Mexico        35443           51  0.0     40
# Aguascalientes, Aguascalientes, Mexico      12567            9  0.0      6
# Amozoc de Mota, Puebla, Mexico                193            0  0.0      0
# Apodaca, Nuevo León, Mexico                  5399           89  0.0     73
# ...                                           ...          ...  ...    ...
# Xalapa de Enriquez, Veracruz, Mexico         1546            7  0.0      6
# Xochimilco, Mexico City, Mexico             12941           17  0.0     13
# Zacatecas, Zacatecas, Mexico                 2212           10  0.0      7
# Zacatelco, Tlaxcala, Mexico                     1            0  0.0      0
# Zapopan, Jalisco, Mexico                    14362            4  0.0      2
#
#                                         Dislikes  Comments  Shares  Count  \
# Location
# Acambaro, Guanajuato, Mexico                   0         0       0      1
# Acapulco de Juarez, Guerrero, Mexico           0         4       7     10
# Aguascalientes, Aguascalientes, Mexico         0         3       0     14
# Amozoc de Mota, Puebla, Mexico                 0         0       0      1
# Apodaca, Nuevo León, Mexico                    0        11       5      5
# ...                                          ...       ...     ...    ...
# Xalapa de Enriquez, Veracruz, Mexico           0         1       0      4
# Xochimilco, Mexico City, Mexico                0         1       3      5
# Zacatecas, Zacatecas, Mexico                   0         3       0      2
# Zacatelco, Tlaxcala, Mexico                    0         0       0      1
# Zapopan, Jalisco, Mexico                       0         2       0      2
#
#                                                     Ciudad          Estado  \
# Location
# Acambaro, Guanajuato, Mexico                      Acambaro      Guanajuato
# Acapulco de Juarez, Guerrero, Mexico    Acapulco de Juarez        Guerrero
# Aguascalientes, Aguascalientes, Mexico      Aguascalientes  Aguascalientes
# Amozoc de Mota, Puebla, Mexico              Amozoc de Mota          Puebla
# Apodaca, Nuevo León, Mexico                        Apodaca      Nuevo León
# ...                                                    ...             ...
# Xalapa de Enriquez, Veracruz, Mexico    Xalapa de Enriquez        Veracruz
# Xochimilco, Mexico City, Mexico                 Xochimilco     Mexico City
# Zacatecas, Zacatecas, Mexico                     Zacatecas       Zacatecas
# Zacatelco, Tlaxcala, Mexico                      Zacatelco        Tlaxcala
# Zapopan, Jalisco, Mexico                           Zapopan         Jalisco
#
#                                           País
# Location
# Acambaro, Guanajuato, Mexico            Mexico
# Acapulco de Juarez, Guerrero, Mexico    Mexico
# Aguascalientes, Aguascalientes, Mexico  Mexico
# Amozoc de Mota, Puebla, Mexico          Mexico
# Apodaca, Nuevo León, Mexico             Mexico
# ...                                        ...
# Xalapa de Enriquez, Veracruz, Mexico    Mexico
# Xochimilco, Mexico City, Mexico         Mexico
# Zacatecas, Zacatecas, Mexico            Mexico
# Zacatelco, Tlaxcala, Mexico             Mexico
# Zapopan, Jalisco, Mexico                Mexico
#
# [139 rows x 11 columns]

# %%
base_agrupada = base_negativa.groupby('Location').sum()
base_agrupada['Splitted'] = base_agrupada.index.str.split(',')
base_agrupada.loc[:, 'Ciudad'] = base_agrupada.Splitted.map(lambda x: x[0])
try:
    base_agrupada.loc[:, 'Estado'] = base_agrupada.Splitted.str[1].str.strip()
    base_agrupada.loc[:, 'País'] = base_agrupada.Splitted.str[2].str.strip()
    base_agrupada.drop('Splitted', inplace=True, axis=1)
    base_agrupada_mexico_negativa = base_agrupada[base_agrupada['País'] == "Mexico"]
except:
    print("Do Nothing")
base_agrupada_mexico_negativa
# Out:
#                                         Followers_negativo  \
# Location
# Acambaro, Guanajuato, Mexico                            89
# Acapulco de Juarez, Guerrero, Mexico                 27297
# Aguascalientes, Aguascalientes, Mexico                1322
# Amozoc de Mota, Puebla, Mexico                         193
# Apodaca, Nuevo León, Mexico                           2967
# ...                                                    ...
# Villahermosa, Tabasco, Mexico                         7936
# Xalapa de Enriquez, Veracruz, Mexico                  1070
# Xochimilco, Mexico City, Mexico                        129
# Zacatecas, Zacatecas, Mexico                          2212
# Zacatelco, Tlaxcala, Mexico                              1
#
#                                         Engagements_negativo  Age_negativo  \
# Location
# Acambaro, Guanajuato, Mexico                               0           0.0
# Acapulco de Juarez, Guerrero, Mexico                      44           0.0
# Aguascalientes, Aguascalientes, Mexico                     2           0.0
# Amozoc de Mota, Puebla, Mexico                             0           0.0
# Apodaca, Nuevo León, Mexico                               82           0.0
# ...                                                      ...           ...
# Villahermosa, Tabasco, Mexico                              4           0.0
# Xalapa de Enriquez, Veracruz, Mexico                       6           0.0
# Xochimilco, Mexico City, Mexico                            2           0.0
# Zacatecas, Zacatecas, Mexico                              10           0.0
# Zacatelco, Tlaxcala, Mexico                                0           0.0
#
#                                         Likes_negativos  Dislikes_negativo  \
# Location
# Acambaro, Guanajuato, Mexico                          0                  0
# Acapulco de Juarez, Guerrero, Mexico                 36                  0
# Aguascalientes, Aguascalientes, Mexico                1                  0
# Amozoc de Mota, Puebla, Mexico                        0                  0
# Apodaca, Nuevo León, Mexico                          69                  0
# ...                                                 ...                ...
# Villahermosa, Tabasco, Mexico                         4                  0
# Xalapa de Enriquez, Veracruz, Mexico                  5                  0
# Xochimilco, Mexico City, Mexico                       1                  0
# Zacatecas, Zacatecas, Mexico                          7                  0
# Zacatelco, Tlaxcala, Mexico                           0                  0
#
#                                         Comments_negativo  Shares_negativo  \
# Location
# Acambaro, Guanajuato, Mexico                            0                0
# Acapulco de Juarez, Guerrero, Mexico                    4                4
# Aguascalientes, Aguascalientes, Mexico                  1                0
# Amozoc de Mota, Puebla, Mexico                          0                0
# Apodaca, Nuevo León, Mexico                             9                4
# ...                                                   ...              ...
# Villahermosa, Tabasco, Mexico                           0                0
# Xalapa de Enriquez, Veracruz, Mexico                    1                0
# Xochimilco, Mexico City, Mexico                         0                1
# Zacatecas, Zacatecas, Mexico                            3                0
# Zacatelco, Tlaxcala, Mexico                             0                0
#
#                                         Count_negativo              Ciudad  \
# Location
# Acambaro, Guanajuato, Mexico                         1            Acambaro
# Acapulco de Juarez, Guerrero, Mexico                 7  Acapulco de Juarez
# Aguascalientes, Aguascalientes, Mexico               8      Aguascalientes
# Amozoc de Mota, Puebla, Mexico                       1      Amozoc de Mota
# Apodaca, Nuevo León, Mexico                          3             Apodaca
# ...                                                ...                 ...
# Villahermosa, Tabasco, Mexico                        3        Villahermosa
# Xalapa de Enriquez, Veracruz, Mexico                 2  Xalapa de Enriquez
# Xochimilco, Mexico City, Mexico                      3          Xochimilco
# Zacatecas, Zacatecas, Mexico                         2           Zacatecas
# Zacatelco, Tlaxcala, Mexico                          1           Zacatelco
#
#                                                 Estado    País
# Location
# Acambaro, Guanajuato, Mexico                Guanajuato  Mexico
# Acapulco de Juarez, Guerrero, Mexico          Guerrero  Mexico
# Aguascalientes, Aguascalientes, Mexico  Aguascalientes  Mexico
# Amozoc de Mota, Puebla, Mexico                  Puebla  Mexico
# Apodaca, Nuevo León, Mexico                 Nuevo León  Mexico
# ...                                                ...     ...
# Villahermosa, Tabasco, Mexico                  Tabasco  Mexico
# Xalapa de Enriquez, Veracruz, Mexico          Veracruz  Mexico
# Xochimilco, Mexico City, Mexico            Mexico City  Mexico
# Zacatecas, Zacatecas, Mexico                 Zacatecas  Mexico
# Zacatelco, Tlaxcala, Mexico                   Tlaxcala  Mexico
#
# [100 rows x 11 columns]

# %%
base_agrupada_estados_mexico_positiva = base_agrupada_mexico_positiva.groupby("Estado").sum()
base_agrupada_estados_mexico_negativa = base_agrupada_mexico_negativa.groupby("Estado").sum()
base_agrupada_estados_mexico = pd.merge(left=base_agrupada_estados_mexico_negativa, right=base_agrupada_estados_mexico_positiva, right_on=base_agrupada_estados_mexico_positiva.index , left_on=base_agrupada_estados_mexico_negativa.index, how='inner')
base_agrupada_estados_mexico
# Out:
#               key_0  Followers_negativo  Engagements_negativo  Age_negativo  \
# 0    Aguascalientes                1335                     9           0.0
# 1   Baja California                1496                     2           0.0
# 2           Chiapas                 495                     2           0.0
# 3          Coahuila                6760                     3           0.0
# 4            Colima                6305                     1           0.0
# 5        Guanajuato                3434                     1           0.0
# 6          Guerrero               27297                    44           0.0
# 7           Hidalgo                 759                     5           0.0
# 8           Jalisco               31736                   177           0.0
# 9       Mexico City              155154                  1224           0.0
# 10        Michoacán                1029                     6           0.0
# 11          Morelos                2928                     9           0.0
# 12           México               69417                   137           0.0
# 13          Nayarit                  45                     0           0.0
# 14       Nuevo León               41759                   198           0.0
# 15           Oaxaca               30294                    27           0.0
# 16           Puebla                5775                    20           0.0
# 17        Querétaro               75936                    39           0.0
# 18  San Luis Potosí                 124                     1           0.0
# 19          Sinaloa                5899                    25           0.0
# 20           Sonora               30025                    45           0.0
# 21          Tabasco                9336                    30           0.0
# 22       Tamaulipas                   2                     1           0.0
# 23         Tlaxcala                 876                     3           0.0
# 24         Veracruz                7187                    23           0.0
# 25          Yucatán               38470                    28           0.0
# 26        Zacatecas                2212                    10           0.0
#
#     Likes_negativos  Dislikes_negativo  Comments_negativo  Shares_negativo  \
# 0                 7                  0                  1                1
# 1                 1                  0                  1                0
# 2                 2                  0                  0                0
# 3                 2                  0                  1                0
# 4                 0                  0                  1                0
# 5                 1                  0                  0                0
# 6                36                  0                  4                4
# 7                 2                  0                  2                1
# 8               152                  0                 17                8
# 9               875                  0                 86              263
# 10                3                  0                  0                3
# 11                7                  0                  2                0
# 12              100                  0                 11               26
# 13                0                  0                  0                0
# 14              155                  0                 28               15
# 15               18                  0                  6                3
# 16               16                  0                  2                2
# 17               28                  0                  5                6
# 18                1                  0                  0                0
# 19               20                  0                  1                4
# 20               35                  0                  9                1
# 21               21                  0                  1                8
# 22                0                  0                  1                0
# 23                2                  0                  1                0
# 24               19                  0                  1                3
# 25               20                  0                  5                3
# 26                7                  0                  3                0
#
#     Count_negativo  Followers  Engagements  Age  Likes  Dislikes  Comments  \
# 0                9      12580           16  0.0     12         0         3
# 1                5      10498           30  0.0     18         0         9
# 2                3       2626            6  0.0      5         0         0
# 3                3      13848            3  0.0      2         0         1
# 4                2       6908            6  0.0      4         0         2
# 5               10      90916          371  0.0    295         0        30
# 6                7      40442           66  0.0     52         0         5
# 7                4       1154            5  0.0      2         0         2
# 8               43      88360          268  0.0    222         0        33
# 9              131     807072         3373  0.0   2520         0       254
# 10               6       3609           24  0.0     15         0         0
# 11              18       9293           82  0.0     50         0         6
# 12              60     165554          317  0.0    235         0        39
# 13               1        806            1  0.0      1         0         0
# 14              43     386841          557  0.0    429         0        65
# 15               6     112401          190  0.0    165         0        13
# 16               8      41402           60  0.0     38         0        10
# 17              19     152893          122  0.0     96         0        14
# 18               1      35646           32  0.0     23         0         5
# 19               3      14815           96  0.0     86         0         6
# 20              19      56234          141  0.0    103         0        20
# 21               4      34094           45  0.0     33         0         1
# 22               1      27974           11  0.0      6         0         3
# 23               4       1568            6  0.0      4         0         2
# 24              11      10384           28  0.0     23         0         2
# 25               7     443202          262  0.0    194         0        12
# 26               2       3939           12  0.0      8         0         4
#
#     Shares  Count
# 0        1     15
# 1        3     13
# 2        1      6
# 3        0      5
# 4        0      5
# 5       46     29
# 6        9     12
# 7        1      5
# 8       13     86
# 9      599    257
# 10       9     12
# 11      26     27
# 12      43    121
# 13       0      2
# 14      63     89
# 15      12     12
# 16      12     25
# 17      12     45
# 18       4      5
# 19       4     10
# 20      18     35
# 21      11     11
# 22       2      6
# 23       0      6
# 24       3     16
# 25      56     21
# 26       0      3

# %%
from sklearn import preprocessing
normalized_arr = preprocessing.normalize(base_agrupada_estados_mexico['Engagements'].to_numpy().reshape(1,-1))
rounded_arr = lambda x: round(x,4)
vfunc = np.vectorize(rounded_arr)
vfunc(normalized_arr)
# Out:
# array([[4.600e-03, 8.600e-03, 1.700e-03, 9.000e-04, 1.700e-03, 1.064e-01,
#         1.890e-02, 1.400e-03, 7.680e-02, 9.670e-01, 6.900e-03, 2.350e-02,
#         9.090e-02, 3.000e-04, 1.597e-01, 5.450e-02, 1.720e-02, 3.500e-02,
#         9.200e-03, 2.750e-02, 4.040e-02, 1.290e-02, 3.200e-03, 1.700e-03,
#         8.000e-03, 7.510e-02, 3.400e-03]])

# %%
scaler = preprocessing.MinMaxScaler()
base_agrupada_estados_mexicos_counts = base_agrupada_estados_mexico[['key_0','Count', 'Count_negativo']]
base_agrupada_estados_mexicos_counts.rename({'key_0': 'Estado'}, axis=1, inplace=True)
base_agrupada_estados_mexicos_counts.set_index('Estado', inplace=True)
base_agrupada_estados_mexicos_counts['% Odio'] = base_agrupada_estados_mexicos_counts['Count_negativo']/base_agrupada_estados_mexicos_counts['Count']
base_agrupada_estados_mexicos_counts.to_csv("Base_estados_mexicanos_completa.csv")
base_agrupada_estados_mexicos_counts
# Out:
# C:\Users\JOSE\anaconda3\envs\nltkenv\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\JOSE\AppData\Local\Temp/ipykernel_15868/1745844275.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_agrupada_estados_mexicos_counts['% Odio'] = base_agrupada_estados_mexicos_counts['Count_negativo']/base_agrupada_estados_mexicos_counts['Count']
#                  Count  Count_negativo    % Odio
# Estado
# Aguascalientes      15               9  0.600000
# Baja California     13               5  0.384615
# Chiapas              6               3  0.500000
# Coahuila             5               3  0.600000
# Colima               5               2  0.400000
# Guanajuato          29              10  0.344828
# Guerrero            12               7  0.583333
# Hidalgo              5               4  0.800000
# Jalisco             86              43  0.500000
# Mexico City        257             131  0.509728
# Michoacán           12               6  0.500000
# Morelos             27              18  0.666667
# México             121              60  0.495868
# Nayarit              2               1  0.500000
# Nuevo León          89              43  0.483146
# Oaxaca              12               6  0.500000
# Puebla              25               8  0.320000
# Querétaro           45              19  0.422222
# San Luis Potosí      5               1  0.200000
# Sinaloa             10               3  0.300000
# Sonora              35              19  0.542857
# Tabasco             11               4  0.363636
# Tamaulipas           6               1  0.166667
# Tlaxcala             6               4  0.666667
# Veracruz            16              11  0.687500
# Yucatán             21               7  0.333333
# Zacatecas            3               2  0.666667

# %%
names = base_agrupada_estados_mexicos_counts.columns
d = scaler.fit_transform(base_agrupada_estados_mexicos_counts)
scaled_df = pd.DataFrame(d, columns=names)
scaled_df['Estado'] = base_agrupada_estados_mexico.index
scaled_df.set_index('Estado', inplace=True)
scaled_df.head(8)
# Out:
#            Count  Count_negativo
# Estado
# 0       0.050980        0.061538
# 1       0.043137        0.030769
# 2       0.015686        0.015385
# 3       0.011765        0.015385
# 4       0.011765        0.007692
# 5       0.105882        0.069231
# 6       0.039216        0.046154
# 7       0.011765        0.023077

# %%
fulled_df = pd.merge(left= scaled_df, right= base_agrupada_estados_mexico, left_on=scaled_df.index, right_on=base_agrupada_estados_mexico.index, how="inner")
fulled_df.rename({'key_0':'Estado', 'Followers_x':'Followers_n'
                 , 'Engagements_x':'Engagements_n', 'Count_x':'Count_n'
                 , 'Count_y':'Count', 'Followers_y':'Followers', 'Engagements_y':'Engagements'}, inplace=True, axis=1)
fulled_df.set_index('Estado', inplace=True)
fulled_df
# Out:
#                  Followers_n  Engagements_n   Count_n  Followers  Engagements  \
# Estado
# Aguascalientes      0.002583       0.002173  0.012195       2803           19
# Baja California     0.038418       0.003317  0.103659      40499           29
# Chiapas             0.043982       0.014871  0.085366      46352          130
# Chihuahua           0.000000       0.000000  0.000000         86            0
# Coahuila            0.045528       0.000000  0.042683      47978            0
# Colima              0.001162       0.000000  0.006098       1308            0
# Guanajuato          0.014991       0.380005  0.103659      15855         3322
# Guerrero            0.009105       0.002974  0.030488       9664           26
# Hidalgo             0.013893       0.004690  0.073171      14701           41
# Jalisco             0.034750       0.084878  0.201220      36641          742
# Mexico City         1.000000       1.000000  1.000000    1052018         8742
# Michoacán           0.018497       0.017044  0.079268      19544          149
# Morelos             0.024803       0.023450  0.109756      26177          205
# México              0.049423       0.020018  0.365854      52076          175
# Nayarit             0.000004       0.000000  0.006098         90            0
# Nuevo León          0.087665       0.049531  0.317073      92304          433
# Oaxaca              0.026301       0.003432  0.030488      27753           30
# Puebla              0.023301       0.014299  0.170732      24597          125
# Querétaro           0.131637       0.003889  0.231707     138559           34
# Quintana Roo        0.003905       0.002173  0.012195       4194           19
# San Luis Potosí     0.001202       0.000000  0.018293       1350            0
# Sinaloa             0.016479       0.004118  0.048780      17421           36
# Sonora              0.016250       0.018760  0.103659      17180          164
# Tabasco             0.001535       0.006863  0.018293       1701           60
# Tamaulipas          0.025736       0.001830  0.036585      27159           16
# Veracruz            0.008669       0.005605  0.121951       9205           49
# Yucatán             0.154702       0.025967  0.103659     162822          227
# Zacatecas           0.000009       0.000915  0.000000         95            8
#
#                  Count
# Estado
# Aguascalientes       3
# Baja California     18
# Chiapas             15
# Chihuahua            1
# Coahuila             8
# Colima               2
# Guanajuato          18
# Guerrero             6
# Hidalgo             13
# Jalisco             34
# Mexico City        165
# Michoacán           14
# Morelos             19
# México              61
# Nayarit              2
# Nuevo León          53
# Oaxaca               6
# Puebla              29
# Querétaro           39
# Quintana Roo         3
# San Luis Potosí      4
# Sinaloa              9
# Sonora              18
# Tabasco              4
# Tamaulipas           7
# Veracruz            21
# Yucatán             18
# Zacatecas            1

# %%
scaled_df.to_excel("Base_estados_mexicanos_normalizada.xlsx")
scaled_df.to_csv("Base_estados_mexicanos_normalizada.csv")
fulled_df.to_csv("Base_estados_mexicanos_completa.csv")

# %% [markdown]
# # Gráficas

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import pandas as pd
from io import StringIO
base_graficas = pd.read_csv("Base_estados_mexicanos_completa.csv")
base_graficas.sort_values("Count_negativo", inplace=True, ascending=False)
base_graficas['Total_Nacional'] = base_graficas['Count'].sum()
base_graficas['Participación % Nacional'] = base_graficas['Count']/base_graficas['Total_Nacional']
base_graficas
# Out:
#              Estado  Count  Count_negativo    % Odio  Total_Nacional  \
# 9       Mexico City    257             131  0.509728             879
# 12           México    121              60  0.495868             879
# 14       Nuevo León     89              43  0.483146             879
# 8           Jalisco     86              43  0.500000             879
# 20           Sonora     35              19  0.542857             879
# 17        Querétaro     45              19  0.422222             879
# 11          Morelos     27              18  0.666667             879
# 24         Veracruz     16              11  0.687500             879
# 5        Guanajuato     29              10  0.344828             879
# 0    Aguascalientes     15               9  0.600000             879
# 16           Puebla     25               8  0.320000             879
# 6          Guerrero     12               7  0.583333             879
# 25          Yucatán     21               7  0.333333             879
# 10        Michoacán     12               6  0.500000             879
# 15           Oaxaca     12               6  0.500000             879
# 1   Baja California     13               5  0.384615             879
# 23         Tlaxcala      6               4  0.666667             879
# 7           Hidalgo      5               4  0.800000             879
# 21          Tabasco     11               4  0.363636             879
# 3          Coahuila      5               3  0.600000             879
# 19          Sinaloa     10               3  0.300000             879
# 2           Chiapas      6               3  0.500000             879
# 26        Zacatecas      3               2  0.666667             879
# 4            Colima      5               2  0.400000             879
# 22       Tamaulipas      6               1  0.166667             879
# 18  San Luis Potosí      5               1  0.200000             879
# 13          Nayarit      2               1  0.500000             879
#
#     Participación % Nacional
# 9                   0.292378
# 12                  0.137656
# 14                  0.101251
# 8                   0.097838
# 20                  0.039818
# 17                  0.051195
# 11                  0.030717
# 24                  0.018203
# 5                   0.032992
# 0                   0.017065
# 16                  0.028441
# 6                   0.013652
# 25                  0.023891
# 10                  0.013652
# 15                  0.013652
# 1                   0.014790
# 23                  0.006826
# 7                   0.005688
# 21                  0.012514
# 3                   0.005688
# 19                  0.011377
# 2                   0.006826
# 26                  0.003413
# 4                   0.005688
# 22                  0.006826
# 18                  0.005688
# 13                  0.002275

# %%
base_graficas = base_graficas[0:5]
base_graficas
# Out:
#          Estado  Count  Count_negativo    % Odio  Total_Nacional  \
# 9   Mexico City    257             131  0.509728             879
# 12       México    121              60  0.495868             879
# 14   Nuevo León     89              43  0.483146             879
# 8       Jalisco     86              43  0.500000             879
# 20       Sonora     35              19  0.542857             879
#
#     Participación % Nacional
# 9                   0.292378
# 12                  0.137656
# 14                  0.101251
# 8                   0.097838
# 20                  0.039818

# %%
x_ = base_graficas.columns[0]
y_ = base_graficas.columns[3]
y_2 = base_graficas.columns[5]
data1 = base_graficas[[x_, y_]]
data2 = base_graficas[[x_, y_2]]
plt.figure(figsize=(15,8))
ax = sns.barplot(x=x_,y=y_,data=data1)
width_scale = 0.45
for bar in ax.containers[0]:
    bar.set_width(bar.get_width() * width_scale)
ax.yaxis.set_major_formatter(PercentFormatter(1))
ax.grid(False)
ax2 = ax.twinx()
sns.barplot(x=x_,y=y_2,data=data2,alpha=0.7,hatch='xx',ax=ax2)
for bar in ax2.containers[0]:
    x = bar.get_x()
    w = bar.get_width()
    bar.set_x(x + w * (1 - width_scale))
    bar.set_width(w *  width_scale)
ax2.grid(False)  
plt.show()

# %%
# Pegar las bases
base_1 = pd.read_csv("mensajes_7_feb_16_feb.csv")
base_2 = pd.read_csv("mensajes_17_feb_28_feb.csv")
base_racismo = base_1.append(base_2)
base_racismo['Splitted'] = base_racismo['Location'].str.split(',')
try:
    base_racismo.loc[:, 'Estado'] = base_racismo.Splitted.str[1].str.strip()
    base_racismo.loc[:, 'País'] = base_racismo.Splitted.str[2].str.strip()
    base_racismo.loc[:, 'Ciudad'] = base_racismo.Splitted.map(lambda x: x[0])
except:
    print("Do Nothing.")
base_racismo['Count'] = 1
base_negativa = pd.read_csv("mensajes_negativos_7_feb_28_feb.csv")
base_negativa['Count_negativo'] = 1
base_negativa.rename({"Followers": "Followers_negativo",	"Engagements": "Engagements_negativo", "Age":"Age_negativo", "Likes":"Likes_negativos",	
                      "Dislikes":"Dislikes_negativo",	"Comments":"Comments_negativo",	"Shares":"Shares_negativo"}, inplace=True, axis=1)
base_negativa = base_negativa[['Message URL','Count_negativo']]
base_negativa
# Out:
# Index(['Network', 'Message URL', 'Profile', 'Date', 'Message', 'Type',
#        'Content Type', 'Followers', 'Engagements', 'Location', 'Gender', 'Age',
#        'Likes', 'Dislikes', 'Comments', 'Shares', 'Theme'],
#       dtype='object')
# Do Nothing.
#                                            Message URL  Count_negativo
# 0    https://twitter.com/elcacabonita/statuses/1498...               1
# 1    https://twitter.com/AxelGar56163124/statuses/1...               1
# 2    https://twitter.com/jvalenci777/statuses/14985...               1
# 3    https://twitter.com/Clau07Rocha/statuses/14985...               1
# 4    https://twitter.com/Omttl83/statuses/149850127...               1
# ..                                                 ...             ...
# 821  https://twitter.com/raticio/statuses/149078884...               1
# 822  https://twitter.com/Andres_Vingback/statuses/1...               1
# 823  https://twitter.com/VilchisJuan1/statuses/1490...               1
# 824  https://twitter.com/sirfelipon/statuses/149076...               1
# 825  https://twitter.com/edavidmtzm/statuses/149076...               1
#
# [826 rows x 2 columns]

# %%
base_merged = pd.merge(right=base_racismo , left=base_negativa, left_on = "Message URL", right_on = "Message URL", how="right")
base_merged.fillna(0, inplace = True)
base_merged
# Out:
#                                             Message URL  Count_negativo  \
# 0     https://twitter.com/Padawanmx/statuses/1494174...             0.0
# 1     https://twitter.com/leo_poblete/statuses/14941...             1.0
# 2     https://twitter.com/DiversidadCDMX/statuses/14...             0.0
# 3     https://twitter.com/mavagomez_/statuses/149416...             0.0
# 4     https://twitter.com/mavagomez_/statuses/149416...             1.0
# ...                                                 ...             ...
# 1733  https://twitter.com/javyconfeti/statuses/14940...             0.0
# 1734  https://twitter.com/SDCrisOficial/statuses/149...             0.0
# 1735  https://twitter.com/krismel2929/statuses/14940...             0.0
# 1736  https://twitter.com/Kaleno87/statuses/14940326...             0.0
# 1737  https://twitter.com/Josuenclave/statuses/14940...             0.0
#
#       Network         Profile                Date  \
# 0     Twitter       Padawanmx  2/16/2022 11:57 pm
# 1     Twitter     leo_poblete  2/16/2022 11:43 pm
# 2     Twitter  DiversidadCDMX  2/16/2022 11:37 pm
# 3     Twitter      mavagomez_  2/16/2022 11:35 pm
# 4     Twitter      mavagomez_  2/16/2022 11:33 pm
# ...       ...             ...                 ...
# 1733  Twitter     javyconfeti   2/16/2022 3:37 pm
# 1734  Twitter   SDCrisOficial   2/16/2022 3:16 pm
# 1735  Twitter     krismel2929   2/16/2022 3:04 pm
# 1736  Twitter        Kaleno87   2/16/2022 2:35 pm
# 1737  Twitter     Josuenclave   2/16/2022 2:25 pm
#
#                                                 Message     Type Content Type  \
# 0     Como sabes que un twittero es un pendejo?\n\nU...  Message         Link
# 1     Agradezco el apoyo de @FiscaliaCDMX, y del gob...  Message         Link
# 2     #Entérate La @FiscaliaCDMX vinculó a proceso a...  Message    Text Only
# 3     Que rabia me da ver a gente racista, sexista, ...  Message    Text Only
# 4     Fernandcc El racismo no es una opinión, es ign...  Mention    Text Only
# ...                                                 ...      ...          ...
# 1733  Todos éramos humanos hasta que la raza nos des...  Message    Text Only
# 1734  Seguimos en compartiendo, mucho trabajo e inci...  Message         Link
# 1735  maribelalonso No solo es un presidentito resen...  Mention    Text Only
# 1736  3_nicaragua @indio_nica @TaniaEl19 @florisandi...  Mention    Text Only
# 1737  🤣🤣🤣 resentido salió. Pero está bien no acercar...  Message         Link
#
#       Followers  Engagements  ...  Age Likes  Dislikes  Comments  Shares  \
# 0          1836            1  ...  0.0     1         0         0       0
# 1           344           13  ...  0.0     9         0         1       3
# 2          6653          102  ...  0.0    67         0         1      34
# 3         21280           97  ...  0.0    93         0         0       4
# 4         21280            3  ...  0.0     2         0         1       0
# ...         ...          ...  ...  ...   ...       ...       ...     ...
# 1733       1753            1  ...  0.0     1         0         0       0
# 1734        555            1  ...  0.0     1         0         0       0
# 1735       1689           43  ...  0.0    39         0         0       4
# 1736       1836            0  ...  0.0     0         0         0       0
# 1737         34            0  ...  0.0     0         0         0       0
#
#                 Theme                                      Splitted  \
# 0                   0               [Cuernavaca,  Morelos,  Mexico]
# 1                   0       [Naucalpan de Juarez,  México,  Mexico]
# 2                   0    [Colonia del Valle,  Mexico City,  Mexico]
# 3                   0    [Los Angeles,  California,  United States]
# 4                   0    [Los Angeles,  California,  United States]
# ...               ...                                           ...
# 1733                0                                      [Mexico]
# 1734                0                                      [Mexico]
# 1735         Backlash  [Venustiano Carranza,  Mexico City,  Mexico]
# 1736  Origen cultural                                   [Nicaragua]
# 1737         Backlash                                    [Honduras]
#
#            Estado           País Count
# 0         Morelos         Mexico     1
# 1          México         Mexico     1
# 2     Mexico City         Mexico     1
# 3      California  United States     1
# 4      California  United States     1
# ...           ...            ...   ...
# 1733            0              0     1
# 1734            0              0     1
# 1735  Mexico City         Mexico     1
# 1736            0              0     1
# 1737            0              0     1
#
# [1738 rows x 22 columns]

# %%
base_merged.to_excel("Base_preliminar.xlsx")
