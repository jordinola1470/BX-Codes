# %%
import pandas as pd
import numpy as np
import os
import datetime

# %%
path = r'D:\Trabajo\Barómetro\BX\Web Scraping\Pie Charts Ecuador\Historico hasta enero 26 2022' + '\\'

# %%
df = pd.read_excel(path + "archivo_0.xlsx", skiprows=9)
df
# Out:
#           all  all.1
# 0    Trabajo     282
# 1      Salud    1283
# 2  Seguridad     977
# 3   Educación    285

# %%
df.rename(columns= {"all": "Categoria", "all.1": "Volumen"}, inplace=True)

# %%
df
# Out:
#     Categoria  Volumen
# 0    Trabajo      2079
# 1       Mujer      519
# 2  Educación       705
# 3  Seguridad      4435
# 4      Salud      1493

# %%
df.sum()[1]
# Out:
# 9231

# %%
start_date = '2020-01-01' # YYYY-MM-DD
end_date = '2022-02-04' # PATTERN YYYY-MM-DD - YYYY-MM-DD
def next_week(fecha:str) -> str:
    nueva_fecha = datetime.datetime.strptime(fecha,'%Y-%m-%d').date()
    nueva_fecha = nueva_fecha + datetime.timedelta(days=7)
    return str(nueva_fecha)

def query_pie_chart(start_date: str, end_date: str) -> list:
    centinela = True
    retorno = list()
    two_weeks = next_week(next_week(start_date)) 
    n = 0
    while centinela == True:
        if n == 0:
            envio_range_fechas = start_date + " - " + two_weeks
            retorno.append(envio_range_fechas)
        else:
            start_date = two_weeks
            two_weeks = next_week(next_week(start_date))
            two_weeks_verif = datetime.datetime.strptime(two_weeks,'%Y-%m-%d').date()
            end_date_verif = datetime.datetime.strptime(end_date,'%Y-%m-%d').date()
            if int((end_date_verif - two_weeks_verif).days) < 0:
                centinela = False
            else:
                envio_range_fechas = start_date + " - " + two_weeks
                retorno.append(envio_range_fechas)
        n+=1
    return retorno
fechas = query_pie_chart(start_date, end_date)

# %%
final = pd.DataFrame()
for i in range(0,54):
    df = pd.read_excel(path + "archivo_" + str(i) + ".xlsx", skiprows=9)
    df.rename(columns= {"all": "Categoria", "all.1": "Volumen"}, inplace=True)
    dato = {'Categoria': 'Total', 'Volumen': df.sum()[1]}
    df = df.append(dato, ignore_index=True)
    df["Rango Fecha"] = fechas[i]
    final = final.append(df)

# %%
final
# Out:
#      Categoria  Volumen              Rango Fecha
# 0     Trabajo      2079  2020-01-01 - 2020-01-15
# 1        Mujer      519  2020-01-01 - 2020-01-15
# 2   Educación       705  2020-01-01 - 2020-01-15
# 3   Seguridad      4435  2020-01-01 - 2020-01-15
# 4       Salud      1493  2020-01-01 - 2020-01-15
# ..         ...      ...                      ...
# 1        Mujer      299  2022-01-12 - 2022-01-26
# 2   Educación       684  2022-01-12 - 2022-01-26
# 3   Seguridad      3962  2022-01-12 - 2022-01-26
# 4       Salud      1079  2022-01-12 - 2022-01-26
# 5        Total     7421  2022-01-12 - 2022-01-26
#
# [324 rows x 3 columns]

# %%
melteddf = final.pivot(index='Rango Fecha', columns=['Categoria'], values=['Volumen'])

# %%
melteddf
# Out:
#                            Volumen
# Categoria               Educación  Mujer Salud  Seguridad   Total Trabajo
# 2021-08-25 - 2021-09-08        963   481   1696       5135   9827     1552
# 2021-09-08 - 2021-09-22        843   308   1332       5639   9722     1600
# 2021-09-22 - 2021-10-06        821   403   1294       3952   7675     1205
# 2021-10-06 - 2021-10-20        881   311   1688       8591  13529     2058
# 2021-10-20 - 2021-11-03       1011   357   1936       3561   8680     1815
# 2021-11-03 - 2021-11-17        815   297   1604       3718   7836     1402
# 2021-11-17 - 2021-12-01       1047   305   1165       2878   6635     1240
# 2021-12-01 - 2021-12-15       1006   327   1163       4408   8361     1457
# 2021-12-15 - 2021-12-29        894   269    950       2709   6262     1440
# 2021-12-29 - 2022-01-12        517   259   1437       6206   9812     1393
# 2022-01-12 - 2022-01-26        684   299   1079       3962   7421     1397

# %%
melteddf.columns = melteddf.columns.droplevel()
melteddf.head(5)
# Out:
# Categoria                Educación   Mujer  Salud   Seguridad   Total  \
# Rango Fecha
# 2020-01-01 - 2020-01-15         705    519    1493        4435   9231
# 2020-01-15 - 2020-01-29        1058    607    2437        5657  11401
# 2020-01-29 - 2020-02-12         975    479    1344        5166   9683
# 2020-02-12 - 2020-02-26        1187    438    2042        6233  13379
# 2020-02-26 - 2020-03-11        1078    664    2381        4003   9607
#
# Categoria                Trabajo
# Rango Fecha
# 2020-01-01 - 2020-01-15      2079
# 2020-01-15 - 2020-01-29      1642
# 2020-01-29 - 2020-02-12      1719
# 2020-02-12 - 2020-02-26      3479
# 2020-02-26 - 2020-03-11      1481

# %%
columns_list = melteddf.columns
columns_list = columns_list.drop('Total')
for i in range(len(columns_list)):
    texto = str(columns_list[i]).strip()
    melteddf[texto + " %"] = melteddf[columns_list[i]]/melteddf['Total']
melteddf.head(5)
# Out:
# Categoria                Educación   Mujer  Salud   Seguridad   Total  \
# Rango Fecha
# 2020-01-01 - 2020-01-15         705    519    1493        4435   9231
# 2020-01-15 - 2020-01-29        1058    607    2437        5657  11401
# 2020-01-29 - 2020-02-12         975    479    1344        5166   9683
# 2020-02-12 - 2020-02-26        1187    438    2042        6233  13379
# 2020-02-26 - 2020-03-11        1078    664    2381        4003   9607
#
# Categoria                Trabajo   Educación %   Mujer %   Salud %  \
# Rango Fecha
# 2020-01-01 - 2020-01-15      2079     0.076373  0.056224  0.161738
# 2020-01-15 - 2020-01-29      1642     0.092799  0.053241  0.213753
# 2020-01-29 - 2020-02-12      1719     0.100692  0.049468  0.138800
# 2020-02-12 - 2020-02-26      3479     0.088721  0.032738  0.152627
# 2020-02-26 - 2020-03-11      1481     0.112210  0.069116  0.247840
#
# Categoria                Seguridad %  Trabajo %
# Rango Fecha
# 2020-01-01 - 2020-01-15     0.480446   0.225219
# 2020-01-15 - 2020-01-29     0.496185   0.144022
# 2020-01-29 - 2020-02-12     0.533512   0.177528
# 2020-02-12 - 2020-02-26     0.465879   0.260034
# 2020-02-26 - 2020-03-11     0.416675   0.154158

# %%
melteddf.to_excel("Histórico_Pie_Charts.xlsx")
