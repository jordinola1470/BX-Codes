# %%
import urllib.request, urllib.parse, urllib.error
import twurl
import json
import ssl

# https://apps.twitter.com/
# Create App and get the four strings, put them in hidden.py

TWITTER_URL = 'https://api.twitter.com/1.1/friends/list.json'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    print('')
    acct = input('Enter Twitter Account:')
    if (len(acct) < 1): break
    url = twurl.augment(TWITTER_URL,
                        {'screen_name': acct, 'count': '5'})
    print('Retrieving', url)
    connection = urllib.request.urlopen(url, context=ctx)
    data = connection.read().decode()

    js = json.loads(data)
    print(json.dumps(js, indent=2))

    headers = dict(connection.getheaders())
    print('Remaining', headers['x-rate-limit-remaining'])

    for u in js['users']:
        print(u['screen_name'])
        if 'status' not in u:
            print('   * No status found')
            continue
        s = u['status']['text']
        print('  ', s[:50])
# Out:
# Enter Twitter Account:migravenezuela
# Retrieving https://api.twitter.com/1.1/friends/list.json?oauth_consumer_key=cbXOyd0gaMNU4eit4xYZQmqU3&oauth_timestamp=1613665251&oauth_nonce=07182875&oauth_version=1.0&screen_name=migravenezuela&count=5&oauth_token=1476162662-X622FbKFdiq3QkmAP9zLBD0Vd2dDWukwVHJMKEh&oauth_signature_method=HMAC-SHA1&oauth_signature=U0Kz1Z%2BezFKmuchjvtKBgWMWgZk%3D
# {
#   "users": [
#     {
#       "id": 771046912015405056,
#       "id_str": "771046912015405056",
#       "name": "Fund. Sergio Urrego",
#       "screen_name": "sergiourregoorg",
#       "location": "Colombia",
#       "description": "Proteger a ni\u00f1as/os y j\u00f3venes de la discriminaci\u00f3n, previniendo el suicidio a trav\u00e9s de l\u00edneas de acompa\u00f1amiento y asistencia. \u00a1Puedes donar aqu\u00ed! \ud83d\udc47\ud83c\udffd",
#       "url": "https://t.co/TTQ1tif3KO",
#       "entities": {
#         "url": {
#           "urls": [
#             {
#               "url": "https://t.co/TTQ1tif3KO",
#               "expanded_url": "https://linktr.ee/fundacionsergiourrego",
#               "display_url": "linktr.ee/fundacionsergi\u2026",
#               "indices": [
#                 0,
#                 23
#               ]
#             }
#           ]
#         },
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 5219,
#       "friends_count": 483,
#       "listed_count": 25,
#       "created_at": "Wed Aug 31 18:08:04 +0000 2016",
#       "favourites_count": 12619,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": true,
#       "statuses_count": 6027,
#       "lang": null,
#       "status": {
#         "created_at": "Thu Feb 18 03:34:14 +0000 2021",
#         "id": 1362244003933155330,
#         "id_str": "1362244003933155330",
#         "text": "RT @Nuddsove_: #NuddsoInforma: Asesinan a mujer trans venezolana en el municipio de Soledad en #Colombia. \n\nLa creciente violencia hacia pe\u2026",
#         "truncated": false,
#         "entities": {
#           "hashtags": [
#             {
#               "text": "NuddsoInforma",
#               "indices": [
#                 15,
#                 29
#               ]
#             },
#             {
#               "text": "Colombia",
#               "indices": [
#                 95,
#                 104
#               ]
#             }
#           ],
#           "symbols": [],
#           "user_mentions": [
#             {
#               "screen_name": "Nuddsove_",
#               "name": "Nunca dejes de so\u00f1ar/ ONG LGBTI",
#               "id": 1255991968250937344,
#               "id_str": "1255991968250937344",
#               "indices": [
#                 3,
#                 13
#               ]
#             }
#           ],
#           "urls": []
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#           "created_at": "Thu Feb 18 02:58:50 +0000 2021",
#           "id": 1362235093356400640,
#           "id_str": "1362235093356400640",
#           "text": "#NuddsoInforma: Asesinan a mujer trans venezolana en el municipio de Soledad en #Colombia. \n\nLa creciente violencia\u2026 https://t.co/GoGHMmqaBj",
#           "truncated": true,
#           "entities": {
#             "hashtags": [
#               {
#                 "text": "NuddsoInforma",
#                 "indices": [
#                   0,
#                   14
#                 ]
#               },
#               {
#                 "text": "Colombia",
#                 "indices": [
#                   80,
#                   89
#                 ]
#               }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#               {
#                 "url": "https://t.co/GoGHMmqaBj",
#                 "expanded_url": "https://twitter.com/i/web/status/1362235093356400640",
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "indices": [
#                   117,
#                   140
#                 ]
#               }
#             ]
#           },
#           "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#           "in_reply_to_status_id": null,
#           "in_reply_to_status_id_str": null,
#           "in_reply_to_user_id": null,
#           "in_reply_to_user_id_str": null,
#           "in_reply_to_screen_name": null,
#           "geo": null,
#           "coordinates": null,
#           "place": null,
#           "contributors": null,
#           "is_quote_status": false,
#           "retweet_count": 16,
#           "favorite_count": 12,
#           "favorited": false,
#           "retweeted": false,
#           "possibly_sensitive": false,
#           "lang": "es"
#         },
#         "is_quote_status": false,
#         "retweet_count": 16,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "es"
#       },
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "000000",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1339248071121793025/-ym2gsIG_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1339248071121793025/-ym2gsIG_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/771046912015405056/1612468598",
#       "profile_link_color": "FAB81E",
#       "profile_sidebar_border_color": "000000",
#       "profile_sidebar_fill_color": "000000",
#       "profile_text_color": "000000",
#       "profile_use_background_image": false,
#       "has_extended_profile": false,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "live_following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "muting": false,
#       "blocking": false,
#       "blocked_by": false,
#       "translator_type": "none"
#     },
#     {
#       "id": 172850610,
#       "id_str": "172850610",
#       "name": "Julio Cesar Daly",
#       "screen_name": "juliodalyr",
#       "location": "",
#       "description": "Economista. Estudio la migraci\u00f3n. Intento generar evidencia para combatir la xenofobia y promover la integraci\u00f3n.",
#       "url": null,
#       "entities": {
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 270,
#       "friends_count": 852,
#       "listed_count": 0,
#       "created_at": "Fri Jul 30 19:34:09 +0000 2010",
#       "favourites_count": 1470,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": false,
#       "statuses_count": 1213,
#       "lang": null,
#       "status": {
#         "created_at": "Sat Feb 13 00:04:09 +0000 2021",
#         "id": 1360379194597867523,
#         "id_str": "1360379194597867523",
#         "text": "RT @paularossiasco: El trabajo de #Bar\u00f3metroDeXenofobia es impecable. Pero en el \u00faltimo reporte se superaron a ellos mismos. La medici\u00f3n de\u2026",
#         "truncated": false,
#         "entities": {
#           "hashtags": [
#             {
#               "text": "Bar\u00f3metroDeXenofobia",
#               "indices": [
#                 34,
#                 55
#               ]
#             }
#           ],
#           "symbols": [],
#           "user_mentions": [
#             {
#               "screen_name": "paularossiasco",
#               "name": "Paula Rossiasco",
#               "id": 387405385,
#               "id_str": "387405385",
#               "indices": [
#                 3,
#                 18
#               ]
#             }
#           ],
#           "urls": []
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#           "created_at": "Fri Feb 12 18:36:40 +0000 2021",
#           "id": 1360296780353720320,
#           "id_str": "1360296780353720320",
#           "text": "El trabajo de #Bar\u00f3metroDeXenofobia es impecable. Pero en el \u00faltimo reporte se superaron a ellos mismos. La medici\u00f3\u2026 https://t.co/7HvbK3MdxV",
#           "truncated": true,
#           "entities": {
#             "hashtags": [
#               {
#                 "text": "Bar\u00f3metroDeXenofobia",
#                 "indices": [
#                   14,
#                   35
#                 ]
#               }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#               {
#                 "url": "https://t.co/7HvbK3MdxV",
#                 "expanded_url": "https://twitter.com/i/web/status/1360296780353720320",
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "indices": [
#                   117,
#                   140
#                 ]
#               }
#             ]
#           },
#           "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#           "in_reply_to_status_id": null,
#           "in_reply_to_status_id_str": null,
#           "in_reply_to_user_id": null,
#           "in_reply_to_user_id_str": null,
#           "in_reply_to_screen_name": null,
#           "geo": null,
#           "coordinates": null,
#           "place": null,
#           "contributors": null,
#           "is_quote_status": true,
#           "quoted_status_id": 1360190409075523591,
#           "quoted_status_id_str": "1360190409075523591",
#           "retweet_count": 3,
#           "favorite_count": 7,
#           "favorited": false,
#           "retweeted": false,
#           "possibly_sensitive": false,
#           "lang": "es"
#         },
#         "is_quote_status": true,
#         "quoted_status_id": 1360190409075523591,
#         "quoted_status_id_str": "1360190409075523591",
#         "retweet_count": 3,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "es"
#       },
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "C0DEED",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1317996155276529666/2bl_wD_h_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1317996155276529666/2bl_wD_h_normal.jpg",
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": false,
#       "live_following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "muting": false,
#       "blocking": false,
#       "blocked_by": false,
#       "translator_type": "none"
#     },
#     {
#       "id": 1073348071868850178,
#       "id_str": "1073348071868850178",
#       "name": "Laura Cristancho",
#       "screen_name": "Lauracamila_cc",
#       "location": "Bogot\u00e1, D.C., Colombia",
#       "description": "",
#       "url": null,
#       "entities": {
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 87,
#       "friends_count": 1160,
#       "listed_count": 0,
#       "created_at": "Thu Dec 13 22:44:56 +0000 2018",
#       "favourites_count": 10263,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": false,
#       "verified": false,
#       "statuses_count": 170,
#       "lang": null,
#       "status": {
#         "created_at": "Thu Feb 18 02:43:51 +0000 2021",
#         "id": 1362231323633532928,
#         "id_str": "1362231323633532928",
#         "text": "RT @migravenezuela: #Econom\u00eda | M\u00e1s all\u00e1 del impacto humanitario del Estatuto Temporal de Protecci\u00f3n, la inclusi\u00f3n de los migrantes venezol\u2026",
#         "truncated": false,
#         "entities": {
#           "hashtags": [
#             {
#               "text": "Econom\u00eda",
#               "indices": [
#                 20,
#                 29
#               ]
#             }
#           ],
#           "symbols": [],
#           "user_mentions": [
#             {
#               "screen_name": "migravenezuela",
#               "name": "Proyecto Migraci\u00f3n Venezuela",
#               "id": 1055478285856059394,
#               "id_str": "1055478285856059394",
#               "indices": [
#                 3,
#                 18
#               ]
#             }
#           ],
#           "urls": []
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#           "created_at": "Tue Feb 16 00:34:30 +0000 2021",
#           "id": 1361473995795750919,
#           "id_str": "1361473995795750919",
#           "text": "#Econom\u00eda | M\u00e1s all\u00e1 del impacto humanitario del Estatuto Temporal de Protecci\u00f3n, la inclusi\u00f3n de los migrantes ven\u2026 https://t.co/W6Sy9g65hC",
#           "truncated": true,
#           "entities": {
#             "hashtags": [
#               {
#                 "text": "Econom\u00eda",
#                 "indices": [
#                   0,
#                   9
#                 ]
#               }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#               {
#                 "url": "https://t.co/W6Sy9g65hC",
#                 "expanded_url": "https://twitter.com/i/web/status/1361473995795750919",
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "indices": [
#                   117,
#                   140
#                 ]
#               }
#             ]
#           },
#           "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#           "in_reply_to_status_id": null,
#           "in_reply_to_status_id_str": null,
#           "in_reply_to_user_id": null,
#           "in_reply_to_user_id_str": null,
#           "in_reply_to_screen_name": null,
#           "geo": null,
#           "coordinates": null,
#           "place": null,
#           "contributors": null,
#           "is_quote_status": false,
#           "retweet_count": 4,
#           "favorite_count": 6,
#           "favorited": false,
#           "retweeted": false,
#           "possibly_sensitive": false,
#           "lang": "es"
#         },
#         "is_quote_status": false,
#         "retweet_count": 4,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "es"
#       },
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": null,
#       "profile_background_image_url_https": null,
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1361844622910246914/I34SJJ3s_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1361844622910246914/I34SJJ3s_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/1073348071868850178/1589148826",
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": false,
#       "live_following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "muting": false,
#       "blocking": false,
#       "blocked_by": false,
#       "translator_type": "none"
#     },
#     {
#       "id": 28810531,
#       "id_str": "28810531",
#       "name": "Cristal Monta\u00f1ez",
#       "screen_name": "CristalMontanez",
#       "location": "Venezuela - USA - Pakistan",
#       "description": "Global Citizen pomoting more peaceful and inclusive societies through Citizen Diplomacy, Intercultural Relations and Understanding. https://t.co/qN8XFOLOI4",
#       "url": null,
#       "entities": {
#         "description": {
#           "urls": [
#             {
#               "url": "https://t.co/qN8XFOLOI4",
#               "expanded_url": "http://youtu.be/okkuwB64_yU",
#               "display_url": "youtu.be/okkuwB64_yU",
#               "indices": [
#                 132,
#                 155
#               ]
#             }
#           ]
#         }
#       },
#       "protected": false,
#       "followers_count": 2707,
#       "friends_count": 3087,
#       "listed_count": 28,
#       "created_at": "Sat Apr 04 15:21:14 +0000 2009",
#       "favourites_count": 250,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": false,
#       "verified": false,
#       "statuses_count": 3877,
#       "lang": null,
#       "status": {
#         "created_at": "Sat Nov 21 23:12:53 +0000 2020",
#         "id": 1330288099809767424,
#         "id_str": "1330288099809767424",
#         "text": "RT @CristalMontane: Smartmatic has been used in elections in Africa, Argentina, Belgium, Brazil, Chile, Ecuador, Italy Mexico, the Philippi\u2026",
#         "truncated": false,
#         "entities": {
#           "hashtags": [],
#           "symbols": [],
#           "user_mentions": [
#             {
#               "screen_name": "CristalMontane",
#               "name": "Cristal Monta\u00f1\u00e9z",
#               "id": 46779980,
#               "id_str": "46779980",
#               "indices": [
#                 3,
#                 18
#               ]
#             }
#           ],
#           "urls": []
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#           "created_at": "Sat Nov 21 22:56:47 +0000 2020",
#           "id": 1330284048959365123,
#           "id_str": "1330284048959365123",
#           "text": "Smartmatic has been used in elections in Africa, Argentina, Belgium, Brazil, Chile, Ecuador, Italy Mexico, the Phil\u2026 https://t.co/SpptRlsB3Q",
#           "truncated": true,
#           "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#               {
#                 "url": "https://t.co/SpptRlsB3Q",
#                 "expanded_url": "https://twitter.com/i/web/status/1330284048959365123",
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "indices": [
#                   117,
#                   140
#                 ]
#               }
#             ]
#           },
#           "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#           "in_reply_to_status_id": null,
#           "in_reply_to_status_id_str": null,
#           "in_reply_to_user_id": null,
#           "in_reply_to_user_id_str": null,
#           "in_reply_to_screen_name": null,
#           "geo": null,
#           "coordinates": null,
#           "place": null,
#           "contributors": null,
#           "is_quote_status": false,
#           "retweet_count": 9,
#           "favorite_count": 8,
#           "favorited": false,
#           "retweeted": false,
#           "possibly_sensitive": false,
#           "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 9,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#       },
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "C0DEED",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/684971046043160576/8PfFQRNR_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/684971046043160576/8PfFQRNR_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/28810531/1491364793",
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": false,
#       "live_following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "muting": false,
#       "blocking": false,
#       "blocked_by": false,
#       "translator_type": "none"
#     },
#     {
#       "id": 41883780,
#       "id_str": "41883780",
#       "name": "Women's Link",
#       "screen_name": "womenslink",
#       "location": "From Colombia&Spain&Kenya to Global",
#       "description": "International nonprofit organization using the power of the law to advance the rights of women & girls. Our President & CEO is @VivianaWaisman",
#       "url": "https://t.co/uxEQ7gNLyj",
#       "entities": {
#         "url": {
#           "urls": [
#             {
#               "url": "https://t.co/uxEQ7gNLyj",
#               "expanded_url": "http://womenslinkworldwide.org",
#               "display_url": "womenslinkworldwide.org",
#               "indices": [
#                 0,
#                 23
#               ]
#             }
#           ]
#         },
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 21074,
#       "friends_count": 3435,
#       "listed_count": 439,
#       "created_at": "Fri May 22 19:36:38 +0000 2009",
#       "favourites_count": 4994,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": true,
#       "statuses_count": 27023,
#       "lang": null,
#       "status": {
#         "created_at": "Thu Feb 18 12:25:48 +0000 2021",
#         "id": 1362377778369290246,
#         "id_str": "1362377778369290246",
#         "text": "\"No se est\u00e1 teniendo en cuenta. Si ya de por s\u00ed un hombre est\u00e1 en condici\u00f3n de vulnerabilidad, las mujeres\u2026 Nos dic\u2026 https://t.co/S4fcssyteT",
#         "truncated": true,
#         "entities": {
#           "hashtags": [],
#           "symbols": [],
#           "user_mentions": [],
#           "urls": [
#             {
#               "url": "https://t.co/S4fcssyteT",
#               "expanded_url": "https://twitter.com/i/web/status/1362377778369290246",
#               "display_url": "twitter.com/i/web/status/1\u2026",
#               "indices": [
#                 117,
#                 140
#               ]
#             }
#           ]
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": 1362377776976773120,
#         "in_reply_to_status_id_str": "1362377776976773120",
#         "in_reply_to_user_id": 41883780,
#         "in_reply_to_user_id_str": "41883780",
#         "in_reply_to_screen_name": "womenslink",
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 4,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "es"
#       },
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "DBE9ED",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme10/bg.gif",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme10/bg.gif",
#       "profile_background_tile": true,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1034429328661127168/_2gDM36V_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1034429328661127168/_2gDM36V_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/41883780/1543227243",
#       "profile_link_color": "CC3366",
#       "profile_sidebar_border_color": "DBE9ED",
#       "profile_sidebar_fill_color": "E6F6F9",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "live_following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "muting": false,
#       "blocking": false,
#       "blocked_by": false,
#       "translator_type": "none"
#     }
#   ],
#   "next_cursor": 1682828658360965021,
#   "next_cursor_str": "1682828658360965021",
#   "previous_cursor": 0,
#   "previous_cursor_str": "0",
#   "total_count": null
# }
# Remaining 14
# sergiourregoorg
#    RT @Nuddsove_: #NuddsoInforma: Asesinan a mujer tr
# juliodalyr
#    RT @paularossiasco: El trabajo de #BarómetroDeXeno
# Lauracamila_cc
#    RT @migravenezuela: #Economía | Más allá del impac
# CristalMontanez
#    RT @CristalMontane: Smartmatic has been used in el
# womenslink
#    "No se está teniendo en cuenta. Si ya de por sí un
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-79bc6a9b3109> in <module>
#      16 while True:
#      17     print('')
# ---> 18     acct = input('Enter Twitter Account:')
#      19     if (len(acct) < 1): break
#      20     url = twurl.augment(TWITTER_URL,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
TWITTER_URL = 'https://api.twitter.com/1.1/friends/list.json'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    print('')
    acct = input('Ingrese una cuenta de twitter:')
    if (len(acct) < 1): break
    url = twurl.augment(TWITTER_URL,
                        {'screen_name': acct, 'count': '10'})
    print('Retrieving', url)
    connection = urllib.request.urlopen(url, context=ctx)
    data = connection.read().decode()

    js = json.loads(data)
    #print(json.dumps(js, indent=2))

    headers = dict(connection.getheaders())
    print('Remaining', headers['x-rate-limit-remaining'])

    for u in js['users']:
        print(u['screen_name'])
        if 'status' not in u:
            print('   * No status found')
            continue
        s = u['status']['text']
        print('  ', s[:50])
# Out:
# Ingrese una cuenta de twitter:juliodalyr
# Retrieving https://api.twitter.com/1.1/friends/list.json?oauth_consumer_key=cbXOyd0gaMNU4eit4xYZQmqU3&oauth_timestamp=1613667180&oauth_nonce=80369471&oauth_version=1.0&screen_name=juliodalyr&count=10&oauth_token=1476162662-X622FbKFdiq3QkmAP9zLBD0Vd2dDWukwVHJMKEh&oauth_signature_method=HMAC-SHA1&oauth_signature=uvHJJGK4B9G8cM96FB1CTvUmDSM%3D
# Remaining 14
# JatarJulia
#    Tengo una inmensa biblioteca y no me voy a despren
# MigrantVoiceUK
#    RT @EquanicityUK: "In my country, they torture you
# migrants_rights
#    Extremely useful and comprehensive thread, give it
# InfoMigrants
#    A memorial will be created on the Italian island o
# JFCrisp
#    Myanmar.
# Has the military bitten off more than it
# carolaam
#    RT @lasillavacia: #DetectorDeMentiras
#
# Todo el día
# arnaiz
#    Sí no fuera ya de por sí una vergüenza como país,
# LiliVillamizar1
#    RT @VoluntadLa: Ustedes no se alcanzan a imaginar
# LauNieto05
#    RT @dgomezco: Resumen Conpes Reactivación https://
# KevinCo25507990
#    * No status found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4d9e83d0cced> in <module>
#       8 while True:
#       9     print('')
# ---> 10     acct = input('Ingrese una cuenta de twitter:')
#      11     if (len(acct) < 1): break
#      12     url = twurl.augment(TWITTER_URL,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
