# %%
import pandas as pd
import numpy as np
import sys
import chardet
import csv
#with open('Informe semestral 2022-1/[Q] Barómetro Migrante Perú.csv', 'rb') as f:
#    enc = chardet.detect(f.read())  # or readline if the file is large    
base = pd.read_excel('Perú_autores_16_junio.xlsx')
base
# Out:
#         Query Id                   Query Name                   Date  \
# 0     2000574935  [Q] Barómetro Migrante Perú  2022-06-22 17:59:51.0
# 1     2000574935  [Q] Barómetro Migrante Perú  2022-06-22 17:58:57.0
# 2     2000574935  [Q] Barómetro Migrante Perú  2022-06-22 17:48:16.0
# 3     2000574935  [Q] Barómetro Migrante Perú  2022-06-22 17:46:03.0
# 4     2000574935  [Q] Barómetro Migrante Perú  2022-06-22 17:41:11.0
# ...          ...                          ...                    ...
# 3452  2000574935  [Q] Barómetro Migrante Perú  2022-06-15 00:19:08.0
# 3453  2000574935  [Q] Barómetro Migrante Perú  2022-06-15 00:08:30.0
# 3454  2000574935  [Q] Barómetro Migrante Perú  2022-06-15 00:08:19.0
# 3455  2000574935  [Q] Barómetro Migrante Perú  2022-06-15 00:06:18.0
# 3456  2000574935  [Q] Barómetro Migrante Perú  2022-06-15 00:04:32.0
#
#                                                   Title  \
# 0     @ArturoR69908859 Por cierto, los refugiados ha...
# ...

# %%
base_xenofobia = base.copy()
base_xenofobia = base_xenofobia[base_xenofobia['Categorías barómetro - Xenofobia'] == 'X']
base_xenofobia
# Out:
#         Query Id                   Query Name                   Date  \
# 29    2000574935  [Q] Barómetro Migrante Perú  2022-06-22 16:38:49.0
# 75    2000574935  [Q] Barómetro Migrante Perú  2022-06-22 14:46:12.0
# 76    2000574935  [Q] Barómetro Migrante Perú  2022-06-22 14:36:21.0
# 88    2000574935  [Q] Barómetro Migrante Perú  2022-06-22 14:08:57.0
# 100   2000574935  [Q] Barómetro Migrante Perú  2022-06-22 13:45:46.0
# ...          ...                          ...                    ...
# 3419  2000574935  [Q] Barómetro Migrante Perú  2022-06-15 02:42:26.0
# 3430  2000574935  [Q] Barómetro Migrante Perú  2022-06-15 02:13:48.0
# 3447  2000574935  [Q] Barómetro Migrante Perú  2022-06-15 00:41:36.0
# 3448  2000574935  [Q] Barómetro Migrante Perú  2022-06-15 00:36:01.0
# 3451  2000574935  [Q] Barómetro Migrante Perú  2022-06-15 00:24:12.0
#
#                                                   Title  \
# 29    RT @JorgeOr11544795 Vota por Hernández para q ...
# ...

# %%
lista_autores = pd.unique(base_xenofobia['Author'])
lista_autores
# Out:
# array(['GersinB', 'jorita20', 'Actualizado Jun', 'Totoelmono',
#        'wgpasitrote99', 'rominalozada', 'bienfranca', nan,
#        'hleonardocr25', 'MiguelA87974638', 'laSraKfuerzan1',
#        'ProgreZolano', 'Landox20', 'fer_CL4', 'Andresavm',
#        'Juan Sequeiros', 'Morochuinni', 'CynthiaLandeo', 'Le_daniro',
#        'SlayerSum', 'leguerrer2', 'eSCelente', 'ZatraStarcraft',
#        'Lisandrooo5', 'sndr_gic', 'rafaele39783376', 'MisiaLoquera',
#        'SahzdiPaz', 'Maritza67335907', 'Yarrdo', 'cyrano710', 'BrunoLA19',
#        'JosemiDice', 'GoodeFAB', 'AdalitP78', 'Mario_Padilla_B',
#        'Rafaelmillascrf', 'BrDJANGO', 'escup1tajo_bebe', 'bichota93',
#        'isbhexdevera', 'facho_liberal1', 'QuijoteenPeru', 'RSaldamando',
#        'almgabo', 'danielerussianv', 'eliecerdiazv', 'SantiagoJG_',
#        'JisellHiguera', 'YonathanRuiz', 'geraldvidal', 'ManuelAAprr',
#        'guachoporname', 'FaridAquino', 'eframero', 'bk7destiny',
# ...

# %%
with open('autores_xenofobia_16_junio.txt', 'w') as f:
    for item in range(len(lista_autores)):
        f.write(str(lista_autores[item]))
        f.write("\n")
