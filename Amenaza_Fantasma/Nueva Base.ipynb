# %%
import numpy as np
import pandas as pd
import sys
sys.path.append(r'C:\Users\JOSE\Desktop\Trabajo\BX')
import funciones as fn
import re

# %%
df = pd.read_excel(r'C:\Users\JOSE\Desktop\Trabajo\BX\Supervisado\Base_semanal_pegada.xlsx')
df
# Out:
#         Unnamed: 0                   Date  \
# 0                0  2020-01-08 23:59:57.0
# 1                2  2020-01-08 23:59:20.0
# 2                4  2020-01-08 23:58:10.0
# 3                5  2020-01-08 23:55:42.0
# 4                7  2020-01-08 23:54:14.0
# ...            ...                    ...
# 350574       46995  2021-03-08 00:11:19.0
# 350575       46996  2021-03-08 00:10:35.0
# 350576       47000  2021-03-08 00:07:01.0
# 350577       47001  2021-03-08 00:05:02.0
# 350578       47004  2021-03-08 00:02:23.0
#
#                                                   Snippet           Domain  \
# 0       Justamente le acabe el guacamole picante al ve...      twitter.com
# 1       ...1141486160931430407] El seleccionado catarí...   vanguardia.com
# 2       @NTN24ve EL QUE NO SABE CON QUIEN SE METE ES L...      twitter.com
# 3       @NoticiasCaracol Los venezolanos siempre esper...      twitter.com
# 4       Los 6 puntos q trata la cartica denota su prox...      twitter.com
# ...                                                   ...              ...
# 350574  @yoligrilla @elespectador Y este gobierno colo...      twitter.com
# 350575  ..., y de taquito se la sirvió a Yesus Cabrera...  primertiempo.co
# 350576  Eduardo Sosa, José David Barragán y José Luis ...      twitter.com
# 350577  La venezolana Jenny Camacho es la mente maestr...      twitter.com
# 350578  @fpcwin uno de los venezolanos buenos en su pa...      twitter.com
#
#        Sentiment                 City_Code Account_Type           Author  \
# 0        neutral         COL.Bogota.Bogota   individual       Hector_Jk7
# 1        neutral                       NaN          NaN              NaN
# 2       positive    COL.Antioquia.Medellin   individual     LeilaLozano3
# 3       negative    COL.Antioquia.Medellin   individual         0rwell07
# 4        neutral         COL.Bogota.Bogota   individual  PartidoRepubl14
# ...          ...                       ...          ...              ...
# 350574   neutral                       NaN   individual         RamonEdo
# 350575  negative                       NaN          NaN              NaN
# 350576  positive         COL.Bogota.Bogota   individual    riosgonzalezp
# 350577   neutral         COL.Bogota.Bogota   individual    dinersrevista
# 350578  positive  COL.Valle del Cauca.Cali   individual       Humobanda1
#
#             City   Gender  ... Categoría_Barometro_v4_-_Denuncia_Xenofobia  \
# 0         Bogota     male  ...                                         NaN
# 1            NaN  unknown  ...                                         NaN
# 2       Medellin   female  ...                                         NaN
# 3       Medellin     male  ...                                         NaN
# 4         Bogota  unknown  ...                                         NaN
# ...          ...      ...  ...                                         ...
# 350574       NaN  unknown  ...                                         NaN
# 350575       NaN  unknown  ...                                         NaN
# 350576    Bogota     male  ...                                         NaN
# 350577    Bogota  unknown  ...                                         NaN
# 350578      Cali     male  ...                                         NaN
#
#         Categoría_Barometro_v4_-_Xenofobia  Categorías_prueba_-_Denuncia  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
# ...                                    ...                           ...
# 350574                                 NaN                           NaN
# 350575                                 NaN                           NaN
# 350576                                 NaN                           NaN
# 350577                                 NaN                           NaN
# 350578                                 NaN                           NaN
#
#        Categorías_prueba_-_Xenofobia  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 350574                           NaN
# 350575                           NaN
# 350576                           NaN
# 350577                           NaN
# 350578                           NaN
#
#        Categorías_prueba_-_denuncia_xenofobia_cl  \
# 0                                              X
# 1                                            NaN
# 2                                              X
# 3                                              X
# 4                                              X
# ...                                          ...
# 350574                                       NaN
# 350575                                         X
# 350576                                         X
# 350577                                         X
# 350578                                         X
#
#        Categorías_prueba_-_denuncia_xenofobia_col  \
# 0                                               X
# 1                                               X
# 2                                               X
# 3                                               X
# 4                                               X
# ...                                           ...
# 350574                                          X
# 350575                                          X
# 350576                                        NaN
# 350577                                          X
# 350578                                        NaN
#
#        xenofobia_e_Integración_-_Integración  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 350574                                   NaN
# 350575                                   NaN
# 350576                                   NaN
# 350577                                   NaN
# 350578                                   NaN
#
#        xenofobia_e_Integración_-_Xenofobia  \
# 0                                        X
# 1                                      NaN
# 2                                        X
# 3                                      NaN
# 4                                        X
# ...                                    ...
# 350574                                   X
# 350575                                 NaN
# 350576                                 NaN
# 350577                                 NaN
# 350578                                 NaN
#
#         xenofobia_e_Integración_-_not_xenofobia  \
# 0                                             X
# 1                                           NaN
# 2                                             X
# 3                                             X
# 4                                             X
# ...                                         ...
# 350574                                      NaN
# 350575                                      NaN
# 350576                                      NaN
# 350577                                        X
# 350578                                      NaN
#
#                                                Clean_text
# 0       Justamente le acabe el guacamole picante al ve...
# 1       ..1141486160931430407] El seleccionado catarí,...
# 2       @NTN24ve EL QUE NO SABE CON QUIEN SE METE ES L...
# 3       @NoticiasCaracol Los venezolanos siempre esper...
# 4       Los 6 puntos q trata la cartica denota su prox...
# ...                                                   ...
# 350574  @yoligrilla @elespectador Y este gobierno colo...
# 350575  .., y de taquito se la sirvió a Yesus Cabrera....
# 350576  Eduardo Sosa, José David Barragán y José Luis ...
# 350577  La venezolana Jenny Camacho es la mente maestr...
# 350578  @fpcwin uno de los venezolanos buenos en su pa...
#
# [350579 rows x 37 columns]

# %%
for col in df.columns.to_list():
    print(col)
# Out:
# Unnamed: 0
# Date
# Snippet
# Domain
# Sentiment
# City_Code
# Account_Type
# Author
# City
# Gender
# Hashtags
# Impact
# Impressions
# Interest
# Mentioned_Authors
# Professions
# Thread_Author
# Thread_Entry_Type
# Total_Monthly_Visitors
# Twitter_Followers
# Twitter_Following
# Twitter_Reply_Count
# Twitter_Retweets
# Twitter_Tweets
# Twitter_Verified
# Reach_(new)
# Categoría_Barometro_v3_-_Seguridad_
# Categoría_Barometro_v4_-_Denuncia_Xenofobia
# Categoría_Barometro_v4_-_Xenofobia
# Categorías_prueba_-_Denuncia
# Categorías_prueba_-_Xenofobia
# Categorías_prueba_-_denuncia_xenofobia_cl
# Categorías_prueba_-_denuncia_xenofobia_col
# xenofobia_e_Integración_-_Integración
# xenofobia_e_Integración_-_Xenofobia
# xenofobia_e_Integración_-_not_xenofobia
# Clean_text

# %%
print(df.loc[3])
# Out:
# Unnamed: 0                                                                                     5
# Date                                                                       2020-01-08 23:55:42.0
# Snippet                                        @NoticiasCaracol Los venezolanos siempre esper...
# Domain                                                                               twitter.com
# Sentiment                                                                               negative
# City_Code                                                                 COL.Antioquia.Medellin
# Account_Type                                                                          individual
# Author                                                                                  0rwell07
# City                                                                                    Medellin
# Gender                                                                                      male
# Hashtags                                                                                     NaN
# Impact                                                                                       0.0
# Impressions                                                                                  602
# Interest                                                                                   Music
# Mentioned_Authors                                                               @noticiascaracol
# Professions                                                                                  NaN
# Thread_Author                                                                    NoticiasCaracol
# Thread_Entry_Type                                                                          reply
# Total_Monthly_Visitors                                                                6000000000
# Twitter_Followers                                                                            301
# Twitter_Following                                                                            287
# Twitter_Reply_Count                                                                            0
# Twitter_Retweets                                                                               0
# Twitter_Tweets                                                                             13374
# Twitter_Verified                                                                           False
# Reach_(new)                                                                                  0.0
# Categoría_Barometro_v3_-_Seguridad_                                                          NaN
# Categoría_Barometro_v4_-_Denuncia_Xenofobia                                                  NaN
# Categoría_Barometro_v4_-_Xenofobia                                                           NaN
# Categorías_prueba_-_Denuncia                                                                 NaN
# Categorías_prueba_-_Xenofobia                                                                NaN
# Categorías_prueba_-_denuncia_xenofobia_cl                                                      X
# Categorías_prueba_-_denuncia_xenofobia_col                                                     X
# xenofobia_e_Integración_-_Integración                                                        NaN
# xenofobia_e_Integración_-_Xenofobia                                                          NaN
# xenofobia_e_Integración_-_not_xenofobia                                                        X
# Clean_text                                     @NoticiasCaracol Los venezolanos siempre esper...
# Name: 3, dtype: object

# %%
df['Thread_Entry_Type'].unique()
# Out:
# array(['post', 'reply', 'share'], dtype=object)

# %%
# Nos vamos a quedar solo con medios, policía y figuras
# Importamos autores de medios
text = open(r"C:\Users\JOSE\Desktop\Trabajo\BX\Denuncia Xenofobia\medios.txt","r")
medios = list()
for line in text:
    line = line.rsplit("OR")
    line = line[0].strip()
    #if line.find(".") == -1:
    #    line = "@" + line
    medios.append(line)
# Vamos a guardar la lista de autores. Primero policia, luego medios tradicionales y después, alternos
medios_policia = ["PoliciaBogota", "region6policia", "region7policia", "Region8Policia", "Region2Policia", "Region3Policia", "Region1Policia",
                    "Region4Policia", "Region5Policia", "PoliciaNarino", "DevalPolicia", "PoliciaMeta", "PoliciaMedellin", "PoliciaBoyaca",
                    "PoliciaMzales", "PoliciaVillavo", "PoliciaBmanga", "PoliciaCali", "PoliciaDEMAG", "PoliciaCmarca", "Policiantioquia",
                    "PoliciaCucuta", "PoliciaQuindio", "Policia_Caldas", "SucrePolicia", "PoliciaVichada", "PoliciaGuainia",
                    "PoliciaArauca", "PoliciaCasanare", "GuajiraPolicia", "PoliciaVaupes", "PoliciaChoco", "PoliciaDepuy",
                    "PoliciaUraba", "PoliciAtlantico", "PoliciaDECOR", "PoliciaNteSder", "HuilaPolicia", "PoliciaBolivar", "PoliciaCaqueta",
                    "PoliciaDeris", "PoliciaDeTolima", "PoliciaDEMAM", "PoliciaMTunja", "PoliciaMonteria", "PoliciAmazonas", "PoliciaDeCesar",
                    "PoliciaSanyProv", "PoliciaPasto", "PoliciaStander", "PoliciaStaMarta", "PoliciaPereira", "PoliciaIbague", "PoliciaPopayan", 
                    "PoliciaCtagena", "PoliciaColombia"]
#Medios alternativos
text = open(r"C:\Users\JOSE\Desktop\Trabajo\BX\Denuncia Xenofobia\alternos.txt","r")
alternos = list()
for line in text:
    line = line.rsplit("OR")
    line = line[0].strip()
    #if line.find(".") == -1:
    #    line = "@" + line
    alternos.append(line)
figuras = ['IvanDuque', 'ClaudiaLopez', 'QuinteroCalle', 'JorgeIvanOspina', 'jaimepumarejo', 'nicolasgarciab', 
           'ernestosamperp', 'LaPullaOficial', 'DanielSamperO',
                'MariaFdaCabal', 'AlvaroUribeVel', 'petrogustavo', 'GustavoBolivar', 
           'JuanManSantos', 'PalomaValenciaL', 'AlcaldiadeMed', 'Bogota', 'sergio_fajardo', 'EstradaCarlosM', 
                'seguridadmed', 'SeguridadBOG']
todos_medios = alternos + medios + medios_policia + figuras
todos_medios
# Out:
# ['D_C_Bogota',
#  'Agencia_API',
#  'ArgumentosyOpi',
#  'lasillavacia',
#  'noticucuta',
#  '2minutosco',
#  'Elsonajeroweb',
#  'siaradio',
#  'noticierolaruta',
#  'AlertaPaisa',
#  'orientesetuguia',
#  'acuariotv',
#  'cncnoticias',
#  'Informativoan',
#  'MiPutumayo',
#  'zonacero',
#  'AtlanticoEmi',
#  'primeronoticiaa1',
#  'primeronoticiaa',
#  'CVnoticiastv',
#  'LaLibertadCo',
#  'CanalTropicaltv',
#  'elambito',
#  'NorteSeguro2018',
#  'areacucuta',
#  'CucutaDenuncia',
#  'WALLTHER_VE',
#  'noticucuta',
#  'NorteNoticiasCu',
#  'EnterateCali',
#  'norte_periodico',
#  'canalguacari',
#  'TwiterosCali',
#  'YaCelacanto',
#  'HablaManizales',
#  'tintiando',
#  'NCTNOTICIAS',
#  '1anoticiass',
#  'OsBoyaca',
#  'aldianoticiasco',
#  'LaIndependenci1',
#  'Prensalibcasan',
#  'elconucoacacias',
#  'EIExpedienteCol',
#  'hablalonoticias',
#  '7NNoticias',
#  'ElPregonar',
#  '45SegundosCom',
#  'AlPuntoCol',
#  'ColmundoRadio',
#  'ElVenezolanoCo',
#  'ExtraColombia',
#  'HSBnoticias',
#  'rodrigoprensa',
#  'Yariguies1027',
#  'BLUSantanderes',
#  'Villavoalreves',
#  'Region_365',
#  'ElInformador_SM',
#  'Seguimiento',
#  'elrotativoc',
#  'vernoticiassan1',
#  'DiarioDelNorte',
#  'NoticiasGuajira',
#  'laregionalnet',
#  'elpaisvallenato',
#  'Soyquintopoder',
#  'PrensaLlanera',
#  'croniquindio',
#  'agenciaNDS',
#  'ASAKERW',
#  'transmisora720',
#  'pvirtualcom',
#  'SuperPopayan',
#  'HoyDiarioMag',
#  'CHICACERETE',
#  'el_regionales',
#  'NoticiasBQ',
#  'elhomenoticias',
#  'HSBnoticias',
#  'HablemeC',
#  'elhomenoticias',
#  'confidencialcol',
#  'AlertaTolima',
#  'QHUBOTOLIMA',
#  'hesnoticia',
#  'norte_periodico',
#  'RioNoticiasCo',
#  'CHICACERETE',
#  'Coneolavozdelpu',
#  'lalenguacaribe',
#  'diarioriente',
#  'noticiasyabq',
#  'laotraverdadBAQ',
#  'noticoopercom',
#  'noticiasyabq',
#  'latertuliakilla',
#  'diarioelfrente',
#  'TvcucutaC',
#  'HoyNoticias2',
#  'lareporteria',
#  'CasanareonlineC',
#  'LATALPAZ',
#  'Cambio24Oficial',
#  'LaJornadaco',
#  'RadioMagdalena',
#  'EventosStaMta',
#  'LaGuajira_',
#  'hernandomontes6',
#  'TuValledupar',
#  'croniquindio',
#  'SomosAgroNotas',
#  'SASComCreativa',
#  'CostaNoticiasTV',
#  'duvanedo',
#  'AlInformativo',
#  'NPIndependiente',
#  'kesedice',
#  'atntelevision',
#  'anticorrupto26_',
#  'FronteraInforma',
#  'Horadelaverdad',
#  'SantamartaAD',
#  'LGCundinamarca',
#  'Caracol1170AM',
#  'lavibrante',
#  'Newsradio7arauc',
#  'ImpactoMundo_',
#  'ElkanalTunja',
#  'fronteravivanew',
#  'momento24co',
#  'AnalisisUrbano',
#  'SeguridadCucuta',
#  'CucutaSeguridad',
#  'FunemeTito',
#  'El_NuevoOriente',
#  'radiosantafentc',
#  'kienyke',
#  'periodispublico',
#  'diariodelsur.com.co',
#  'atlinnovacion.com',
#  'diariolalibertad.com',
#  'elcolombiano.com',
#  'extra.com.co',
#  'diariodelcauca.com.co',
#  'hoydiariodelmagdalena.com.co',
#  'diariodelhuila.com',
#  'costanoticias.com',
#  'areacucuta.com',
#  'confidencialcolombia.com',
#  'radiosantafe.com',
#  'RevistaSemana',
#  'larepublica_co',
#  'Portafolioco',
#  'RevistaDinero',
#  'NoticiasCaracol',
#  'NoticiasRCN',
#  'Citytv',
#  'InstitucionalTV',
#  'Canal1Colombia',
#  'SenalColombia',
#  'CABLENOTICIAS',
#  'CanalCapital',
#  'CanalTreceCo',
#  'NoticiasUno',
#  'NTN24',
#  'lafm',
#  'BluRadioCo',
#  'dinersrevista',
#  'colombiareports',
#  'mundoinstante',
#  'pulzo',
#  'PublimetroCol',
#  'RedPrensaVerde',
#  'semana.com',
#  'larepublica.co',
#  'portafolio.co',
#  'dinero.com',
#  'noticias.caracoltv.com',
#  'noticias.canalrcn.com',
#  'citytv.com.co',
#  'canalinstitucional.tv',
#  'noticias.canal1.com.co',
#  'senalcolombia.tv',
#  'cablenoticias.tv',
#  'canalcapital.gov.co',
#  'canaltrece.com.co',
#  'noticiasuno.com',
#  'ntn24.com',
#  'lafm.com.co',
#  'bluradio.com',
#  'revistadiners.com.co',
#  'colombiareports.com',
#  'elmundoalinstante.com',
#  'pulzo.com',
#  'publimetro.co',
#  'redprensaverde.org',
#  'elheraldoco',
#  'LaLibertadCo',
#  'CanalTelecaribe',
#  'QhuboQuilla',
#  'adnbarranquilla',
#  'diariolalibertad.com',
#  'telecaribe.co',
#  'qhubo.com',
#  'diarioadn.co',
#  'ELTIEMPO',
#  'elespectador',
#  'ElNuevoSiglo',
#  'malpensante',
#  'RevistaLNE',
#  'citypaperbogota',
#  'BogotaPost',
#  'QhuboBogota',
#  'adncolombia',
#  'Gatopardocom',
#  'elespectador.com',
#  'elnuevosiglo.com.co',
#  'elmalpensante.com',
#  'lanotaeconomica.com.co',
#  'thecitypaperbogota.com',
#  'thebogotapost.com',
#  'qhubobogota.com',
#  'diarioadn.co',
#  'gatopardo.com',
#  'Diarioccidente',
#  'elpaiscali',
#  'TelepacificoTV',
#  'Noti90Minutos',
#  'Redsonoraradio',
#  'QhuboCali',
#  'adncali',
#  'elpais.com.co',
#  'telepacifico.com',
#  '90minutos.co',
#  'redsonoraradio.net',
#  'qhubocali.com',
#  'diarioadn.co',
#  'laopinioncucuta',
#  'QhuboCucuta',
#  'TvcucutaC',
#  'noticucuta',
#  'TUKANAL',
#  'CucutaEsNoticia',
#  'LaVozDelNorteAM',
#  'CaracolCucuta',
#  'qhubo.com',
#  'tvcucuta.com',
#  'noticucuta3.blogspot.com',
#  'tukanal.tv',
#  'cucutaesnoticia.com',
#  'elcolombiano',
#  'Teleantioquia',
#  'Telemedellin',
#  'minuto30com',
#  'QhuboMedallo',
#  'ADNMedellin',
#  'hora13noticias',
#  'Centropolis_med',
#  'elpalpitar',
#  'ActualidadPol',
#  'DespiertaAnt',
#  'vivirpoblado',
#  'teleantioquia.co',
#  'telemedellin.tv',
#  'minuto30.com',
#  'qhubo.com',
#  'diarioadn.co',
#  'h13n.com',
#  'centropolismedellin.com',
#  'elpalpitar.com',
#  'actualidad.com.co',
#  'despiertaantioquia.com',
#  'vivirenelpoblado.com',
#  'PoliciaBogota',
#  'region6policia',
#  'region7policia',
#  'Region8Policia',
#  'Region2Policia',
#  'Region3Policia',
#  'Region1Policia',
#  'Region4Policia',
#  'Region5Policia',
#  'PoliciaNarino',
#  'DevalPolicia',
#  'PoliciaMeta',
#  'PoliciaMedellin',
#  'PoliciaBoyaca',
#  'PoliciaMzales',
#  'PoliciaVillavo',
#  'PoliciaBmanga',
#  'PoliciaCali',
#  'PoliciaDEMAG',
#  'PoliciaCmarca',
#  'Policiantioquia',
#  'PoliciaCucuta',
#  'PoliciaQuindio',
#  'Policia_Caldas',
#  'SucrePolicia',
#  'PoliciaVichada',
#  'PoliciaGuainia',
#  'PoliciaArauca',
#  'PoliciaCasanare',
#  'GuajiraPolicia',
#  'PoliciaVaupes',
#  'PoliciaChoco',
#  'PoliciaDepuy',
#  'PoliciaUraba',
#  'PoliciAtlantico',
#  'PoliciaDECOR',
#  'PoliciaNteSder',
#  'HuilaPolicia',
#  'PoliciaBolivar',
#  'PoliciaCaqueta',
#  'PoliciaDeris',
#  'PoliciaDeTolima',
#  'PoliciaDEMAM',
#  'PoliciaMTunja',
#  'PoliciaMonteria',
#  'PoliciAmazonas',
#  'PoliciaDeCesar',
#  'PoliciaSanyProv',
#  'PoliciaPasto',
#  'PoliciaStander',
#  'PoliciaStaMarta',
#  'PoliciaPereira',
#  'PoliciaIbague',
#  'PoliciaPopayan',
#  'PoliciaCtagena',
#  'PoliciaColombia',
#  'IvanDuque',
#  'ClaudiaLopez',
#  'QuinteroCalle',
#  'JorgeIvanOspina',
#  'jaimepumarejo',
#  'nicolasgarciab',
#  'ernestosamperp',
#  'LaPullaOficial',
#  'DanielSamperO',
#  'MariaFdaCabal',
#  'AlvaroUribeVel',
#  'petrogustavo',
#  'GustavoBolivar',
#  'JuanManSantos',
#  'PalomaValenciaL',
#  'AlcaldiadeMed',
#  'Bogota',
#  'sergio_fajardo',
#  'EstradaCarlosM',
#  'seguridadmed',
#  'SeguridadBOG']

# %%
# ESTE CÓDIGO ES UN BOOLEAN MASK HECHO A MANO, PUEDE TARDAR MUCHO
nonan = df[~df['Thread_Author'].isnull()]
tipos = [alternos, medios, medios_policia, figuras]
nombres = ['alternos', 'tradicionales', 'policia','figuras']
nonan['Tipo_de_autor'] = ''
i = 0
for tipo in tipos:
    nombre = nombres[i]
    i += 1
    for autor in tipo:
        nonan.loc[nonan.Thread_Author == autor, 'Tipo_de_autor'] = nombre
datos = nonan[np.logical_or.reduce([nonan['Thread_Author'].str.contains(autor) for autor in todos_medios])]
datos = datos.reset_index()
datos
# Out:
# <ipython-input-69-888416789af0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonan['Tipo_de_autor'] = ''
# C:\Users\JOSE\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#         index  Unnamed: 0                   Date  \
# 0           2           4  2020-01-08 23:58:10.0
# 1           3           5  2020-01-08 23:55:42.0
# 2          15          34  2020-01-08 23:32:58.0
# 3          36          76  2020-01-08 22:51:46.0
# 4         108         225  2020-01-08 20:36:22.0
# ...       ...         ...                    ...
# 31110  350417       46598  2021-03-08 12:07:38.0
# 31111  350419       46604  2021-03-08 12:04:41.0
# 31112  350478       46753  2021-03-08 04:20:21.0
# 31113  350553       46946  2021-03-08 00:56:15.0
# 31114  350573       46993  2021-03-08 00:13:35.0
#
#                                                  Snippet       Domain  \
# 0      @NTN24ve EL QUE NO SABE CON QUIEN SE METE ES L...  twitter.com
# 1      @NoticiasCaracol Los venezolanos siempre esper...  twitter.com
# 2      @petrogustavo Yo me imagino una economía en la...  twitter.com
# 3      @IvanDuque Menos hablabla y más acción, ahora ...  twitter.com
# 4      @NoticiasCaracol Veneco hijo de puta, merece l...  twitter.com
# ...                                                  ...          ...
# 31110  @petrogustavo Así eres tú un aprovechado popul...  twitter.com
# 31111  @NTN24ve Y las Vacunas para los Venezolanos? Q...  twitter.com
# 31112  @Citytv Una avalancha de venecos y dos millone...  twitter.com
# 31113  @PublimetroCol Estas son las “ideas” nefastas ...  twitter.com
# 31114  En serio venid todos hermanos venezolanos aca ...  twitter.com
#
#       Sentiment                   City_Code Account_Type           Author  \
# 0      positive      COL.Antioquia.Medellin   individual     LeilaLozano3
# 1      negative      COL.Antioquia.Medellin   individual         0rwell07
# 2      negative                         NaN   individual       MrSwanMods
# 3      negative           COL.Bogota.Bogota   individual      billyjohnns
# 4      negative           COL.Bogota.Bogota   individual   carlomagno2704
# ...         ...                         ...          ...              ...
# 31110  negative           COL.Bogota.Bogota   individual          andirup
# 31111  negative  COL.Atlantico.Barranquilla   individual            MAPY2
# 31112   neutral           COL.Bogota.Bogota   individual    alexfajardo71
# 31113  negative                         NaN   individual  DiegoAl50239232
# 31114  negative                         NaN   individual  El_rolo_es_fapu
#
#                City  ... Categoría_Barometro_v4_-_Xenofobia  \
# 0          Medellin  ...                                NaN
# 1          Medellin  ...                                NaN
# 2               NaN  ...                                NaN
# 3            Bogota  ...                                NaN
# 4            Bogota  ...                                NaN
# ...             ...  ...                                ...
# 31110        Bogota  ...                                NaN
# 31111  Barranquilla  ...                                NaN
# 31112        Bogota  ...                                NaN
# 31113           NaN  ...                                NaN
# 31114           NaN  ...                                NaN
#
#       Categorías_prueba_-_Denuncia  Categorías_prueba_-_Xenofobia  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ...                            ...                            ...
# 31110                          NaN                            NaN
# 31111                          NaN                            NaN
# 31112                          NaN                            NaN
# 31113                          NaN                            NaN
# 31114                          NaN                            NaN
#
#        Categorías_prueba_-_denuncia_xenofobia_cl  \
# 0                                              X
# 1                                              X
# 2                                              X
# 3                                              X
# 4                                              X
# ...                                          ...
# 31110                                          X
# 31111                                          X
# 31112                                          X
# 31113                                          X
# 31114                                          X
#
#       Categorías_prueba_-_denuncia_xenofobia_col  \
# 0                                              X
# 1                                              X
# 2                                              X
# 3                                              X
# 4                                              X
# ...                                          ...
# 31110                                        NaN
# 31111                                          X
# 31112                                          X
# 31113                                          X
# 31114                                        NaN
#
#       xenofobia_e_Integración_-_Integración  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 31110                                     X
# 31111                                   NaN
# 31112                                   NaN
# 31113                                   NaN
# 31114                                     X
#
#       xenofobia_e_Integración_-_Xenofobia  \
# 0                                       X
# 1                                     NaN
# 2                                     NaN
# 3                                       X
# 4                                       X
# ...                                   ...
# 31110                                 NaN
# 31111                                 NaN
# 31112                                   X
# 31113                                   X
# 31114                                 NaN
#
#       xenofobia_e_Integración_-_not_xenofobia  \
# 0                                           X
# 1                                           X
# 2                                           X
# 3                                           X
# 4                                           X
# ...                                       ...
# 31110                                     NaN
# 31111                                       X
# 31112                                       X
# 31113                                       X
# 31114                                     NaN
#
#                                               Clean_text  Tipo_de_autor
# 0      @NTN24ve EL QUE NO SABE CON QUIEN SE METE ES L...
# 1      @NoticiasCaracol Los venezolanos siempre esper...  tradicionales
# 2      @petrogustavo Yo me imagino una economía en la...        figuras
# 3      @IvanDuque Menos hablabla y más acción, ahora ...        figuras
# 4      @NoticiasCaracol Veneco hijo de puta, merece l...  tradicionales
# ...                                                  ...            ...
# 31110  @petrogustavo Así eres tú un aprovechado popul...        figuras
# 31111  @NTN24ve Y las Vacunas para los Venezolanos? Q...
# 31112  @Citytv Una avalancha de venecos y dos millone...  tradicionales
# 31113  @PublimetroCol Estas son las “ideas” nefastas ...  tradicionales
# 31114  En serio venid todos hermanos venezolanos aca ...  tradicionales
#
# [31115 rows x 39 columns]

# %%
vacios = datos[datos['Tipo_de_autor'] == '']
print(vacios['Thread_Author'].unique())
# Out:
# ['NTN24ve' 'Bogota__DC' 'ActivistaBogota' 'ArribaBogota' 'BogotaTransito'
#  'BogotaET' 'AlertaBogota' 'CGurisattiNTN24' 'MirandaBogota' 'elBogotano'
#  'DadepBogota' 'ConcejoDeBogota' 'NCBogota' 'LaNocheNTN24'
#  'BogotanoAnonimo' 'Parque93Bogota' 'BogotaInter_nal' 'lafmmedellin'
#  'BogotaMiBarrio' 'JeffersonNTN24' 'VeeduriaBogota' 'BomberosBogota'
#  'BogotaParticipa' 'VladoBogota' 'VzlanosBogota' 'elcolombianox19'
#  'LasernaBogota' 'UnaBogotana' 'SrBogotano' 'BogotaCurioso' 'MillanBogota'
#  'NovioBogota' 'USEmbassyBogota' 'YoSoyDeBogota' 'Fontibon_Bogota'
#  'TerminalBogota' 'Bogota31610272' 'DonBogotano' 'MonoMarioBogota'
#  'ElSolBogota' 'GuzmanBogota' 'NTN24Zoom' 'VenecoBogota' 'ArchivodeBogota'
#  'lafmdeleje' '23Bogota' 'CPoderNTN24' 'MetroBogota' 'ElBogotan0'
#  'BogotaLogica' 'FabianLBogota' 'EnamorateBogota' 'BogotaCruising'
#  'AjiDulceBogota' 'BogotaEE' 'Bogotaensis' 'ClubPrensaNTN24' 'TropiBogota'
#  'GerardoBogota' 'BogotaHumana_' 'DjxBogota' 'NayiBogota' 'BogotaseMueve'
#  'UNICDBogota' 'ActivoBogota21' 'BogotaDCBogotaD' 'BogotaDCMejor']

# %%
coldrop = ['Categoría_Barometro_v3_-_Seguridad_' ,
'Categoría_Barometro_v4_-_Denuncia_Xenofobia',
'Categoría_Barometro_v4_-_Xenofobia',
'Categorías_prueba_-_Denuncia',
'Categorías_prueba_-_Xenofobia',
'Categorías_prueba_-_denuncia_xenofobia_cl',
'Categorías_prueba_-_denuncia_xenofobia_col',
'index','Unnamed: 0', 'xenofobia_e_Integración_-_not_xenofobia']
datos = datos.drop(coldrop, axis = 1)
datos['xenofobia_e_Integración_-_Xenofobia'] = datos['xenofobia_e_Integración_-_Xenofobia'].map({"NaN":0 , np.nan:0, 'X':1, 'x':1})
datos['xenofobia_e_Integración_-_Integración'] = datos['xenofobia_e_Integración_-_Integración'].map({"NaN":0, np.nan:0 , 'X':1, 'x':1})
datos
# Out:
#                         Date  \
# 0      2020-01-08 23:58:10.0
# 1      2020-01-08 23:55:42.0
# 2      2020-01-08 23:32:58.0
# 3      2020-01-08 22:51:46.0
# 4      2020-01-08 20:36:22.0
# ...                      ...
# 31110  2021-03-08 12:07:38.0
# 31111  2021-03-08 12:04:41.0
# 31112  2021-03-08 04:20:21.0
# 31113  2021-03-08 00:56:15.0
# 31114  2021-03-08 00:13:35.0
#
#                                                  Snippet       Domain  \
# 0      @NTN24ve EL QUE NO SABE CON QUIEN SE METE ES L...  twitter.com
# 1      @NoticiasCaracol Los venezolanos siempre esper...  twitter.com
# 2      @petrogustavo Yo me imagino una economía en la...  twitter.com
# 3      @IvanDuque Menos hablabla y más acción, ahora ...  twitter.com
# 4      @NoticiasCaracol Veneco hijo de puta, merece l...  twitter.com
# ...                                                  ...          ...
# 31110  @petrogustavo Así eres tú un aprovechado popul...  twitter.com
# 31111  @NTN24ve Y las Vacunas para los Venezolanos? Q...  twitter.com
# 31112  @Citytv Una avalancha de venecos y dos millone...  twitter.com
# 31113  @PublimetroCol Estas son las “ideas” nefastas ...  twitter.com
# 31114  En serio venid todos hermanos venezolanos aca ...  twitter.com
#
#       Sentiment                   City_Code Account_Type           Author  \
# 0      positive      COL.Antioquia.Medellin   individual     LeilaLozano3
# 1      negative      COL.Antioquia.Medellin   individual         0rwell07
# 2      negative                         NaN   individual       MrSwanMods
# 3      negative           COL.Bogota.Bogota   individual      billyjohnns
# 4      negative           COL.Bogota.Bogota   individual   carlomagno2704
# ...         ...                         ...          ...              ...
# 31110  negative           COL.Bogota.Bogota   individual          andirup
# 31111  negative  COL.Atlantico.Barranquilla   individual            MAPY2
# 31112   neutral           COL.Bogota.Bogota   individual    alexfajardo71
# 31113  negative                         NaN   individual  DiegoAl50239232
# 31114  negative                         NaN   individual  El_rolo_es_fapu
#
#                City   Gender           Hashtags  ...  Twitter_Following  \
# 0          Medellin   female                NaN  ...                 21
# 1          Medellin     male                NaN  ...                287
# 2               NaN  unknown                NaN  ...                102
# 3            Bogota     male                NaN  ...                364
# 4            Bogota     male                NaN  ...               4997
# ...             ...      ...                ...  ...                ...
# 31110        Bogota     male                NaN  ...                 39
# 31111  Barranquilla   female                NaN  ...                460
# 31112        Bogota  unknown                NaN  ...                520
# 31113           NaN  unknown  #alvarouribevelez  ...                177
# 31114           NaN  unknown                NaN  ...                282
#
#        Twitter_Reply_Count Twitter_Retweets Twitter_Tweets Twitter_Verified  \
# 0                        0                0            878            False
# 1                        0                0          13374            False
# 2                        0                0           1216            False
# 3                        0                0            115            False
# 4                        0                0          36459            False
# ...                    ...              ...            ...              ...
# 31110                    0                0            352            False
# 31111                    0                0          14770            False
# 31112                    0                0          11497            False
# 31113                    0                0           5245            False
# 31114                    0                0          16930            False
#
#       Reach_(new) xenofobia_e_Integración_-_Integración  \
# 0             0.0                                     0
# 1             0.0                                     0
# 2             0.0                                     0
# 3             0.0                                     0
# 4          3774.0                                     0
# ...           ...                                   ...
# 31110         0.0                                     1
# 31111         0.0                                     0
# 31112         0.0                                     0
# 31113         0.0                                     0
# 31114         0.0                                     1
#
#        xenofobia_e_Integración_-_Xenofobia  \
# 0                                        1
# 1                                        0
# 2                                        0
# 3                                        1
# 4                                        1
# ...                                    ...
# 31110                                    0
# 31111                                    0
# 31112                                    1
# 31113                                    1
# 31114                                    0
#
#                                               Clean_text  Tipo_de_autor
# 0      @NTN24ve EL QUE NO SABE CON QUIEN SE METE ES L...
# 1      @NoticiasCaracol Los venezolanos siempre esper...  tradicionales
# 2      @petrogustavo Yo me imagino una economía en la...        figuras
# 3      @IvanDuque Menos hablabla y más acción, ahora ...        figuras
# 4      @NoticiasCaracol Veneco hijo de puta, merece l...  tradicionales
# ...                                                  ...            ...
# 31110  @petrogustavo Así eres tú un aprovechado popul...        figuras
# 31111  @NTN24ve Y las Vacunas para los Venezolanos? Q...
# 31112  @Citytv Una avalancha de venecos y dos millone...  tradicionales
# 31113  @PublimetroCol Estas son las “ideas” nefastas ...  tradicionales
# 31114  En serio venid todos hermanos venezolanos aca ...  tradicionales
#
# [31115 rows x 29 columns]

# %%
dups_shape = datos.pivot_table(index=['Thread_Author'], aggfunc='size')
dups_shape = pd.DataFrame(dups_shape)
mapping = {dups_shape.columns[0]:'Total_replies'}
dups_shape = dups_shape.rename(columns=mapping)
dups_shape
# Out:
#                  Total_replies
# Thread_Author
# 1anoticiass                  4
# 23Bogota                     2
# 45SegundosCom               21
# 7NNoticias                   2
# ActivistaBogota              2
# ...                        ...
# rodrigoprensa                7
# seguridadmed                 3
# sergio_fajardo              61
# vivirpoblado                 1
# zonacero                   252
#
# [228 rows x 1 columns]

# %%
prueba = datos[datos['Thread_Author'] == 'NoticiasCaracol']
prueba
# Out:
#                         Date  \
# 1      2020-01-08 23:55:42.0
# 4      2020-01-08 20:36:22.0
# 5      2020-01-08 20:32:05.0
# 7      2020-01-08 19:54:09.0
# 8      2020-01-08 19:52:26.0
# ...                      ...
# 31057  2021-03-09 17:04:41.0
# 31070  2021-03-09 12:44:55.0
# 31077  2021-03-09 04:20:12.0
# 31082  2021-03-09 02:12:31.0
# 31095  2021-03-08 22:47:56.0
#
#                                                  Snippet       Domain  \
# 1      @NoticiasCaracol Los venezolanos siempre esper...  twitter.com
# 4      @NoticiasCaracol Veneco hijo de puta, merece l...  twitter.com
# 5      @NoticiasCaracol Nada. Partiendo de que es ciu...  twitter.com
# 7      @NoticiasCaracol LO DE SIEMPRE CON LOS VENEZOL...  twitter.com
# 8      @NoticiasCaracol No he podido conocer al prime...  twitter.com
# ...                                                  ...          ...
# 31057  @NoticiasCaracol Y el gobierno ayuda con el es...  twitter.com
# 31070  @NoticiasCaracol Tenemos a todos los venecos d...  twitter.com
# 31077  @NoticiasCaracol Nos quejamos porque nos trata...  twitter.com
# 31082  Preocupación en las toldas uribistas, menos ve...  twitter.com
# 31095  @NoticiasCaracol Acá los desplazados tiene que...  twitter.com
#
#       Sentiment                  City_Code Account_Type           Author  \
# 1      negative     COL.Antioquia.Medellin   individual         0rwell07
# 4      negative          COL.Bogota.Bogota   individual   carlomagno2704
# 5      negative          COL.Bogota.Bogota   individual       avendano89
# 7       neutral          COL.Bogota.Bogota   individual         lpacho55
# 8      positive  COL.Magdalena.Santa Marta   individual  juandavid181006
# ...         ...                        ...          ...              ...
# 31057   neutral          COL.Bogota.Bogota   individual  Adrianarincon07
# 31070  negative          COL.Bogota.Bogota   individual    bogotano_1538
# 31077  negative          COL.Bogota.Bogota   individual  CarlosA51856874
# 31082  negative          COL.Bogota.Bogota   individual     RobertoMTico
# 31095  negative          COL.Bogota.Bogota   individual    nosoyladrillo
#
#               City   Gender Hashtags  ...  Twitter_Following  \
# 1         Medellin     male      NaN  ...                287
# 4           Bogota     male      NaN  ...               4997
# 5           Bogota     male      NaN  ...                 80
# 7           Bogota     male      NaN  ...               4690
# 8      Santa Marta     male      NaN  ...                 53
# ...            ...      ...      ...  ...                ...
# 31057       Bogota   female      NaN  ...                 65
# 31070       Bogota     male      NaN  ...                240
# 31077       Bogota     male      NaN  ...                232
# 31082       Bogota  unknown      NaN  ...              12480
# 31095       Bogota  unknown      NaN  ...                399
#
#        Twitter_Reply_Count Twitter_Retweets Twitter_Tweets Twitter_Verified  \
# 1                        0                0          13374            False
# 4                        0                0          36459            False
# 5                        0                0           3156            False
# 7                        0                0          28058            False
# 8                        0                0          10638            False
# ...                    ...              ...            ...              ...
# 31057                    0                0            530            False
# 31070                    0                0           1564            False
# 31077                    0                0           5487            False
# 31082                    2               14          30964            False
# 31095                    0                0           1494            False
#
#       Reach_(new) xenofobia_e_Integración_-_Integración  \
# 1             0.0                                     0
# 4          3774.0                                     0
# 5             0.0                                     0
# 7           468.0                                     0
# 8             0.0                                     1
# ...           ...                                   ...
# 31057         0.0                                     0
# 31070         0.0                                     0
# 31077         0.0                                     1
# 31082     17709.0                                     0
# 31095         0.0                                     0
#
#        xenofobia_e_Integración_-_Xenofobia  \
# 1                                        0
# 4                                        1
# 5                                        0
# 7                                        0
# 8                                        0
# ...                                    ...
# 31057                                    0
# 31070                                    1
# 31077                                    0
# 31082                                    0
# 31095                                    0
#
#                                               Clean_text  Tipo_de_autor
# 1      @NoticiasCaracol Los venezolanos siempre esper...  tradicionales
# 4      @NoticiasCaracol Veneco hijo de puta, merece l...  tradicionales
# 5      @NoticiasCaracol Nada. Partiendo de que es ciu...  tradicionales
# 7      @NoticiasCaracol LO DE SIEMPRE CON LOS VENEZOL...  tradicionales
# 8      @NoticiasCaracol No he podido conocer al prime...  tradicionales
# ...                                                  ...            ...
# 31057  @NoticiasCaracol Y el gobierno ayuda con el es...  tradicionales
# 31070  @NoticiasCaracol Tenemos a todos los venecos d...  tradicionales
# 31077  @NoticiasCaracol Nos quejamos porque nos trata...  tradicionales
# 31082  Preocupación en las toldas uribistas, menos ve...  tradicionales
# 31095  @NoticiasCaracol Acá los desplazados tiene que...  tradicionales
#
# [2877 rows x 29 columns]

# %%
print("Noticias Caracol generó " + str(prueba['xenofobia_e_Integración_-_Xenofobia'].sum()) + " replies xenofobos de las " + str(prueba.shape[0]) + " replies capturadas")
# Out:
# Noticias Caracol generó 974 replies xenofobos de las 2877 replies capturadas

# %%
grouped = datos.groupby('Thread_Author')
grouped.agg([np.sum]).loc[['NoticiasCaracol']]
# Out:
#                                                               Date  \
#                                                                sum
# Thread_Author
# NoticiasCaracol  2020-01-08 23:55:42.02020-01-08 20:36:22.02020...
#
#                                                            Snippet  \
#                                                                sum
# Thread_Author
# NoticiasCaracol  @NoticiasCaracol Los venezolanos siempre esper...
#
#                                                             Domain  \
#                                                                sum
# Thread_Author
# NoticiasCaracol  twitter.comtwitter.comtwitter.comtwitter.comtw...
#
#                                                          Sentiment  \
#                                                                sum
# Thread_Author
# NoticiasCaracol  negativenegativenegativeneutralpositiveneutral...
#
#                                                       Account_Type  \
#                                                                sum
# Thread_Author
# NoticiasCaracol  individualindividualindividualindividualindivi...
#
#                                                             Author   Impact  \
#                                                                sum      sum
# Thread_Author
# NoticiasCaracol  0rwell07carlomagno2704avendano89lpacho55juanda...  14166.0
#
#                 Impressions  \
#                         sum
# Thread_Author
# NoticiasCaracol     3568879
#
#                                                  Thread_Entry_Type  \
#                                                                sum
# Thread_Author
# NoticiasCaracol  replyreplyreplyreplyreplyreplyreplyreplyreplyr...
#
#                 Total_Monthly_Visitors  ... Twitter_Following  \
#                                    sum  ...               sum
# Thread_Author                           ...
# NoticiasCaracol         17262000000000  ...           1625902
#
#                 Twitter_Reply_Count Twitter_Retweets Twitter_Tweets  \
#                                 sum              sum            sum
# Thread_Author
# NoticiasCaracol                 772              672       32334549
#
#                 Twitter_Verified Reach_(new)  \
#                              sum         sum
# Thread_Author
# NoticiasCaracol                3   1508895.0
#
#                 xenofobia_e_Integración_-_Integración  \
#                                                   sum
# Thread_Author
# NoticiasCaracol                                   224
#
#                 xenofobia_e_Integración_-_Xenofobia  \
#                                                 sum
# Thread_Author
# NoticiasCaracol                                 974
#
#                                                         Clean_text  \
#                                                                sum
# Thread_Author
# NoticiasCaracol  @NoticiasCaracol Los venezolanos siempre esper...
#
#                                                      Tipo_de_autor
#                                                                sum
# Thread_Author
# NoticiasCaracol  tradicionalestradicionalestradicionalestradici...
#
# [1 rows x 21 columns]

# %%
grouped.agg([np.sum]).loc[['NoticiasCaracol']]['xenofobia_e_Integración_-_Xenofobia']
# Out:
# Thread_Author
# NoticiasCaracol    974
# Name: sum, dtype: int64

# %%
frame_grouped = grouped.agg([np.sum])
datos['replies_xenofobos_Thread_Author'] = ''
datos['replies_integracion_Thread_Author'] = ''
lista_autores_base = frame_grouped.index.unique()
print(lista_autores_base)
for autor in lista_autores_base:
    datos.loc[datos.Thread_Author == autor, 'replies_xenofobos_Thread_Author'] = int(frame_grouped.loc[[autor]]['xenofobia_e_Integración_-_Xenofobia']['sum'])
    datos.loc[datos.Thread_Author == autor, 'replies_integracion_Thread_Author'] = int(frame_grouped.loc[[autor]]['xenofobia_e_Integración_-_Integración']['sum'])
datos = pd.merge(datos,dups_shape,how='left',left_on='Thread_Author',right_on=dups_shape.index)
datos
# Out:
# Index(['1anoticiass', '23Bogota', '45SegundosCom', '7NNoticias',
#        'ActivistaBogota', 'ActivoBogota21', 'Agencia_API', 'AjiDulceBogota',
#        'AlPuntoCol', 'AlcaldiadeMed',
#        ...
#        'petrogustavo', 'primeronoticiaa', 'pulzo', 'pvirtualcom',
#        'radiosantafentc', 'rodrigoprensa', 'seguridadmed', 'sergio_fajardo',
#        'vivirpoblado', 'zonacero'],
#       dtype='object', name='Thread_Author', length=228)
#                         Date  \
# 0      2020-01-08 23:58:10.0
# 1      2020-01-08 23:55:42.0
# 2      2020-01-08 23:32:58.0
# 3      2020-01-08 22:51:46.0
# 4      2020-01-08 20:36:22.0
# ...                      ...
# 31110  2021-03-08 12:07:38.0
# 31111  2021-03-08 12:04:41.0
# 31112  2021-03-08 04:20:21.0
# 31113  2021-03-08 00:56:15.0
# 31114  2021-03-08 00:13:35.0
#
#                                                  Snippet       Domain  \
# 0      @NTN24ve EL QUE NO SABE CON QUIEN SE METE ES L...  twitter.com
# 1      @NoticiasCaracol Los venezolanos siempre esper...  twitter.com
# 2      @petrogustavo Yo me imagino una economía en la...  twitter.com
# 3      @IvanDuque Menos hablabla y más acción, ahora ...  twitter.com
# 4      @NoticiasCaracol Veneco hijo de puta, merece l...  twitter.com
# ...                                                  ...          ...
# 31110  @petrogustavo Así eres tú un aprovechado popul...  twitter.com
# 31111  @NTN24ve Y las Vacunas para los Venezolanos? Q...  twitter.com
# 31112  @Citytv Una avalancha de venecos y dos millone...  twitter.com
# 31113  @PublimetroCol Estas son las “ideas” nefastas ...  twitter.com
# 31114  En serio venid todos hermanos venezolanos aca ...  twitter.com
#
#       Sentiment                   City_Code Account_Type           Author  \
# 0      positive      COL.Antioquia.Medellin   individual     LeilaLozano3
# 1      negative      COL.Antioquia.Medellin   individual         0rwell07
# 2      negative                         NaN   individual       MrSwanMods
# 3      negative           COL.Bogota.Bogota   individual      billyjohnns
# 4      negative           COL.Bogota.Bogota   individual   carlomagno2704
# ...         ...                         ...          ...              ...
# 31110  negative           COL.Bogota.Bogota   individual          andirup
# 31111  negative  COL.Atlantico.Barranquilla   individual            MAPY2
# 31112   neutral           COL.Bogota.Bogota   individual    alexfajardo71
# 31113  negative                         NaN   individual  DiegoAl50239232
# 31114  negative                         NaN   individual  El_rolo_es_fapu
#
#                City   Gender           Hashtags  ...  Twitter_Tweets  \
# 0          Medellin   female                NaN  ...             878
# 1          Medellin     male                NaN  ...           13374
# 2               NaN  unknown                NaN  ...            1216
# 3            Bogota     male                NaN  ...             115
# 4            Bogota     male                NaN  ...           36459
# ...             ...      ...                ...  ...             ...
# 31110        Bogota     male                NaN  ...             352
# 31111  Barranquilla   female                NaN  ...           14770
# 31112        Bogota  unknown                NaN  ...           11497
# 31113           NaN  unknown  #alvarouribevelez  ...            5245
# 31114           NaN  unknown                NaN  ...           16930
#
#        Twitter_Verified Reach_(new) xenofobia_e_Integración_-_Integración  \
# 0                 False         0.0                                     0
# 1                 False         0.0                                     0
# 2                 False         0.0                                     0
# 3                 False         0.0                                     0
# 4                 False      3774.0                                     0
# ...                 ...         ...                                   ...
# 31110             False         0.0                                     1
# 31111             False         0.0                                     0
# 31112             False         0.0                                     0
# 31113             False         0.0                                     0
# 31114             False         0.0                                     1
#
#       xenofobia_e_Integración_-_Xenofobia  \
# 0                                       1
# 1                                       0
# 2                                       0
# 3                                       1
# 4                                       1
# ...                                   ...
# 31110                                   0
# 31111                                   0
# 31112                                   1
# 31113                                   1
# 31114                                   0
#
#                                               Clean_text  Tipo_de_autor  \
# 0      @NTN24ve EL QUE NO SABE CON QUIEN SE METE ES L...
# 1      @NoticiasCaracol Los venezolanos siempre esper...  tradicionales
# 2      @petrogustavo Yo me imagino una economía en la...        figuras
# 3      @IvanDuque Menos hablabla y más acción, ahora ...        figuras
# 4      @NoticiasCaracol Veneco hijo de puta, merece l...  tradicionales
# ...                                                  ...            ...
# 31110  @petrogustavo Así eres tú un aprovechado popul...        figuras
# 31111  @NTN24ve Y las Vacunas para los Venezolanos? Q...
# 31112  @Citytv Una avalancha de venecos y dos millone...  tradicionales
# 31113  @PublimetroCol Estas son las “ideas” nefastas ...  tradicionales
# 31114  En serio venid todos hermanos venezolanos aca ...  tradicionales
#
#        replies_xenofobos_Thread_Author  replies_integracion_Thread_Author  \
# 0                                   46                                 28
# 1                                  974                                224
# 2                                  674                                220
# 3                                  357                                240
# 4                                  974                                224
# ...                                ...                                ...
# 31110                              674                                220
# 31111                               46                                 28
# 31112                              668                                126
# 31113                               27                                  6
# 31114                              414                                 86
#
#        Total_replies
# 0                293
# 1               2877
# 2               2392
# 3               1906
# 4               2877
# ...              ...
# 31110           2392
# 31111            293
# 31112           1663
# 31113             96
# 31114           1297
#
# [31115 rows x 32 columns]

# %%
datos.to_excel('datos_replies.xlsx')
