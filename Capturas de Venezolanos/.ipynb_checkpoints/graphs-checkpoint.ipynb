# %%
import pandas as pd
import numpy as np
import os
import re
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
from jupyterthemes import jtplot
# Fondo oscuro
#jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)
# Fondo blanco
jtplot.style(theme='grade3', context='notebook', ticks=True, grid=True)
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = pd.read_excel(r'C:\Users\JOSE\Desktop\Trabajo\BX\Capturas de Venezolanos\Base_final_colapsada.xlsx')
#base = pd.read_excel(r'D:\Trabajo\Barómetro\BX\Capturas de Venezolanos\Base_final_colapsada.xlsx')
base
# Out:
#       Unnamed: 0  mes_año                                          Ubicación  \
# 0              0  10_2019  Bucaramanga, Cúcuta, Santander, Norte de Santa...
# 1              1  10_2020                                           Amazonas
# 2              2  10_2020                                          Atlantico
# 3              3  10_2020                       Bogotá, Boyacá, Cundinamarca
# 4              4  10_2020  Bucaramanga, Cúcuta, Santander, Norte de Santa...
# ...          ...      ...                                                ...
# 1052        1052   9_2022                                    Valle del Cauca
# 1053        1053   9_2022                                             Vaupes
# 1054        1054   9_2022                                            Vichada
# 1055        1055   9_2022                                      Villavicencio
# 1056        1056   9_2022  Villavicencio, Meta, Casanare, Amazonas, Guain...
#
#       Unnamed: 0.1            id  Capturas  Migrantes  Capturas Migrantes  \
# 0          2486808  1.030143e+20        10          0                   0
# 1          9952174  8.959990e+19         5          0                   0
# 2         12238435  1.447591e+20        12          0                   0
# 3          4064819  2.463349e+20        40          0                   0
# 4           664788  3.158886e+19         2          0                   0
# ...            ...           ...       ...        ...                 ...
# 1052       3817949  1.852271e+20         0          0                   0
# 1053       7604619  1.241031e+20         7          0                   0
# 1054       9382230  1.836665e+20         2          0                   0
# 1055       7567400  2.464909e+20         5          0                   0
# 1056        822750  1.962279e+20         4          2                   0
#
#       mes   dia   año
# 0      10  1282  2019
# 1      10  1182  2020
# 2      10  1405  2020
# 3      10  3071  2020
# 4      10   323  2020
# ...   ...   ...   ...
# 1052    9  1534  2022
# 1053    9  1302  2022
# 1054    9  1550  2022
# 1055    9  2173  2022
# 1056    9  1673  2022
#
# [1057 rows x 11 columns]

# %%
base_2022 = base[(base['año'] == 2022) 
                 | ((base['año'] == 2021) & (base['mes'] == 11)) 
                 | ((base['año'] == 2021) & (base['mes'] == 12))]
base_2022
# Out:
#       Unnamed: 0  mes_año                                          Ubicación  \
# 52            52  10_2022                                           Amazonas
# 53            53  10_2022                                          Antioquia
# 54            54  10_2022                                             Arauca
# 55            55  10_2022                                          Atlantico
# 56            56  10_2022  Barranquilla, Cartagena, Santa Marta, Atlántic...
# ...          ...      ...                                                ...
# 1052        1052   9_2022                                    Valle del Cauca
# 1053        1053   9_2022                                             Vaupes
# 1054        1054   9_2022                                            Vichada
# 1055        1055   9_2022                                      Villavicencio
# 1056        1056   9_2022  Villavicencio, Meta, Casanare, Amazonas, Guain...
#
#       Unnamed: 0.1            id  Capturas  Migrantes  Capturas Migrantes  \
# 52         9507465  1.043790e+20         9          1                   1
# 53        12704571  3.131823e+20        28          1                   0
# 54         5014245  9.169601e+19         1          0                   0
# 55         8491431  1.233377e+20         7          0                   0
# 56         1651975  2.688845e+20        13          0                   0
# ...            ...           ...       ...        ...                 ...
# 1052       3817949  1.852271e+20         0          0                   0
# 1053       7604619  1.241031e+20         7          0                   0
# 1054       9382230  1.836665e+20         2          0                   0
# 1055       7567400  2.464909e+20         5          0                   0
# 1056        822750  1.962279e+20         4          2                   0
#
#       mes   dia   año
# 52     10  1038  2022
# 53     10  3201  2022
# 54     10   815  2022
# 55     10  1154  2022
# 56     10  2719  2022
# ...   ...   ...   ...
# 1052    9  1534  2022
# 1053    9  1302  2022
# 1054    9  1550  2022
# 1055    9  2173  2022
# 1056    9  1673  2022
#
# [709 rows x 11 columns]

# %%
data_grafico_1 = base_2022.groupby(['Ubicación']).sum()
data_grafico_1['Participación migrantes en crimen'] = data_grafico_1['Capturas Migrantes']/data_grafico_1['Capturas']
data_grafico_1 = data_grafico_1.sort_values(by=['Participación migrantes en crimen'], ascending=False)
data_grafico_1.head(10)
# Out:
#                                                     Unnamed: 0  Unnamed: 0.1  \
# Ubicación
# Amazonas                                                  6175     137395725
# Bucaramanga                                               5236     168958400
# Vichada                                                   6845     140631191
# Cúcuta                                                    6449     186132255
# Bucaramanga, Cúcuta, Santander, Norte de Santan...        4384      27723930
# Quindio                                                   6703     143740278
# Bogotá                                                    6239       3812941
# Tunja                                                     3148     445438400
# Bogotá, Boyacá, Cundinamarca                              6252      12869611
# Casanare                                                  6375     184680503
#
#                                                               id  Capturas  \
# Ubicación
# Amazonas                                            1.446119e+21       101
# Bucaramanga                                         4.937492e+21       781
# Vichada                                             2.637207e+21        78
# Cúcuta                                              4.098075e+21       410
# Bucaramanga, Cúcuta, Santander, Norte de Santan...  1.628343e+21        86
# Quindio                                             3.064156e+21       173
# Bogotá                                              4.173462e+21       846
# Tunja                                               5.020367e+21       862
# Bogotá, Boyacá, Cundinamarca                        9.952514e+20        54
# Casanare                                            3.072240e+21       185
#
#                                                     Migrantes  \
# Ubicación
# Amazonas                                                    8
# Bucaramanga                                                40
# Vichada                                                     4
# Cúcuta                                                     28
# Bucaramanga, Cúcuta, Santander, Norte de Santan...          2
# Quindio                                                     6
# Bogotá                                                     16
# Tunja                                                      27
# Bogotá, Boyacá, Cundinamarca                                3
# Casanare                                                    3
#
#                                                     Capturas Migrantes  mes  \
# Ubicación
# Amazonas                                                             6   89
# Bucaramanga                                                         40   63
# Vichada                                                              3   89
# Cúcuta                                                              14   89
# Bucaramanga, Cúcuta, Santander, Norte de Santan...                   2   72
# Quindio                                                              4   89
# Bogotá                                                              16   89
# Tunja                                                               16   45
# Bogotá, Boyacá, Cundinamarca                                         1   89
# Casanare                                                             3   89
#
#                                                       dia    año  \
# Ubicación
# Amazonas                                            14342  26284
# Bucaramanga                                         51435  18198
# Vichada                                             27045  26284
# Cúcuta                                              41310  26284
# Bucaramanga, Cúcuta, Santander, Norte de Santan...  16972  22240
# Quindio                                             29458  26284
# Bogotá                                              42651  26284
# Tunja                                               53980  10110
# Bogotá, Boyacá, Cundinamarca                         9145  26284
# Casanare                                            29673  26284
#
#                                                     Participación migrantes en crimen
# Ubicación
# Amazonas                                                                     0.059406
# Bucaramanga                                                                  0.051216
# Vichada                                                                      0.038462
# Cúcuta                                                                       0.034146
# Bucaramanga, Cúcuta, Santander, Norte de Santan...                           0.023256
# Quindio                                                                      0.023121
# Bogotá                                                                       0.018913
# Tunja                                                                        0.018561
# Bogotá, Boyacá, Cundinamarca                                                 0.018519
# Casanare                                                                     0.016216

# %%
# Principales ubicaciones
data_grafico_1.index[0:5]
# Out:
# Index(['Amazonas', 'Bucaramanga', 'Vichada', 'Cúcuta',
#        'Bucaramanga, Cúcuta, Santander, Norte de Santander, Arauca, Magdalena Medio'],
#       dtype='object', name='Ubicación')

# %%
data_grafico_1 = base_2022.sort_values(by=['Capturas Migrantes'], ascending=False)
data_grafico_1.head(20)
# Out:
#       Unnamed: 0  mes_año        Ubicación  Unnamed: 0.1            id  \
# 1049        1049   9_2022            Tunja     112562642  1.271435e+21
# 611          611   5_2022      Bucaramanga      34795475  9.915243e+20
# 135          135  11_2021           Cúcuta      27955314  5.854588e+20
# 904          904   8_2022      Bucaramanga      17267154  5.177431e+20
# 702          702   6_2022      Bucaramanga      27268735  7.918420e+20
# 800          800   7_2022      Bucaramanga      27055686  7.993739e+20
# 1010        1010   9_2022      Bucaramanga      13754993  4.176381e+20
# 698          698   6_2022           Bogotá        149946  3.089871e+20
# 520          520   4_2022           Bogotá        247428  3.274465e+20
# 239          239  12_2021           Bogotá        571914  3.707201e+20
# 320          320   1_2022           Cúcuta      16659125  3.574277e+20
# 537          537   4_2022           Cúcuta      17024877  3.772757e+20
# 308          308   1_2022           Boyacá      10482115  3.531360e+20
# 796          796   7_2022           Bogotá         98120  2.724527e+20
# 555          555   4_2022          Popayan      25603125  2.272468e+20
# 101          101  10_2022            Tunja     138508965  1.584543e+21
# 161          161  11_2021  Valle del Cauca      12312900  5.255217e+20
# 445          445   3_2022           Bogotá        359710  3.909729e+20
# 61            61  10_2022      Bucaramanga      15684625  4.825052e+20
# 106          106  10_2022          Vichada       7848085  1.550078e+20
#
#       Capturas  Migrantes  Capturas Migrantes  mes    dia   año
# 1049       245         22                  14    9  14802  2022
# 611        177         11                  11    5   9050  2022
# 135         67         11                   7   11   5714  2021
# 904        112          7                   7    8   5291  2022
# 702        106          7                   7    6   8392  2022
# 800        134          6                   6    7   9478  2022
# 1010        90          5                   5    9   3731  2022
# 698         78          3                   3    6   3079  2022
# 520         65          3                   3    4   3807  2022
# 239         74          3                   3   12   3743  2021
# 320         45          3                   2    1   4100  2022
# 537         35          4                   2    4   3858  2022
# 308         22          2                   2    1   4472  2022
# 796         62          2                   2    7   2657  2022
# 555         18          3                   2    4   2245  2022
# 101        288          4                   2   10  15249  2022
# 161         46          3                   2   11   4908  2021
# 445         80          2                   2    3   3873  2022
# 61          75          2                   2   10   5168  2022
# 106          4          3                   2   10   1579  2022

# %%
data_grafico_1 = base_2022.sort_values(by=['Capturas Migrantes'], ascending=False)
data_grafico_1 = data_grafico_1[data_grafico_1['Ubicación'].isin(['Amazonas', 'Bucaramanga', 'Vichada', 'Cúcuta','Bogotá','Tunja','Cali','Nariño'])]
data_grafico_1 = data_grafico_1.sort_values(by=['Ubicación','mes'], ascending=True)
data_grafico_1 = data_grafico_1.groupby(['Ubicación']).sum()
data_grafico_1 = data_grafico_1.sort_values(by=['Capturas Migrantes'], ascending=False)
data_grafico_1
# Out:
#              Unnamed: 0  Unnamed: 0.1            id  Capturas  Migrantes  \
# Ubicación
# Bucaramanga        5236     168958400  4.937492e+21       781         40
# Bogotá             6239       3812941  4.173462e+21       846         16
# Tunja              3148     445438400  5.020367e+21       862         27
# Cúcuta             6449     186132255  4.098075e+21       410         28
# Amazonas           6175     137395725  1.446119e+21       101          8
# Vichada            6845     140631191  2.637207e+21        78          4
# Cali               6196     179198400  4.909910e+21       828          4
# Nariño             6612      61448770  3.116587e+21       171          8
#
#              Capturas Migrantes  mes    dia    año
# Ubicación
# Bucaramanga                  40   63  51435  18198
# Bogotá                       16   89  42651  26284
# Tunja                        16   45  53980  10110
# Cúcuta                       14   89  41310  26284
# Amazonas                      6   89  14342  26284
# Vichada                       3   89  27045  26284
# Cali                          2   78  52122  24263
# Nariño                        1   89  31024  26284

# %%
data_grafico_1 = data_grafico_1.sort_values(by=['Capturas Migrantes'], ascending=False)
plt.figure(figsize=(20,5))
lines = sns.barplot(data=data_grafico_1, x=data_grafico_1.index, y="Capturas Migrantes")
#sns.move_legend(lines, "upper left", bbox_to_anchor=(1, 1))
#trat = sns.scatterplot(x="Treated", y= "y_coord", data=base_nodos)
#ax2 = ax.twinx()
#cont = sns.scatterplot(x="Control", y= "y_coord", data=base_nodos, ax=ax2)
#plt.axvline(x = 0, color = 'b', label = '')
# add label to the axis and label to the plot
#for i in range(len(Short_name)):
    #plt.annotate(Short_name[i], (base_nodos['Treated'][i]-0.15, base_nodos['y_coord'][i]-0.01) )
   # plt.annotate(Short_name[i], (base_nodos['Control'][i]+0.05, base_nodos['y_coord'][i]-0.01) )
lines.set(xlabel = "Ubicación", ylabel = 'Capturas a Migrantes')
#cont.set( ylabel = '')
plt.grid(False)
#ax2.grid(False)

# %%
data_grafico_1 = base_2022.groupby(['Ubicación']).sum()
data_grafico_1 = data_grafico_1.sort_values(by=['Tasa capturas de migrantes'], ascending=False)
data_grafico_1.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19972/2165497113.py in <module>
#       1 data_grafico_1 = base_2022.groupby(['Ubicación']).sum()
# ----> 2 data_grafico_1 = data_grafico_1.sort_values(by=['Tasa capturas de migrantes'], ascending=False)
#       3 data_grafico_1.head(10)
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6252
#    6253             by = by[0]
# -> 6254             k = self._get_label_or_level_values(by, axis=axis)
#    6255
#    6256             # need to rewrap column in Series to apply key function
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'Tasa capturas de migrantes'

# %%
data_grafico_1 = base_2022.sort_values(by=['Tasa capturas de migrantes'], ascending=False)
data_grafico_1 = data_grafico_1[data_grafico_1['Ubicación'].isin(['Amazonas', 'Bucaramanga', 'Vichada', 'Cúcuta','Bogotá','Tunja','Cali','Nariño'])]
data_grafico_1 = data_grafico_1.sort_values(by=['Ubicación','mes'], ascending=True)
data_grafico_1 = data_grafico_1.groupby(['Ubicación']).sum()
data_grafico_1 = data_grafico_1.sort_values(by=['Capturas Migrantes'], ascending=False)
data_grafico_1['Participación migrantes en crimen'] = data_grafico_1['Capturas Migrantes']/data_grafico_1['Capturas']
data_grafico_1 = data_grafico_1.sort_values(by=['Participación migrantes en crimen'], ascending=False)
data_grafico_1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19972/4248743833.py in <module>
# ----> 1 data_grafico_1 = base_2022.sort_values(by=['Tasa capturas de migrantes'], ascending=False)
#       2 data_grafico_1 = data_grafico_1[data_grafico_1['Ubicación'].isin(['Amazonas', 'Bucaramanga', 'Vichada', 'Cúcuta','Bogotá','Tunja','Cali','Nariño'])]
#       3 data_grafico_1 = data_grafico_1.sort_values(by=['Ubicación','mes'], ascending=True)
#       4 data_grafico_1 = data_grafico_1.groupby(['Ubicación']).sum()
#       5 data_grafico_1 = data_grafico_1.sort_values(by=['Capturas Migrantes'], ascending=False)
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6252
#    6253             by = by[0]
# -> 6254             k = self._get_label_or_level_values(by, axis=axis)
#    6255
#    6256             # need to rewrap column in Series to apply key function
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'Tasa capturas de migrantes'

# %%
data_grafico_1['Participación migrantes en crimen'] = data_grafico_1['Capturas Migrantes']/data_grafico_1['Capturas']
data_grafico_1 = data_grafico_1.sort_values(by=['Participación migrantes en crimen'], ascending=False)
plt.figure(figsize=(20,5))
data_grafico_1 = data_grafico_1[data_grafico_1['Ubicación'].isin(['Amazonas', 'Bucaramanga', 'Vichada', 'Cúcuta','Bogotá','Tunja','Cali','Nariño'])]
lines = sns.barplot(data=data_grafico_1, x=data_grafico_1.index, y="Participación migrantes en crimen")
#sns.move_legend(lines, "upper left", bbox_to_anchor=(1, 1))
#trat = sns.scatterplot(x="Treated", y= "y_coord", data=base_nodos)
#ax2 = ax.twinx()
#cont = sns.scatterplot(x="Control", y= "y_coord", data=base_nodos, ax=ax2)
#plt.axvline(x = 0, color = 'b', label = '')
# add label to the axis and label to the plot
#for i in range(len(Short_name)):
    #plt.annotate(Short_name[i], (base_nodos['Treated'][i]-0.15, base_nodos['y_coord'][i]-0.01) )
   # plt.annotate(Short_name[i], (base_nodos['Control'][i]+0.05, base_nodos['y_coord'][i]-0.01) )
lines.set(xlabel = "Ubicación", ylabel = 'Participación migrantes en crimen')
#cont.set( ylabel = '')
plt.grid(False)
#ax2.grid(False)
# Out:
# C:\Users\JOSE\AppData\Local\Temp/ipykernel_3380/2314056652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_grafico_1['Participación migrantes en crimen'] = data_grafico_1['Capturas Migrantes']/data_grafico_1['Capturas']

# %%
data_grafico_1 = base_2022[base_2022['Ubicación'].isin(['Amazonas', 'Arauca', 'Vichada', 'Cúcuta','Guainia','Bogotá','Nariño'])]
data_grafico_1.head(10)
# Out:
#      Unnamed: 0  mes_año Ubicación  Unnamed: 0.1            id  Capturas  \
# 52           52  10_2022  Amazonas       9507465  1.043790e+20         9
# 54           54  10_2022    Arauca       5014245  9.169601e+19         1
# 57           57  10_2022    Bogotá         19920  2.531396e+20        54
# 74           74  10_2022    Cúcuta      10163206  2.388232e+20         1
# 75           75  10_2022   Guainia       7659598  1.454828e+20         8
# 87           87  10_2022    Nariño       3293403  1.803437e+20        24
# 106         106  10_2022   Vichada       7848085  1.550078e+20         4
# 118         118  11_2021  Amazonas       8115660  8.173457e+19         3
# 119         119  11_2021    Arauca      14782599  2.468436e+20        15
# 122         122  11_2021    Bogotá        943731  5.344711e+20        86
#
#      Migrantes  Capturas Migrantes  mes   dia   año
# 52           1                   1   10  1038  2022
# 54           0                   0   10   815  2022
# 57           0                   0   10  2763  2022
# 74           1                   0   10  2395  2022
# 75           0                   0   10  1376  2022
# 87           0                   0   10  1917  2022
# 106          3                   2   10  1579  2022
# 118          0                   0   11   730  2021
# 119          3                   0   11  2691  2021
# 122          1                   1   11  5505  2021

# %%
figure, axes = plt.subplots(1, 2, sharex=True, figsize=(20,5))
lines = sns.lineplot(ax=axes[0],data=data_grafico_1, x="mes_año", y="Capturas Migrantes", hue="Ubicación")
lines_2 = sns.lineplot(ax=axes[1],data=data_grafico_1, x="mes_año", y="Capturas", hue="Ubicación")
#sns.move_legend(lines, "upper left", bbox_to_anchor=(1, 1))
#trat = sns.scatterplot(x="Treated", y= "y_coord", data=base_nodos)
#ax2 = ax.twinx()
#cont = sns.scatterplot(x="Control", y= "y_coord", data=base_nodos, ax=ax2)
#plt.axvline(x = 0, color = 'b', label = '')
# add label to the axis and label to the plot
#for i in range(len(Short_name)):
    #plt.annotate(Short_name[i], (base_nodos['Treated'][i]-0.15, base_nodos['y_coord'][i]-0.01) )
   # plt.annotate(Short_name[i], (base_nodos['Control'][i]+0.05, base_nodos['y_coord'][i]-0.01) )
axes[0].set_xticklabels(data_grafico_1['mes_año'],rotation=45, ha='right')
axes[1].set_xticklabels(data_grafico_1['mes_año'],rotation=45, ha='right')
axes[0].grid(False)
axes[1].grid(False)
lines.set(xlabel = "mes_año", ylabel = 'Capturas Migrantes')
#cont.set( ylabel = '')
#figure.grid(False)
#ax2.grid(False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3380/2295308860.py in <module>
#       1 figure, axes = plt.subplots(1, 2, sharex=True, figsize=(20,5))
# ----> 2 lines = sns.lineplot(ax=axes[0],data=data_grafico_1, x="mes_año", y="Capturas Migrantes", hue="Ubicación")
#       3 lines_2 = sns.lineplot(ax=axes[1],data=data_grafico_1, x="mes_año", y="Capturas", hue="Ubicación")
#       4 #sns.move_legend(lines, "upper left", bbox_to_anchor=(1, 1))
#       5 #trat = sns.scatterplot(x="Treated", y= "y_coord", data=base_nodos)
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     690
#     691     variables = _LinePlotter.get_semantics(locals())
# --> 692     p = _LinePlotter(
#     693         data=data, variables=variables,
#     694         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     603     def __init__(self, data=None, variables={}):
#     604
# --> 605         self.assign_variables(data, variables)
#     606
#     607         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666         else:
#     667             self.input_format = "long"
# --> 668             plot_data, variables = self._assign_variables_longform(
#     669                 data, **variables,
#     670             )
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     901
#     902                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903                 raise ValueError(err)
#     904
#     905             else:
#
# ValueError: Could not interpret value `mes_año` for parameter `x`

# %%
data_grafico_1 = base_2022.sort_values(by=['Capturas Migrantes'], ascending=False)
data_grafico_1 = data_grafico_1[data_grafico_1['Ubicación'].isin(['Tunja', 'Bucaramanga', 'Cali','Cúcuta', 'Bogotá'])]
print("Promedio Nacional 2022: ")
data_grafico_1['Tasa capturas de migrantes'].mean()
# Out:
# Promedio Nacional 2022:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tasa capturas de migrantes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3380/1289931327.py in <module>
#       2 data_grafico_1 = data_grafico_1[data_grafico_1['Ubicación'].isin(['Tunja', 'Bucaramanga', 'Cali','Cúcuta', 'Bogotá'])]
#       3 print("Promedio Nacional 2022: ")
# ----> 4 data_grafico_1['Tasa capturas de migrantes'].mean()
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~\anaconda3\envs\nltkenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Tasa capturas de migrantes'

# %%
pd.unique(base_2022['Ubicación'])
# Out:
# array(['Amazonas', 'Antioquia', 'Arauca', 'Atlantico',
#        'Barranquilla, Cartagena, Santa Marta, Atlántico, Bolívar, Magdalena, La Guajira, Sucre, San Andrés Y Providencia, Cesar',
#        'Bogotá', 'Bogotá, Boyacá, Cundinamarca', 'Bolivar', 'Boyacá',
#        'Bucaramanga',
#        'Bucaramanga, Cúcuta, Santander, Norte de Santander, Arauca, Magdalena Medio',
#        'Caldas', 'Cali',
#        'Cali, Valle del Cauca, Cauca, Nariño, Buenaventura, Tumaco',
#        'Caqueta', 'Cartagena', 'Casanare', 'Cauca', 'Cesar', 'Choco',
#        'Cordoba', 'Cúcuta', 'Cundinamarca', 'Guainia', 'Guajira', 'Huila',
#        'Ibague', 'Ibagué, Tolima, Huila, Caquetá, Putumayo', 'Magdalena',
#        'Magdalena Medio', 'Manizales', 'Medellín', 'Meta', 'Monteria',
#        'Nacional', 'Nariño', 'Norte de Santander', 'Pasto', 'Pereira',
#        'Pereira, Risaralda, Caldas, Quindío', 'Popayan', 'Putumayo',
#        'Quindio', 'Risaralda', 'San Andrés y Providencia', 'Santa Marta',
#        'Santander', 'Sucre', 'Tolima', 'Tunja', 'Uraba',
#        'Valle de Aburrá, Antioquia, Chocó, Urabá, Córdoba, Bajo Cauca Antioqueño',
#        'Valle del Cauca', 'Vaupes', 'Vichada', 'Villavicencio',
#        'Villavicencio, Meta, Casanare, Amazonas, Guainía, Guaviare, Vichada, Vaupés'],
#       dtype=object)

# %%
data_grafico_1 = base_2022[base_2022['Ubicación'].isin(['Antioquia', 'Atlantico', 'Bogotá', 'Vichada', 'Casanare','Caldas','Caqueta','Casanare',
                                                       'Cauca', 'Cesar','Choco','Cordoba','Cundinamarca','Guainia','Guajira','Huila','Magdalena Medio',
                                                       'Nariño','Norte de Santander','San Andrés y Providencia','Vaupes','Vichada','Valle del Cauca','Sucre',
                                                       'Putumayo','Huila','Meta','Arauca','Quindío','Risaralda','Santander','Tolima','Guaviare','Bolivar','Boyacá',
                                             'Amazonas','Cúcuta'])]
pd.unique(data_grafico_1['Ubicación'])
# Out:
# array(['Amazonas', 'Antioquia', 'Arauca', 'Atlantico', 'Bogotá',
#        'Bolivar', 'Boyacá', 'Caldas', 'Caqueta', 'Casanare', 'Cauca',
#        'Cesar', 'Choco', 'Cordoba', 'Cundinamarca', 'Cúcuta', 'Guainia',
#        'Guajira', 'Huila', 'Magdalena Medio', 'Meta', 'Nariño',
# San Andrés y Providencia          1                   0   89  19343  26284
# Santander                         0                   0   89  37916  26284
# Sucre                             2                   0   89  18295  26284
# Tolima                            0                   0   89  18880  26284
# Valle del Cauca                   4                   2   89  35296  26284
# Vaupes                            2                   0   89  19327  26284
# Vichada                           4                   3   89  27045  26284

# %%
data_grafico_1['Participación migrantes en crimen'] = data_grafico_1['Capturas Migrantes']/data_grafico_1['Capturas']
data_grafico_1 = data_grafico_1.sort_values(by=['Participación migrantes en crimen'], ascending=False)

# %%
data_grafico_1.head(6)
# Out:
#            Unnamed: 0  Unnamed: 0.1            id  Capturas  Migrantes  \
# Ubicación
# Amazonas         6175     137395725  1.446119e+21       101          8
# Vichada          6845     140631191  2.637207e+21        78          4
# Cúcuta           6449     186132255  4.098075e+21       410         28
# Bogotá           6239       3812941  4.173462e+21       846         16
# Casanare         6375     184680503  3.072240e+21       185          3
# Putumayo         6690     138735585  2.045886e+21        63          1
#
#            Capturas Migrantes  mes    dia    año  \
# Ubicación
# Amazonas                    6   89  14342  26284
# Vichada                     3   89  27045  26284
# Cúcuta                     14   89  41310  26284
# Bogotá                     16   89  42651  26284
# Casanare                    3   89  29673  26284
# Putumayo                    1   89  21786  26284
#
#            Participación migrantes en crimen
# Ubicación
# Amazonas                            0.059406
# Vichada                             0.038462
# Cúcuta                              0.034146
# Bogotá                              0.018913
# Casanare                            0.016216
# Putumayo                            0.015873

# %%
data_grafico_1.to_excel('Participación_migrantes_crimen.xlsx')

# %%
data_grafico_1 = data_grafico_1[data_grafico_1.index.isin(['Amazonas', 'Arauca', 'Vichada', 'Cúcuta','Guainia','Bogotá','Nariño'])]

# %%
data_grafico_1 = base_2022.groupby(['Ubicación']).sum()
data_grafico_1
# Out:
#                                                     Unnamed: 0  Unnamed: 0.1  \
# Ubicación
# Amazonas                                                  6175     137395725
# Antioquia                                                 6069     209918400
# Arauca                                                    6200     100545990
# Atlantico                                                 6213     123142175
# Barranquilla, Cartagena, Santa Marta, Atlántico...        6226      20932476
# Bogotá                                                    6239       3812941
# Bogotá, Boyacá, Cundinamarca                              6252      12869611
# Bolivar                                                   6265     238278996
# Boyacá                                                    6278     135999675
# Bucaramanga                                               5236     168958400
# Bucaramanga, Cúcuta, Santander, Norte de Santan...        4384      27723930
# Caldas                                                    6311     240638400
# Cali                                                      6196     179198400
# Cali, Valle del Cauca, Cauca, Nariño, Buenavent...        6336      46750203
# Caqueta                                                   6349     207912685
# Cartagena                                                 6362     558078400
# Casanare                                                  6375     184680503
# Cauca                                                     6388     282214128
# Cesar                                                     6401     225047160
# Choco                                                     5710     322558400
# Cordoba                                                   6290     363518400
# Cundinamarca                                              6436     199678400
# Cúcuta                                                    6449     186132255
# Guainia                                                   6462      82184071
# Guajira                                                   6475     154952685
# Huila                                                     6488     366862811
# Ibague                                                    6501     353160486
# Ibagué, Tolima, Huila, Caquetá, Putumayo                  6514      30743955
# Magdalena                                                 6527      78434785
# Magdalena Medio                                           6398     435198400
# Manizales                                                 6552      71289466
# Tunja                                               5.020367e+21       862
# Uraba                                               3.598653e+21       308
# Valle de Aburrá, Antioquia, Chocó, Urabá, Córdo...  4.952076e+21       289
# Valle del Cauca                                     3.608888e+21       217
# Vaupes                                              1.837516e+21        51
# Vichada                                             2.637207e+21        78
# Villavicencio                                       3.604808e+21        80
# Villavicencio, Meta, Casanare, Amazonas, Guainí...  2.698112e+21        72
#
#                                                     Migrantes  \
# Ubicación
# Amazonas                                                    8
# Antioquia                                                   1
# Arauca                                                      6
# Atlantico                                                   1
# Barranquilla, Cartagena, Santa Marta, Atlántico...          2
# Bogotá                                                     16
# Bogotá, Boyacá, Cundinamarca                                3
# Bolivar                                                     0
# Boyacá                                                      5
# Bucaramanga                                                40
# Bucaramanga, Cúcuta, Santander, Norte de Santan...          2
# Caldas                                                      3
# Cali                                                        4
# Cali, Valle del Cauca, Cauca, Nariño, Buenavent...          0
# Caqueta                                                     0
# Cartagena                                                   9
# Casanare                                                    3
# Cauca                                                       1
# Cesar                                                       3
# Choco                                                      13
# Cordoba                                                     5
# Cundinamarca                                                1
# Cúcuta                                                     28
# Guainia                                                     0
# Guajira                                                     5
# Huila                                                       0
# Ibague                                                      0
# Ibagué, Tolima, Huila, Caquetá, Putumayo                    0
# Magdalena                                                   0
# Magdalena Medio                                             0
# Manizales                                                   6
# Medellín                                                    5
# Meta                                                       11
# Monteria                                                    0
# Nacional                                                    1
# Nariño                                                      8
# Norte de Santander                                          2
# Pasto                                                       2
# Pereira                                                     1
# Pereira, Risaralda, Caldas, Quindío                         2
# Popayan                                                     7
# Putumayo                                                    1
# Quindio                                                     6
# Risaralda                                                   1
# San Andrés y Providencia                                    1
# Santa Marta                                                 2
# Santander                                                   0
# Sucre                                                       2
# Tolima                                                      0
# Tunja                                                      27
# Uraba                                                       2
# Valle de Aburrá, Antioquia, Chocó, Urabá, Córdo...          1
# Valle del Cauca                                             4
# Vaupes                                                      2
# Vichada                                                     4
# Villavicencio                                               1
# Villavicencio, Meta, Casanare, Amazonas, Guainí...          2
#
#                                                     Capturas Migrantes  mes  \
# Ubicación
# Amazonas                                                             6   89
# Antioquia                                                            0   78
# Arauca                                                               0   89
# Atlantico                                                            1   89
# Barranquilla, Cartagena, Santa Marta, Atlántico...                   1   89
# Bogotá                                                              16   89
# Bogotá, Boyacá, Cundinamarca                                         1   89
# Bolivar                                                              0   89
# Boyacá                                                               4   89
# Bucaramanga                                                         40   63
# Bucaramanga, Cúcuta, Santander, Norte de Santan...                   2   72
# Caldas                                                               0   89
# Cali                                                                 2   78
# Cali, Valle del Cauca, Cauca, Nariño, Buenavent...                   0   89
# Caqueta                                                              0   89
# Cartagena                                                            0   89
# Casanare                                                             3   89
# Cauca                                                                0   89
# Cesar                                                                0   89
# Choco                                                                1   65
# Cordoba                                                              2   78
# Cundinamarca                                                         0   89
# Cúcuta                                                              14   89
# Guainia                                                              0   89
# Guajira                                                              1   89
# Huila                                                                0   89
# Ibague                                                               0   89
# Ibagué, Tolima, Huila, Caquetá, Putumayo                             0   89
